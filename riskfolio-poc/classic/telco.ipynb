# %%
import numpy as np
import pandas as pd
import yfinance as yf
import warnings
import json

warnings.filterwarnings("ignore")
pd.options.display.float_format = '{:.4%}'.format

params = json.loads(open('params.json', 'r').read())

# Date range
start = params["start_date"]
end = params["end_date"]

# Tickers of assets
OIL = 'Oil gas biofuels, exploration, refining etc'
TELCO = 'Telecommunications'
PULP_PAPER = 'Pulp and Paper'
ELECTRICAL = 'Electrical energy'
MINERALS = 'Minerals'

industry_asset = json.loads(open('stocks.json', 'r').read())
assets = []
for value in industry_asset[TELCO]:
    assets.append(value)

# Downloading data
data = yf.download(assets, start = start, end = end)

data = data.loc[:,('Adj Close', slice(None))]

data.columns = assets
# Out:
# [*********************100%%**********************]  2 of 2 completed

# %%
# Calculating returns
Y = data[assets].pct_change().dropna()

display(Y.tail())
# Out:
#             TIMS3.SA  VIVT3.SA
# Date
# 2023-10-27  -2.7326%  -2.8454%
# 2023-10-30   0.0669%   0.8272%
# 2023-10-31   1.4037%   0.3104%
# 2023-11-01   4.3507%   5.0619%
# 2023-11-03   0.1895%   0.2525%

# %%
import riskfolio as rp

# Building the portfolio object
port = rp.Portfolio(returns=Y)

# Calculating optimal portfolio

# Select method and estimate input parameters:

method_mu='hist' # Method to estimate expected returns based on historical data.
method_cov='hist' # Method to estimate covariance matrix based on historical data.

port.assets_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

# Estimate optimal portfolio:

model='Classic' # Could be Classic (historical), BL (Black Litterman) or FM (Factor Model)
rm = 'MV' # Risk measure used, this time will be variance
obj = 'Sharpe' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = True # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
l = 0 # Risk aversion factor, only useful when obj is 'Utility'

w_sharpe = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w_sharpe.T)

# Plotting the composition of the portfolio

ax_sharpe = rp.plot_pie(w=w_sharpe, title='Sharpe Mean Variance', others=0.05, nrow=25, cmap = "tab20",
                 height=6, width=10, ax=None)
# Out:
#          TIMS3.SA  VIVT3.SA
# weights  69.0788%  30.9212%

# %%
# Plotting frontier

points = 50 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)
# display(frontier.T.tail())

# Plotting the efficient frontier

label = 'Sharpe Adjusted Return Portfolio' # Title of point
mu = port.mu # Expected returns
cov = port.cov # Covariance matrix
returns = port.returns # Returns of the assets

ax = rp.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                      rf=rf, alpha=0.05, cmap='viridis', w=w_sharpe, label=label,
                      marker='*', s=16, c='r', height=6, width=10, ax=None)

# %%
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

# %%
# Risk Measures available:
#
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

rms = ['MV', 'MAD', 'MSV', 'FLPM', 'SLPM', 'CVaR',
       'EVaR', 'WR', 'MDD', 'ADD', 'CDaR', 'UCI', 'EDaR']

w_s = pd.DataFrame([])

for i in rms:
    w = port.optimization(model=model, rm=i, obj=obj, rf=rf, l=l, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
    
w_s.columns = rms

w_s.style.format("{:.2%}").background_gradient(cmap='YlGn')
# Out:
# <style type="text/css">
# #T_2e98b_row0_col0, #T_2e98b_row0_col1, #T_2e98b_row0_col2, #T_2e98b_row0_col3, #T_2e98b_row0_col4, #T_2e98b_row0_col5, #T_2e98b_row0_col6, #T_2e98b_row0_col7, #T_2e98b_row0_col8, #T_2e98b_row0_col9, #T_2e98b_row0_col10, #T_2e98b_row0_col11, #T_2e98b_row0_col12 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_2e98b_row1_col0, #T_2e98b_row1_col1, #T_2e98b_row1_col2, #T_2e98b_row1_col3, #T_2e98b_row1_col4, #T_2e98b_row1_col5, #T_2e98b_row1_col6, #T_2e98b_row1_col7, #T_2e98b_row1_col8, #T_2e98b_row1_col9, #T_2e98b_row1_col10, #T_2e98b_row1_col11, #T_2e98b_row1_col12 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# </style>
# <table id="T_2e98b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e98b_level0_col0" class="col_heading level0 col0" >MV</th>
#       <th id="T_2e98b_level0_col1" class="col_heading level0 col1" >MAD</th>
#       <th id="T_2e98b_level0_col2" class="col_heading level0 col2" >MSV</th>
#       <th id="T_2e98b_level0_col3" class="col_heading level0 col3" >FLPM</th>
#       <th id="T_2e98b_level0_col4" class="col_heading level0 col4" >SLPM</th>
#       <th id="T_2e98b_level0_col5" class="col_heading level0 col5" >CVaR</th>
#       <th id="T_2e98b_level0_col6" class="col_heading level0 col6" >EVaR</th>
#       <th id="T_2e98b_level0_col7" class="col_heading level0 col7" >WR</th>
#       <th id="T_2e98b_level0_col8" class="col_heading level0 col8" >MDD</th>
#       <th id="T_2e98b_level0_col9" class="col_heading level0 col9" >ADD</th>
#       <th id="T_2e98b_level0_col10" class="col_heading level0 col10" >CDaR</th>
#       <th id="T_2e98b_level0_col11" class="col_heading level0 col11" >UCI</th>
#       <th id="T_2e98b_level0_col12" class="col_heading level0 col12" >EDaR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e98b_level0_row0" class="row_heading level0 row0" >TIMS3.SA</th>
#       <td id="T_2e98b_row0_col0" class="data row0 col0" >69.08%</td>
#       <td id="T_2e98b_row0_col1" class="data row0 col1" >64.12%</td>
#       <td id="T_2e98b_row0_col2" class="data row0 col2" >70.13%</td>
#       <td id="T_2e98b_row0_col3" class="data row0 col3" >64.34%</td>
#       <td id="T_2e98b_row0_col4" class="data row0 col4" >70.38%</td>
#       <td id="T_2e98b_row0_col5" class="data row0 col5" >64.70%</td>
#       <td id="T_2e98b_row0_col6" class="data row0 col6" >74.49%</td>
#       <td id="T_2e98b_row0_col7" class="data row0 col7" >85.79%</td>
#       <td id="T_2e98b_row0_col8" class="data row0 col8" >88.76%</td>
#       <td id="T_2e98b_row0_col9" class="data row0 col9" >99.70%</td>
#       <td id="T_2e98b_row0_col10" class="data row0 col10" >83.68%</td>
#       <td id="T_2e98b_row0_col11" class="data row0 col11" >83.68%</td>
#       <td id="T_2e98b_row0_col12" class="data row0 col12" >83.61%</td>
#     </tr>
#     <tr>
#       <th id="T_2e98b_level0_row1" class="row_heading level0 row1" >VIVT3.SA</th>
#       <td id="T_2e98b_row1_col0" class="data row1 col0" >30.92%</td>
#       <td id="T_2e98b_row1_col1" class="data row1 col1" >35.88%</td>
#       <td id="T_2e98b_row1_col2" class="data row1 col2" >29.87%</td>
#       <td id="T_2e98b_row1_col3" class="data row1 col3" >35.66%</td>
#       <td id="T_2e98b_row1_col4" class="data row1 col4" >29.62%</td>
#       <td id="T_2e98b_row1_col5" class="data row1 col5" >35.30%</td>
#       <td id="T_2e98b_row1_col6" class="data row1 col6" >25.51%</td>
#       <td id="T_2e98b_row1_col7" class="data row1 col7" >14.21%</td>
#       <td id="T_2e98b_row1_col8" class="data row1 col8" >11.24%</td>
#       <td id="T_2e98b_row1_col9" class="data row1 col9" >0.30%</td>
#       <td id="T_2e98b_row1_col10" class="data row1 col10" >16.32%</td>
#       <td id="T_2e98b_row1_col11" class="data row1 col11" >16.32%</td>
#       <td id="T_2e98b_row1_col12" class="data row1 col12" >16.39%</td>
#     </tr>
#   </tbody>
# </table>

# %%
import riskfolio as rp

# Building the portfolio object
port = rp.Portfolio(returns=Y)

# Calculating optimal portfolio

# Select method and estimate input parameters:

method_mu='hist' # Method to estimate expected returns based on historical data.
method_cov='hist' # Method to estimate covariance matrix based on historical data.

port.assets_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

# Estimate optimal portfolio:

model='Classic' # Could be Classic (historical), BL (Black Litterman) or FM (Factor Model)
rm = 'MV' # Risk measure used, this time will be variance
obj = 'MinRisk' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = True # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
l = 0 # Risk aversion factor, only useful when obj is 'Utility'

w_min_risk = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w_min_risk.T)


# Plotting the composition of the portfolio

ax_min_risk = rp.plot_pie(w=w_min_risk, title='Min risk Variance', others=0.05, nrow=25, cmap = "tab20",
                 height=6, width=10, ax=None)
# Out:
#          TIMS3.SA  VIVT3.SA
# weights  33.2466%  66.7534%

# %%
# Plotting frontier

points = 50 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)
# display(frontier.T.tail())

# Plotting the efficient frontier

label = 'Min Risk Adjusted Return Portfolio' # Title of point
mu = port.mu # Expected returns
cov = port.cov # Covariance matrix
returns = port.returns # Returns of the assets

ax = rp.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                      rf=rf, alpha=0.05, cmap='viridis', w=w_min_risk, label=label,
                      marker='*', s=16, c='r', height=6, width=10, ax=None)

# %%
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

# %%
# Risk Measures available:
#
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

rms = ['MV', 'MAD', 'MSV', 'FLPM', 'SLPM', 'CVaR',
       'EVaR', 'WR', 'MDD', 'ADD', 'CDaR', 'UCI', 'EDaR']

w_s = pd.DataFrame([])

for i in rms:
    w = port.optimization(model=model, rm=i, obj=obj, rf=rf, l=l, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
    
w_s.columns = rms

w_s.style.format("{:.2%}").background_gradient(cmap='YlGn')
# Out:
# <style type="text/css">
# #T_98586_row0_col0, #T_98586_row0_col1, #T_98586_row0_col2, #T_98586_row0_col3, #T_98586_row0_col4, #T_98586_row0_col5, #T_98586_row0_col6, #T_98586_row0_col7, #T_98586_row1_col8, #T_98586_row1_col9, #T_98586_row1_col10, #T_98586_row1_col11, #T_98586_row1_col12 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_98586_row0_col8, #T_98586_row0_col9, #T_98586_row0_col10, #T_98586_row0_col11, #T_98586_row0_col12, #T_98586_row1_col0, #T_98586_row1_col1, #T_98586_row1_col2, #T_98586_row1_col3, #T_98586_row1_col4, #T_98586_row1_col5, #T_98586_row1_col6, #T_98586_row1_col7 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_98586">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98586_level0_col0" class="col_heading level0 col0" >MV</th>
#       <th id="T_98586_level0_col1" class="col_heading level0 col1" >MAD</th>
#       <th id="T_98586_level0_col2" class="col_heading level0 col2" >MSV</th>
#       <th id="T_98586_level0_col3" class="col_heading level0 col3" >FLPM</th>
#       <th id="T_98586_level0_col4" class="col_heading level0 col4" >SLPM</th>
#       <th id="T_98586_level0_col5" class="col_heading level0 col5" >CVaR</th>
#       <th id="T_98586_level0_col6" class="col_heading level0 col6" >EVaR</th>
#       <th id="T_98586_level0_col7" class="col_heading level0 col7" >WR</th>
#       <th id="T_98586_level0_col8" class="col_heading level0 col8" >MDD</th>
#       <th id="T_98586_level0_col9" class="col_heading level0 col9" >ADD</th>
#       <th id="T_98586_level0_col10" class="col_heading level0 col10" >CDaR</th>
#       <th id="T_98586_level0_col11" class="col_heading level0 col11" >UCI</th>
#       <th id="T_98586_level0_col12" class="col_heading level0 col12" >EDaR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98586_level0_row0" class="row_heading level0 row0" >TIMS3.SA</th>
#       <td id="T_98586_row0_col0" class="data row0 col0" >33.25%</td>
#       <td id="T_98586_row0_col1" class="data row0 col1" >31.17%</td>
#       <td id="T_98586_row0_col2" class="data row0 col2" >37.55%</td>
#       <td id="T_98586_row0_col3" class="data row0 col3" >33.19%</td>
#       <td id="T_98586_row0_col4" class="data row0 col4" >39.05%</td>
#       <td id="T_98586_row0_col5" class="data row0 col5" >40.74%</td>
#       <td id="T_98586_row0_col6" class="data row0 col6" >39.56%</td>
#       <td id="T_98586_row0_col7" class="data row0 col7" >29.11%</td>
#       <td id="T_98586_row0_col8" class="data row0 col8" >88.76%</td>
#       <td id="T_98586_row0_col9" class="data row0 col9" >83.68%</td>
#       <td id="T_98586_row0_col10" class="data row0 col10" >72.11%</td>
#       <td id="T_98586_row0_col11" class="data row0 col11" >83.68%</td>
#       <td id="T_98586_row0_col12" class="data row0 col12" >77.63%</td>
#     </tr>
#     <tr>
#       <th id="T_98586_level0_row1" class="row_heading level0 row1" >VIVT3.SA</th>
#       <td id="T_98586_row1_col0" class="data row1 col0" >66.75%</td>
#       <td id="T_98586_row1_col1" class="data row1 col1" >68.83%</td>
#       <td id="T_98586_row1_col2" class="data row1 col2" >62.45%</td>
#       <td id="T_98586_row1_col3" class="data row1 col3" >66.81%</td>
#       <td id="T_98586_row1_col4" class="data row1 col4" >60.95%</td>
#       <td id="T_98586_row1_col5" class="data row1 col5" >59.26%</td>
#       <td id="T_98586_row1_col6" class="data row1 col6" >60.44%</td>
#       <td id="T_98586_row1_col7" class="data row1 col7" >70.89%</td>
#       <td id="T_98586_row1_col8" class="data row1 col8" >11.24%</td>
#       <td id="T_98586_row1_col9" class="data row1 col9" >16.32%</td>
#       <td id="T_98586_row1_col10" class="data row1 col10" >27.89%</td>
#       <td id="T_98586_row1_col11" class="data row1 col11" >16.32%</td>
#       <td id="T_98586_row1_col12" class="data row1 col12" >22.37%</td>
#     </tr>
#   </tbody>
# </table>
