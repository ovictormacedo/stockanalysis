# %%
import numpy as np
import pandas as pd
import yfinance as yf
import warnings
import json

warnings.filterwarnings("ignore")
pd.options.display.float_format = '{:.4%}'.format

params = json.loads(open('params.json', 'r').read())

# Date range
start = params["start_date"]
end = params["end_date"]

# Tickers of assets
OIL = 'Oil gas biofuels, exploration, refining etc'
TELCO = 'Telecommunications'
PULP_PAPER = 'Pulp and Paper'
ELECTRICAL = 'Electrical energy'
MINERALS = 'Minerals'

industry_asset = json.loads(open('stocks.json', 'r').read())
assets = []
for value in industry_asset[MINERALS]:
    assets.append(value)

# Downloading data
data = yf.download(assets, start = start, end = end)

data = data.loc[:,('Adj Close', slice(None))]

data.columns = assets
# Out:
# [*********************100%%**********************]  4 of 4 completed

# %%
# Calculating returns
Y = data[assets].pct_change().dropna()

display(Y.tail())
# Out:
#             VALE3.SA  GGBR3.SA  CSNA3.SA  FESA4.SA
# Date
# 2023-10-27   0.7086%   0.1033%  -0.5421%   3.4763%
# 2023-10-30   1.1434%  -0.3714%   0.3469%   0.9028%
# 2023-10-31   2.2609%   0.7249%  -0.9383%   1.2027%
# 2023-11-01   1.7857%  -3.1462%   0.9472%   1.9130%
# 2023-11-03   5.8480%   1.1890%   3.4568%   1.2514%

# %%
import riskfolio as rp

# Building the portfolio object
port = rp.Portfolio(returns=Y)

# Calculating optimal portfolio

# Select method and estimate input parameters:

method_mu='hist' # Method to estimate expected returns based on historical data.
method_cov='hist' # Method to estimate covariance matrix based on historical data.

port.assets_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

# Estimate optimal portfolio:

model='Classic' # Could be Classic (historical), BL (Black Litterman) or FM (Factor Model)
rm = 'MV' # Risk measure used, this time will be variance
obj = 'Sharpe' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = True # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
l = 0 # Risk aversion factor, only useful when obj is 'Utility'

w_sharpe = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w_sharpe.T)

# Plotting the composition of the portfolio

ax_sharpe = rp.plot_pie(w=w_sharpe, title='Sharpe Mean Variance', others=0.05, nrow=25, cmap = "tab20",
                 height=6, width=10, ax=None)
# Out:
#          VALE3.SA  GGBR3.SA  CSNA3.SA  FESA4.SA
# weights   0.0000%  72.0951%  24.3877%   3.5172%

# %%
# Plotting frontier

points = 50 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)
# display(frontier.T.tail())

# Plotting the efficient frontier

label = 'Sharpe Adjusted Return Portfolio' # Title of point
mu = port.mu # Expected returns
cov = port.cov # Covariance matrix
returns = port.returns # Returns of the assets

ax = rp.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                      rf=rf, alpha=0.05, cmap='viridis', w=w_sharpe, label=label,
                      marker='*', s=16, c='r', height=6, width=10, ax=None)

# %%
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

# %%
# Risk Measures available:
#
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

rms = ['MV', 'MAD', 'MSV', 'FLPM', 'SLPM', 'CVaR',
       'EVaR', 'WR', 'MDD', 'ADD', 'CDaR', 'UCI', 'EDaR']

w_s = pd.DataFrame([])

for i in rms:
    w = port.optimization(model=model, rm=i, obj=obj, rf=rf, l=l, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
    
w_s.columns = rms

w_s.style.format("{:.2%}").background_gradient(cmap='YlGn')
# Out:
# <style type="text/css">
# #T_e7724_row0_col0, #T_e7724_row0_col1, #T_e7724_row0_col2, #T_e7724_row0_col3, #T_e7724_row0_col4, #T_e7724_row0_col5, #T_e7724_row0_col6, #T_e7724_row0_col7, #T_e7724_row0_col8, #T_e7724_row0_col9, #T_e7724_row0_col10, #T_e7724_row0_col11, #T_e7724_row0_col12, #T_e7724_row2_col8, #T_e7724_row3_col8, #T_e7724_row3_col9, #T_e7724_row3_col10, #T_e7724_row3_col11, #T_e7724_row3_col12 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_e7724_row1_col0, #T_e7724_row1_col1, #T_e7724_row1_col2, #T_e7724_row1_col3, #T_e7724_row1_col4, #T_e7724_row1_col5, #T_e7724_row1_col6, #T_e7724_row1_col8, #T_e7724_row1_col9, #T_e7724_row1_col10, #T_e7724_row1_col11, #T_e7724_row1_col12, #T_e7724_row2_col7 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_e7724_row1_col7 {
#   background-color: #14783e;
#   color: #f1f1f1;
# }
# #T_e7724_row2_col0 {
#   background-color: #bae394;
#   color: #000000;
# }
# #T_e7724_row2_col1 {
#   background-color: #e7f6ad;
#   color: #000000;
# }
# #T_e7724_row2_col2, #T_e7724_row2_col4 {
#   background-color: #e4f4ab;
#   color: #000000;
# }
# #T_e7724_row2_col3 {
#   background-color: #e8f6ae;
#   color: #000000;
# }
# #T_e7724_row2_col5 {
#   background-color: #f8fcbd;
#   color: #000000;
# }
# #T_e7724_row2_col6 {
#   background-color: #1e8041;
#   color: #f1f1f1;
# }
# #T_e7724_row2_col9 {
#   background-color: #3aa257;
#   color: #f1f1f1;
# }
# #T_e7724_row2_col10 {
#   background-color: #f9fdc7;
#   color: #000000;
# }
# #T_e7724_row2_col11 {
#   background-color: #6fc174;
#   color: #000000;
# }
# #T_e7724_row2_col12, #T_e7724_row3_col1 {
#   background-color: #fdfedb;
#   color: #000000;
# }
# #T_e7724_row3_col0 {
#   background-color: #fcfed4;
#   color: #000000;
# }
# #T_e7724_row3_col2 {
#   background-color: #f8fdc1;
#   color: #000000;
# }
# #T_e7724_row3_col3 {
#   background-color: #feffe1;
#   color: #000000;
# }
# #T_e7724_row3_col4 {
#   background-color: #f8fcbe;
#   color: #000000;
# }
# #T_e7724_row3_col5 {
#   background-color: #f5fbb8;
#   color: #000000;
# }
# #T_e7724_row3_col6 {
#   background-color: #7fc97c;
#   color: #000000;
# }
# #T_e7724_row3_col7 {
#   background-color: #0e743c;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e7724">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7724_level0_col0" class="col_heading level0 col0" >MV</th>
#       <th id="T_e7724_level0_col1" class="col_heading level0 col1" >MAD</th>
#       <th id="T_e7724_level0_col2" class="col_heading level0 col2" >MSV</th>
#       <th id="T_e7724_level0_col3" class="col_heading level0 col3" >FLPM</th>
#       <th id="T_e7724_level0_col4" class="col_heading level0 col4" >SLPM</th>
#       <th id="T_e7724_level0_col5" class="col_heading level0 col5" >CVaR</th>
#       <th id="T_e7724_level0_col6" class="col_heading level0 col6" >EVaR</th>
#       <th id="T_e7724_level0_col7" class="col_heading level0 col7" >WR</th>
#       <th id="T_e7724_level0_col8" class="col_heading level0 col8" >MDD</th>
#       <th id="T_e7724_level0_col9" class="col_heading level0 col9" >ADD</th>
#       <th id="T_e7724_level0_col10" class="col_heading level0 col10" >CDaR</th>
#       <th id="T_e7724_level0_col11" class="col_heading level0 col11" >UCI</th>
#       <th id="T_e7724_level0_col12" class="col_heading level0 col12" >EDaR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7724_level0_row0" class="row_heading level0 row0" >VALE3.SA</th>
#       <td id="T_e7724_row0_col0" class="data row0 col0" >0.00%</td>
#       <td id="T_e7724_row0_col1" class="data row0 col1" >0.00%</td>
#       <td id="T_e7724_row0_col2" class="data row0 col2" >0.00%</td>
#       <td id="T_e7724_row0_col3" class="data row0 col3" >0.00%</td>
#       <td id="T_e7724_row0_col4" class="data row0 col4" >0.00%</td>
#       <td id="T_e7724_row0_col5" class="data row0 col5" >0.00%</td>
#       <td id="T_e7724_row0_col6" class="data row0 col6" >0.00%</td>
#       <td id="T_e7724_row0_col7" class="data row0 col7" >0.00%</td>
#       <td id="T_e7724_row0_col8" class="data row0 col8" >0.00%</td>
#       <td id="T_e7724_row0_col9" class="data row0 col9" >0.00%</td>
#       <td id="T_e7724_row0_col10" class="data row0 col10" >0.00%</td>
#       <td id="T_e7724_row0_col11" class="data row0 col11" >0.00%</td>
#       <td id="T_e7724_row0_col12" class="data row0 col12" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_e7724_level0_row1" class="row_heading level0 row1" >GGBR3.SA</th>
#       <td id="T_e7724_row1_col0" class="data row1 col0" >72.10%</td>
#       <td id="T_e7724_row1_col1" class="data row1 col1" >81.69%</td>
#       <td id="T_e7724_row1_col2" class="data row1 col2" >76.46%</td>
#       <td id="T_e7724_row1_col3" class="data row1 col3" >82.94%</td>
#       <td id="T_e7724_row1_col4" class="data row1 col4" >76.01%</td>
#       <td id="T_e7724_row1_col5" class="data row1 col5" >80.13%</td>
#       <td id="T_e7724_row1_col6" class="data row1 col6" >44.44%</td>
#       <td id="T_e7724_row1_col7" class="data row1 col7" >30.61%</td>
#       <td id="T_e7724_row1_col8" class="data row1 col8" >100.00%</td>
#       <td id="T_e7724_row1_col9" class="data row1 col9" >60.39%</td>
#       <td id="T_e7724_row1_col10" class="data row1 col10" >92.04%</td>
#       <td id="T_e7724_row1_col11" class="data row1 col11" >65.81%</td>
#       <td id="T_e7724_row1_col12" class="data row1 col12" >97.27%</td>
#     </tr>
#     <tr>
#       <th id="T_e7724_level0_row2" class="row_heading level0 row2" >CSNA3.SA</th>
#       <td id="T_e7724_row2_col0" class="data row2 col0" >24.39%</td>
#       <td id="T_e7724_row2_col1" class="data row2 col1" >15.80%</td>
#       <td id="T_e7724_row2_col2" class="data row2 col2" >15.70%</td>
#       <td id="T_e7724_row2_col3" class="data row2 col3" >15.80%</td>
#       <td id="T_e7724_row2_col4" class="data row2 col4" >15.60%</td>
#       <td id="T_e7724_row2_col5" class="data row2 col5" >9.20%</td>
#       <td id="T_e7724_row2_col6" class="data row2 col6" >34.11%</td>
#       <td id="T_e7724_row2_col7" class="data row2 col7" >38.07%</td>
#       <td id="T_e7724_row2_col8" class="data row2 col8" >0.00%</td>
#       <td id="T_e7724_row2_col9" class="data row2 col9" >39.61%</td>
#       <td id="T_e7724_row2_col10" class="data row2 col10" >7.96%</td>
#       <td id="T_e7724_row2_col11" class="data row2 col11" >34.19%</td>
#       <td id="T_e7724_row2_col12" class="data row2 col12" >2.73%</td>
#     </tr>
#     <tr>
#       <th id="T_e7724_level0_row3" class="row_heading level0 row3" >FESA4.SA</th>
#       <td id="T_e7724_row3_col0" class="data row3 col0" >3.52%</td>
#       <td id="T_e7724_row3_col1" class="data row3 col1" >2.51%</td>
#       <td id="T_e7724_row3_col2" class="data row3 col2" >7.83%</td>
#       <td id="T_e7724_row3_col3" class="data row3 col3" >1.26%</td>
#       <td id="T_e7724_row3_col4" class="data row3 col4" >8.39%</td>
#       <td id="T_e7724_row3_col5" class="data row3 col5" >10.68%</td>
#       <td id="T_e7724_row3_col6" class="data row3 col6" >21.46%</td>
#       <td id="T_e7724_row3_col7" class="data row3 col7" >31.33%</td>
#       <td id="T_e7724_row3_col8" class="data row3 col8" >0.00%</td>
#       <td id="T_e7724_row3_col9" class="data row3 col9" >0.00%</td>
#       <td id="T_e7724_row3_col10" class="data row3 col10" >0.00%</td>
#       <td id="T_e7724_row3_col11" class="data row3 col11" >0.00%</td>
#       <td id="T_e7724_row3_col12" class="data row3 col12" >0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
import riskfolio as rp

# Building the portfolio object
port = rp.Portfolio(returns=Y)

# Calculating optimal portfolio

# Select method and estimate input parameters:

method_mu='hist' # Method to estimate expected returns based on historical data.
method_cov='hist' # Method to estimate covariance matrix based on historical data.

port.assets_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

# Estimate optimal portfolio:

model='Classic' # Could be Classic (historical), BL (Black Litterman) or FM (Factor Model)
rm = 'MV' # Risk measure used, this time will be variance
obj = 'MinRisk' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = True # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
l = 0 # Risk aversion factor, only useful when obj is 'Utility'

w_min_risk = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w_min_risk.T)


# Plotting the composition of the portfolio

ax_min_risk = rp.plot_pie(w=w_min_risk, title='Min risk Variance', others=0.05, nrow=25, cmap = "tab20",
                 height=6, width=10, ax=None)
# Out:
#          VALE3.SA  GGBR3.SA  CSNA3.SA  FESA4.SA
# weights   0.0000%  18.6178%  44.8001%  36.5821%

# %%
# Plotting frontier

points = 50 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)
# display(frontier.T.tail())

# Plotting the efficient frontier

label = 'Min Risk Adjusted Return Portfolio' # Title of point
mu = port.mu # Expected returns
cov = port.cov # Covariance matrix
returns = port.returns # Returns of the assets

ax = rp.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                      rf=rf, alpha=0.05, cmap='viridis', w=w_min_risk, label=label,
                      marker='*', s=16, c='r', height=6, width=10, ax=None)

# %%
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

# %%
# Risk Measures available:
#
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

rms = ['MV', 'MAD', 'MSV', 'FLPM', 'SLPM', 'CVaR',
       'EVaR', 'WR', 'MDD', 'ADD', 'CDaR', 'UCI', 'EDaR']

w_s = pd.DataFrame([])

for i in rms:
    w = port.optimization(model=model, rm=i, obj=obj, rf=rf, l=l, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
    
w_s.columns = rms

w_s.style.format("{:.2%}").background_gradient(cmap='YlGn')
# Out:
# <style type="text/css">
# #T_00031_row0_col0, #T_00031_row0_col1, #T_00031_row0_col2, #T_00031_row0_col3, #T_00031_row0_col4, #T_00031_row0_col5, #T_00031_row0_col6, #T_00031_row0_col7, #T_00031_row0_col8, #T_00031_row0_col9, #T_00031_row0_col10, #T_00031_row0_col11, #T_00031_row0_col12, #T_00031_row3_col9, #T_00031_row3_col11 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_00031_row1_col0, #T_00031_row1_col1 {
#   background-color: #9cd687;
#   color: #000000;
# }
# #T_00031_row1_col2 {
#   background-color: #a9db8c;
#   color: #000000;
# }
# #T_00031_row1_col3 {
#   background-color: #6dc073;
#   color: #000000;
# }
# #T_00031_row1_col4 {
#   background-color: #8bce81;
#   color: #000000;
# }
# #T_00031_row1_col5, #T_00031_row3_col12 {
#   background-color: #8dcf81;
#   color: #000000;
# }
# #T_00031_row1_col6 {
#   background-color: #5ab76a;
#   color: #f1f1f1;
# }
# #T_00031_row1_col7 {
#   background-color: #2c8f4b;
#   color: #f1f1f1;
# }
# #T_00031_row1_col8 {
#   background-color: #92d183;
#   color: #000000;
# }
# #T_00031_row1_col9, #T_00031_row1_col11, #T_00031_row2_col1 {
#   background-color: #00492b;
#   color: #f1f1f1;
# }
# #T_00031_row1_col10, #T_00031_row2_col4 {
#   background-color: #005c32;
#   color: #f1f1f1;
# }
# #T_00031_row1_col12 {
#   background-color: #4ab062;
#   color: #f1f1f1;
# }
# #T_00031_row2_col0, #T_00031_row2_col6, #T_00031_row2_col7, #T_00031_row2_col8, #T_00031_row2_col9, #T_00031_row2_col10, #T_00031_row2_col11, #T_00031_row2_col12, #T_00031_row3_col1, #T_00031_row3_col2, #T_00031_row3_col3, #T_00031_row3_col4, #T_00031_row3_col5 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_00031_row2_col2 {
#   background-color: #005e33;
#   color: #f1f1f1;
# }
# #T_00031_row2_col3 {
#   background-color: #004e2d;
#   color: #f1f1f1;
# }
# #T_00031_row2_col5 {
#   background-color: #39a056;
#   color: #f1f1f1;
# }
# #T_00031_row3_col0 {
#   background-color: #10743c;
#   color: #f1f1f1;
# }
# #T_00031_row3_col6 {
#   background-color: #369d54;
#   color: #f1f1f1;
# }
# #T_00031_row3_col7 {
#   background-color: #228343;
#   color: #f1f1f1;
# }
# #T_00031_row3_col8 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_00031_row3_col10 {
#   background-color: #c5e89a;
#   color: #000000;
# }
# </style>
# <table id="T_00031">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00031_level0_col0" class="col_heading level0 col0" >MV</th>
#       <th id="T_00031_level0_col1" class="col_heading level0 col1" >MAD</th>
#       <th id="T_00031_level0_col2" class="col_heading level0 col2" >MSV</th>
#       <th id="T_00031_level0_col3" class="col_heading level0 col3" >FLPM</th>
#       <th id="T_00031_level0_col4" class="col_heading level0 col4" >SLPM</th>
#       <th id="T_00031_level0_col5" class="col_heading level0 col5" >CVaR</th>
#       <th id="T_00031_level0_col6" class="col_heading level0 col6" >EVaR</th>
#       <th id="T_00031_level0_col7" class="col_heading level0 col7" >WR</th>
#       <th id="T_00031_level0_col8" class="col_heading level0 col8" >MDD</th>
#       <th id="T_00031_level0_col9" class="col_heading level0 col9" >ADD</th>
#       <th id="T_00031_level0_col10" class="col_heading level0 col10" >CDaR</th>
#       <th id="T_00031_level0_col11" class="col_heading level0 col11" >UCI</th>
#       <th id="T_00031_level0_col12" class="col_heading level0 col12" >EDaR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00031_level0_row0" class="row_heading level0 row0" >VALE3.SA</th>
#       <td id="T_00031_row0_col0" class="data row0 col0" >0.00%</td>
#       <td id="T_00031_row0_col1" class="data row0 col1" >0.00%</td>
#       <td id="T_00031_row0_col2" class="data row0 col2" >0.00%</td>
#       <td id="T_00031_row0_col3" class="data row0 col3" >0.00%</td>
#       <td id="T_00031_row0_col4" class="data row0 col4" >0.00%</td>
#       <td id="T_00031_row0_col5" class="data row0 col5" >0.00%</td>
#       <td id="T_00031_row0_col6" class="data row0 col6" >0.00%</td>
#       <td id="T_00031_row0_col7" class="data row0 col7" >0.00%</td>
#       <td id="T_00031_row0_col8" class="data row0 col8" >0.00%</td>
#       <td id="T_00031_row0_col9" class="data row0 col9" >0.00%</td>
#       <td id="T_00031_row0_col10" class="data row0 col10" >0.00%</td>
#       <td id="T_00031_row0_col11" class="data row0 col11" >0.00%</td>
#       <td id="T_00031_row0_col12" class="data row0 col12" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_00031_level0_row1" class="row_heading level0 row1" >GGBR3.SA</th>
#       <td id="T_00031_row1_col0" class="data row1 col0" >18.62%</td>
#       <td id="T_00031_row1_col1" class="data row1 col1" >17.28%</td>
#       <td id="T_00031_row1_col2" class="data row1 col2" >16.75%</td>
#       <td id="T_00031_row1_col3" class="data row1 col3" >21.13%</td>
#       <td id="T_00031_row1_col4" class="data row1 col4" >19.16%</td>
#       <td id="T_00031_row1_col5" class="data row1 col5" >21.37%</td>
#       <td id="T_00031_row1_col6" class="data row1 col6" >25.35%</td>
#       <td id="T_00031_row1_col7" class="data row1 col7" >28.87%</td>
#       <td id="T_00031_row1_col8" class="data row1 col8" >19.05%</td>
#       <td id="T_00031_row1_col9" class="data row1 col9" >49.55%</td>
#       <td id="T_00031_row1_col10" class="data row1 col10" >41.25%</td>
#       <td id="T_00031_row1_col11" class="data row1 col11" >49.55%</td>
#       <td id="T_00031_row1_col12" class="data row1 col12" >29.43%</td>
#     </tr>
#     <tr>
#       <th id="T_00031_level0_row2" class="row_heading level0 row2" >CSNA3.SA</th>
#       <td id="T_00031_row2_col0" class="data row2 col0" >44.80%</td>
#       <td id="T_00031_row2_col1" class="data row2 col1" >41.01%</td>
#       <td id="T_00031_row2_col2" class="data row2 col2" >39.58%</td>
#       <td id="T_00031_row2_col3" class="data row2 col3" >38.78%</td>
#       <td id="T_00031_row2_col4" class="data row2 col4" >38.62%</td>
#       <td id="T_00031_row2_col5" class="data row2 col5" >31.25%</td>
#       <td id="T_00031_row2_col6" class="data row2 col6" >44.73%</td>
#       <td id="T_00031_row2_col7" class="data row2 col7" >40.60%</td>
#       <td id="T_00031_row2_col8" class="data row2 col8" >43.25%</td>
#       <td id="T_00031_row2_col9" class="data row2 col9" >50.45%</td>
#       <td id="T_00031_row2_col10" class="data row2 col10" >45.01%</td>
#       <td id="T_00031_row2_col11" class="data row2 col11" >50.45%</td>
#       <td id="T_00031_row2_col12" class="data row2 col12" >48.69%</td>
#     </tr>
#     <tr>
#       <th id="T_00031_level0_row3" class="row_heading level0 row3" >FESA4.SA</th>
#       <td id="T_00031_row3_col0" class="data row3 col0" >36.58%</td>
#       <td id="T_00031_row3_col1" class="data row3 col1" >41.71%</td>
#       <td id="T_00031_row3_col2" class="data row3 col2" >43.67%</td>
#       <td id="T_00031_row3_col3" class="data row3 col3" >40.10%</td>
#       <td id="T_00031_row3_col4" class="data row3 col4" >42.22%</td>
#       <td id="T_00031_row3_col5" class="data row3 col5" >47.38%</td>
#       <td id="T_00031_row3_col6" class="data row3 col6" >29.92%</td>
#       <td id="T_00031_row3_col7" class="data row3 col7" >30.53%</td>
#       <td id="T_00031_row3_col8" class="data row3 col8" >37.71%</td>
#       <td id="T_00031_row3_col9" class="data row3 col9" >0.00%</td>
#       <td id="T_00031_row3_col10" class="data row3 col10" >13.74%</td>
#       <td id="T_00031_row3_col11" class="data row3 col11" >0.00%</td>
#       <td id="T_00031_row3_col12" class="data row3 col12" >21.88%</td>
#     </tr>
#   </tbody>
# </table>
