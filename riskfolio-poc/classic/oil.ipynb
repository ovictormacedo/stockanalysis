# %%
import numpy as np
import pandas as pd
import yfinance as yf
import warnings
import json

warnings.filterwarnings("ignore")
pd.options.display.float_format = '{:.4%}'.format

params = json.loads(open('params.json', 'r').read())

# Date range
start = params["start_date"]
end = params["end_date"]

# Tickers of assets
OIL = 'Oil gas biofuels, exploration, refining etc'
TELCO = 'Telecommunications'
PULP_PAPER = 'Pulp and Paper'
ELECTRICAL = 'Electrical energy'
MINERALS = 'Minerals'

industry_asset = json.loads(open('stocks.json', 'r').read())
assets = []
for value in industry_asset[OIL]:
    assets.append(value)

# Downloading data
data = yf.download(assets, start = start, end = end)

data = data.loc[:,('Adj Close', slice(None))]

data.columns = assets
# Out:
# [*********************100%%**********************]  6 of 6 completed

# %%
# Calculating returns
Y = data[assets].pct_change().dropna()

display(Y.tail())
# Out:
#             CSAN3.SA  VBBR3.SA  PRIO3.SA  UGPA3.SA  ENAT3.SA  PETR3.SA
# Date
# 2023-10-27  -2.0808%  -0.4348%  -0.7224%  -0.4792%  -2.5238%  -2.9014%
# 2023-10-30  -2.1875%  -2.0742%  -0.8056%  -2.9516%  -0.3908%  -1.5936%
# 2023-10-31   0.6390%  -2.8428%  -0.8645%   2.8904%   0.2943%   0.1518%
# 2023-11-01   5.4603%   2.8112%   1.1628%   0.7757%   3.7164%   1.8191%
# 2023-11-03   3.3715%  -2.2879%   0.8359%   0.2704%   0.6129%   1.5881%

# %%
import riskfolio as rp

# Building the portfolio object
port = rp.Portfolio(returns=Y)

# Calculating optimal portfolio

# Select method and estimate input parameters:

method_mu='hist' # Method to estimate expected returns based on historical data.
method_cov='hist' # Method to estimate covariance matrix based on historical data.

port.assets_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

# Estimate optimal portfolio:

model='Classic' # Could be Classic (historical), BL (Black Litterman) or FM (Factor Model)
rm = 'MV' # Risk measure used, this time will be variance
obj = 'Sharpe' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = True # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
l = 0 # Risk aversion factor, only useful when obj is 'Utility'

w_sharpe = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w_sharpe.T)

# Plotting the composition of the portfolio

ax_sharpe = rp.plot_pie(w=w_sharpe, title='Sharpe Mean Variance', others=0.05, nrow=25, cmap = "tab20",
                 height=6, width=10, ax=None)
# Out:
#          CSAN3.SA  VBBR3.SA  PRIO3.SA  UGPA3.SA  ENAT3.SA  PETR3.SA
# weights   0.0000%   0.0000%  53.8067%  46.1933%   0.0000%   0.0000%

# %%
# Plotting frontier

points = 50 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)
# display(frontier.T.tail())

# Plotting the efficient frontier

label = 'Sharpe Adjusted Return Portfolio' # Title of point
mu = port.mu # Expected returns
cov = port.cov # Covariance matrix
returns = port.returns # Returns of the assets

ax = rp.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                      rf=rf, alpha=0.05, cmap='viridis', w=w_sharpe, label=label,
                      marker='*', s=16, c='r', height=6, width=10, ax=None)

# %%
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

# %%
# Risk Measures available:
#
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

rms = ['MV', 'MAD', 'MSV', 'FLPM', 'SLPM', 'CVaR',
       'EVaR', 'WR', 'MDD', 'ADD', 'CDaR', 'UCI', 'EDaR']

w_s = pd.DataFrame([])

for i in rms:
    w = port.optimization(model=model, rm=i, obj=obj, rf=rf, l=l, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
    
w_s.columns = rms

w_s.style.format("{:.2%}").background_gradient(cmap='YlGn')
# Out:
# <style type="text/css">
# #T_e838f_row0_col0, #T_e838f_row0_col1, #T_e838f_row0_col2, #T_e838f_row0_col3, #T_e838f_row0_col4, #T_e838f_row0_col5, #T_e838f_row0_col6, #T_e838f_row0_col7, #T_e838f_row0_col8, #T_e838f_row0_col9, #T_e838f_row0_col10, #T_e838f_row0_col11, #T_e838f_row0_col12, #T_e838f_row1_col0, #T_e838f_row1_col1, #T_e838f_row1_col2, #T_e838f_row1_col3, #T_e838f_row1_col4, #T_e838f_row1_col5, #T_e838f_row1_col6, #T_e838f_row1_col7, #T_e838f_row1_col8, #T_e838f_row1_col9, #T_e838f_row1_col10, #T_e838f_row1_col11, #T_e838f_row1_col12, #T_e838f_row4_col0, #T_e838f_row4_col1, #T_e838f_row4_col2, #T_e838f_row4_col3, #T_e838f_row4_col4, #T_e838f_row4_col5, #T_e838f_row4_col6, #T_e838f_row4_col7, #T_e838f_row4_col8, #T_e838f_row4_col9, #T_e838f_row4_col10, #T_e838f_row4_col11, #T_e838f_row4_col12, #T_e838f_row5_col0, #T_e838f_row5_col1, #T_e838f_row5_col2, #T_e838f_row5_col3, #T_e838f_row5_col4, #T_e838f_row5_col5, #T_e838f_row5_col6, #T_e838f_row5_col7, #T_e838f_row5_col8, #T_e838f_row5_col9, #T_e838f_row5_col10, #T_e838f_row5_col11, #T_e838f_row5_col12 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_e838f_row2_col0, #T_e838f_row2_col1, #T_e838f_row2_col3, #T_e838f_row2_col8, #T_e838f_row2_col10, #T_e838f_row2_col12, #T_e838f_row3_col2, #T_e838f_row3_col4, #T_e838f_row3_col5, #T_e838f_row3_col6, #T_e838f_row3_col7, #T_e838f_row3_col9, #T_e838f_row3_col11 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_e838f_row2_col2 {
#   background-color: #0a703a;
#   color: #f1f1f1;
# }
# #T_e838f_row2_col4 {
#   background-color: #0d733c;
#   color: #f1f1f1;
# }
# #T_e838f_row2_col5 {
#   background-color: #0e743c;
#   color: #f1f1f1;
# }
# #T_e838f_row2_col6 {
#   background-color: #268846;
#   color: #f1f1f1;
# }
# #T_e838f_row2_col7 {
#   background-color: #40aa5c;
#   color: #f1f1f1;
# }
# #T_e838f_row2_col9 {
#   background-color: #004629;
#   color: #f1f1f1;
# }
# #T_e838f_row2_col11 {
#   background-color: #004d2c;
#   color: #f1f1f1;
# }
# #T_e838f_row3_col0 {
#   background-color: #056c39;
#   color: #f1f1f1;
# }
# #T_e838f_row3_col1 {
#   background-color: #036b38;
#   color: #f1f1f1;
# }
# #T_e838f_row3_col3 {
#   background-color: #005b32;
#   color: #f1f1f1;
# }
# #T_e838f_row3_col8 {
#   background-color: #389f55;
#   color: #f1f1f1;
# }
# #T_e838f_row3_col10 {
#   background-color: #14783e;
#   color: #f1f1f1;
# }
# #T_e838f_row3_col12 {
#   background-color: #329850;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e838f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e838f_level0_col0" class="col_heading level0 col0" >MV</th>
#       <th id="T_e838f_level0_col1" class="col_heading level0 col1" >MAD</th>
#       <th id="T_e838f_level0_col2" class="col_heading level0 col2" >MSV</th>
#       <th id="T_e838f_level0_col3" class="col_heading level0 col3" >FLPM</th>
#       <th id="T_e838f_level0_col4" class="col_heading level0 col4" >SLPM</th>
#       <th id="T_e838f_level0_col5" class="col_heading level0 col5" >CVaR</th>
#       <th id="T_e838f_level0_col6" class="col_heading level0 col6" >EVaR</th>
#       <th id="T_e838f_level0_col7" class="col_heading level0 col7" >WR</th>
#       <th id="T_e838f_level0_col8" class="col_heading level0 col8" >MDD</th>
#       <th id="T_e838f_level0_col9" class="col_heading level0 col9" >ADD</th>
#       <th id="T_e838f_level0_col10" class="col_heading level0 col10" >CDaR</th>
#       <th id="T_e838f_level0_col11" class="col_heading level0 col11" >UCI</th>
#       <th id="T_e838f_level0_col12" class="col_heading level0 col12" >EDaR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e838f_level0_row0" class="row_heading level0 row0" >CSAN3.SA</th>
#       <td id="T_e838f_row0_col0" class="data row0 col0" >0.00%</td>
#       <td id="T_e838f_row0_col1" class="data row0 col1" >0.00%</td>
#       <td id="T_e838f_row0_col2" class="data row0 col2" >0.00%</td>
#       <td id="T_e838f_row0_col3" class="data row0 col3" >0.00%</td>
#       <td id="T_e838f_row0_col4" class="data row0 col4" >0.00%</td>
#       <td id="T_e838f_row0_col5" class="data row0 col5" >0.00%</td>
#       <td id="T_e838f_row0_col6" class="data row0 col6" >0.00%</td>
#       <td id="T_e838f_row0_col7" class="data row0 col7" >0.00%</td>
#       <td id="T_e838f_row0_col8" class="data row0 col8" >0.00%</td>
#       <td id="T_e838f_row0_col9" class="data row0 col9" >0.00%</td>
#       <td id="T_e838f_row0_col10" class="data row0 col10" >0.00%</td>
#       <td id="T_e838f_row0_col11" class="data row0 col11" >0.00%</td>
#       <td id="T_e838f_row0_col12" class="data row0 col12" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_e838f_level0_row1" class="row_heading level0 row1" >VBBR3.SA</th>
#       <td id="T_e838f_row1_col0" class="data row1 col0" >0.00%</td>
#       <td id="T_e838f_row1_col1" class="data row1 col1" >0.00%</td>
#       <td id="T_e838f_row1_col2" class="data row1 col2" >0.00%</td>
#       <td id="T_e838f_row1_col3" class="data row1 col3" >0.00%</td>
#       <td id="T_e838f_row1_col4" class="data row1 col4" >0.00%</td>
#       <td id="T_e838f_row1_col5" class="data row1 col5" >0.00%</td>
#       <td id="T_e838f_row1_col6" class="data row1 col6" >0.00%</td>
#       <td id="T_e838f_row1_col7" class="data row1 col7" >0.00%</td>
#       <td id="T_e838f_row1_col8" class="data row1 col8" >0.00%</td>
#       <td id="T_e838f_row1_col9" class="data row1 col9" >0.00%</td>
#       <td id="T_e838f_row1_col10" class="data row1 col10" >0.00%</td>
#       <td id="T_e838f_row1_col11" class="data row1 col11" >0.00%</td>
#       <td id="T_e838f_row1_col12" class="data row1 col12" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_e838f_level0_row2" class="row_heading level0 row2" >PRIO3.SA</th>
#       <td id="T_e838f_row2_col0" class="data row2 col0" >53.81%</td>
#       <td id="T_e838f_row2_col1" class="data row2 col1" >53.78%</td>
#       <td id="T_e838f_row2_col2" class="data row2 col2" >45.61%</td>
#       <td id="T_e838f_row2_col3" class="data row2 col3" >52.07%</td>
#       <td id="T_e838f_row2_col4" class="data row2 col4" >45.19%</td>
#       <td id="T_e838f_row2_col5" class="data row2 col5" >45.15%</td>
#       <td id="T_e838f_row2_col6" class="data row2 col6" >42.41%</td>
#       <td id="T_e838f_row2_col7" class="data row2 col7" >38.54%</td>
#       <td id="T_e838f_row2_col8" class="data row2 col8" >60.17%</td>
#       <td id="T_e838f_row2_col9" class="data row2 col9" >49.83%</td>
#       <td id="T_e838f_row2_col10" class="data row2 col10" >55.52%</td>
#       <td id="T_e838f_row2_col11" class="data row2 col11" >49.30%</td>
#       <td id="T_e838f_row2_col12" class="data row2 col12" >59.30%</td>
#     </tr>
#     <tr>
#       <th id="T_e838f_level0_row3" class="row_heading level0 row3" >UGPA3.SA</th>
#       <td id="T_e838f_row3_col0" class="data row3 col0" >46.19%</td>
#       <td id="T_e838f_row3_col1" class="data row3 col1" >46.22%</td>
#       <td id="T_e838f_row3_col2" class="data row3 col2" >54.39%</td>
#       <td id="T_e838f_row3_col3" class="data row3 col3" >47.93%</td>
#       <td id="T_e838f_row3_col4" class="data row3 col4" >54.81%</td>
#       <td id="T_e838f_row3_col5" class="data row3 col5" >54.85%</td>
#       <td id="T_e838f_row3_col6" class="data row3 col6" >57.59%</td>
#       <td id="T_e838f_row3_col7" class="data row3 col7" >61.46%</td>
#       <td id="T_e838f_row3_col8" class="data row3 col8" >39.83%</td>
#       <td id="T_e838f_row3_col9" class="data row3 col9" >50.17%</td>
#       <td id="T_e838f_row3_col10" class="data row3 col10" >44.48%</td>
#       <td id="T_e838f_row3_col11" class="data row3 col11" >50.70%</td>
#       <td id="T_e838f_row3_col12" class="data row3 col12" >40.70%</td>
#     </tr>
#     <tr>
#       <th id="T_e838f_level0_row4" class="row_heading level0 row4" >ENAT3.SA</th>
#       <td id="T_e838f_row4_col0" class="data row4 col0" >0.00%</td>
#       <td id="T_e838f_row4_col1" class="data row4 col1" >0.00%</td>
#       <td id="T_e838f_row4_col2" class="data row4 col2" >0.00%</td>
#       <td id="T_e838f_row4_col3" class="data row4 col3" >0.00%</td>
#       <td id="T_e838f_row4_col4" class="data row4 col4" >0.00%</td>
#       <td id="T_e838f_row4_col5" class="data row4 col5" >0.00%</td>
#       <td id="T_e838f_ro

# %%
import riskfolio as rp

# Building the portfolio object
port = rp.Portfolio(returns=Y)

# Calculating optimal portfolio

# Select method and estimate input parameters:

method_mu='hist' # Method to estimate expected returns based on historical data.
method_cov='hist' # Method to estimate covariance matrix based on historical data.

port.assets_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

# Estimate optimal portfolio:

model='Classic' # Could be Classic (historical), BL (Black Litterman) or FM (Factor Model)
rm = 'MV' # Risk measure used, this time will be variance
obj = 'MinRisk' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = True # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
l = 0 # Risk aversion factor, only useful when obj is 'Utility'

w_min_risk = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w_min_risk.T)


# Plotting the composition of the portfolio

ax_min_risk = rp.plot_pie(w=w_min_risk, title='Min risk Variance', others=0.05, nrow=25, cmap = "tab20",
                 height=6, width=10, ax=None)
# Out:
#          CSAN3.SA  VBBR3.SA  PRIO3.SA  UGPA3.SA  ENAT3.SA  PETR3.SA
# weights  25.4466%  14.1542%  18.7610%   8.3283%   4.6275%  28.6824%

# %%
# Plotting frontier

points = 50 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)
# display(frontier.T.tail())

# Plotting the efficient frontier

label = 'Max Risk Adjusted Return Portfolio' # Title of point
mu = port.mu # Expected returns
cov = port.cov # Covariance matrix
returns = port.returns # Returns of the assets

ax = rp.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                      rf=rf, alpha=0.05, cmap='viridis', w=w_min_risk, label=label,
                      marker='*', s=16, c='r', height=6, width=10, ax=None)

# %%
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

# %%
# Risk Measures available:
#
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

rms = ['MV', 'MAD', 'MSV', 'FLPM', 'SLPM', 'CVaR',
       'EVaR', 'WR', 'MDD', 'ADD', 'CDaR', 'UCI', 'EDaR']

w_s = pd.DataFrame([])

for i in rms:
    w = port.optimization(model=model, rm=i, obj=obj, rf=rf, l=l, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
    
w_s.columns = rms

w_s.style.format("{:.2%}").background_gradient(cmap='YlGn')
# Out:
# <style type="text/css">
# #T_89b37_row0_col0 {
#   background-color: #026a38;
#   color: #f1f1f1;
# }
# #T_89b37_row0_col1 {
#   background-color: #005830;
#   color: #f1f1f1;
# }
# #T_89b37_row0_col2, #T_89b37_row0_col4, #T_89b37_row0_col5, #T_89b37_row0_col6, #T_89b37_row0_col10, #T_89b37_row0_col11, #T_89b37_row2_col3, #T_89b37_row2_col8, #T_89b37_row2_col9, #T_89b37_row2_col12, #T_89b37_row5_col0, #T_89b37_row5_col1, #T_89b37_row5_col7 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_89b37_row0_col3, #T_89b37_row4_col10 {
#   background-color: #389f55;
#   color: #f1f1f1;
# }
# #T_89b37_row0_col7 {
#   background-color: #a2d88a;
#   color: #000000;
# }
# #T_89b37_row0_col8 {
#   background-color: #1a7d40;
#   color: #f1f1f1;
# }
# #T_89b37_row0_col9 {
#   background-color: #005530;
#   color: #f1f1f1;
# }
# #T_89b37_row0_col12, #T_89b37_row5_col4 {
#   background-color: #005d33;
#   color: #f1f1f1;
# }
# #T_89b37_row1_col0 {
#   background-color: #a4d98a;
#   color: #000000;
# }
# #T_89b37_row1_col1 {
#   background-color: #cbea9c;
#   color: #000000;
# }
# #T_89b37_row1_col2 {
#   background-color: #b1df90;
#   color: #000000;
# }
# #T_89b37_row1_col3 {
#   background-color: #c5e89a;
#   color: #000000;
# }
# #T_89b37_row1_col4 {
#   background-color: #a1d889;
#   color: #000000;
# }
# #T_89b37_row1_col5 {
#   background-color: #4eb163;
#   color: #f1f1f1;
# }
# #T_89b37_row1_col6 {
#   background-color: #8bce81;
#   color: #000000;
# }
# #T_89b37_row1_col7 {
#   background-color: #7cc87b;
#   color: #000000;
# }
# #T_89b37_row1_col8, #T_89b37_row1_col9, #T_89b37_row1_col10, #T_89b37_row1_col11, #T_89b37_row1_col12, #T_89b37_row2_col6, #T_89b37_row2_col7, #T_89b37_row4_col0, #T_89b37_row4_col1, #T_89b37_row4_col2, #T_89b37_row4_col3, #T_89b37_row4_col4, #T_89b37_row4_col5, #T_89b37_row5_col9, #T_89b37_row5_col10, #T_89b37_row5_col12 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_89b37_row2_col0 {
#   background-color: #51b365;
#   color: #f1f1f1;
# }
# #T_89b37_row2_col1 {
#   background-color: #1c7e40;
#   color: #f1f1f1;
# }
# #T_89b37_row2_col2, #T_89b37_row4_col6 {
#   background-color: #9fd788;
#   color: #000000;
# }
# #T_89b37_row2_col4 {
#   background-color: #45ad5f;
#   color: #f1f1f1;
# }
# #T_89b37_row2_col5 {
#   background-color: #eef9b3;
#   color: #000000;
# }
# #T_89b37_row2_col10 {
#   background-color: #13773d;
#   color: #f1f1f1;
# }
# #T_89b37_row2_col11 {
#   background-color: #004a2b;
#   color: #f1f1f1;
# }
# #T_89b37_row3_col0, #T_89b37_row3_col7 {
#   background-color: #f0f9b4;
#   color: #000000;
# }
# #T_89b37_row3_col1 {
#   background-color: #f8fcbe;
#   color: #000000;
# }
# #T_89b37_row3_col2 {
#   background-color: #f7fcbc;
#   color: #000000;
# }
# #T_89b37_row3_col3 {
#   background-color: #a9db8c;
#   color: #000000;
# }
# #T_89b37_row3_col4 {
#   background-color: #bae394;
#   color: #000000;
# }
# #T_89b37_row3_col5 {
#   background-color: #f5fbb8;
#   color: #000000;
# }
# #T_89b37_row3_col6 {
#   background-color: #ebf7b0;
#   color: #000000;
# }
# #T_89b37_row3_col8 {
#   background-color: #ddf1a6;
#   color: #000000;
# }
# #T_89b37_row3_col9 {
#   background-color: #00492b;
#   color: #f1f1f1;
# }
# #T_89b37_row3_col10 {
#   background-color: #7ec97b;
#   color: #000000;
# }
# #T_89b37_row3_col11 {
#   background-color: #1d7f41;
#   color: #f1f1f1;
# }
# #T_89b37_row3_col12 {
#   background-color: #b3e091;
#   color: #000000;
# }
# #T_89b37_row4_col7 {
#   background-color: #3ba358;
#   color: #f1f1f1;
# }
# #T_89b37_row4_col8 {
#   background-color: #3fa85b;
#   color: #f1f1f1;
# }
# #T_89b37_row4_col9, #T_89b37_row5_col6 {
#   background-color: #379e54;
#   color: #f1f1f1;
# }
# #T_89b37_row4_col11 {
#   background-color: #77c679;
#   color: #000000;
# }
# #T_89b37_row4_col12 {
#   background-color: #197c40;
#   color: #f1f1f1;
# }
# #T_89b37_row5_col2 {
#   background-color: #096f3a;
#   color: #f1f1f1;
# }
# #T_89b37_row5_col3 {
#   background-color: #006234;
#   color: #f1f1f1;
# }
# #T_89b37_row5_col5 {
#   background-color: #89ce80;
#   color: #000000;
# }
# #T_89b37_row5_col8 {
#   background-color: #fbfdcf;
#   color: #000000;
# }
# #T_89b37_row5_col11 {
#   background-color: #feffe2;
#   color: #000000;
# }
# </style>
# <table id="T_89b37">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_89b37_level0_col0" class="col_heading level0 col0" >MV</th>
#       <th id="T_89b37_level0_col1" class="col_heading level0 col1" >MAD</th>
#       <th id="T_89b37_level0_col2" class="col_heading level0 col2" >MSV</th>
#       <th id="T_89b37_level0_col3" class="col_heading level0 col3" >FLPM</th>
#       <th id="T_89b37_level0_col4" class="col_heading level0 col4" >SLPM</th>
#       <th id="T_89b37_level0_col5" class="col_heading level0 col5" >CVaR</th>
#       <th id="T_89b37_level0_col6" class="col_heading level0 col6" >EVaR</th>
#       <th id="T_89b37_level0_col7" class="col_heading level0 col7" >WR</th>
#       <th id="T_89b37_level0_col8" class="col_heading level0 col8" >MDD</th>
#       <th id="T_89b37_level0_col9" class="col_heading level0 col9" >ADD</th>
#       <th id="T_89b37_level0_col10" class="col_heading level0 col10" >CDaR</th>
#       <th id="T_89b37_level0_col11" class="col_heading level0 col11" >UCI</th>
#       <th id="T_89b37_level0_col12" class="col_heading level0 col12" >EDaR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89b37_level0_row0" class="row_heading level0 row0" >CSAN3.SA</th>
#       <td id="T_89b37_row0_col0" class="data row0 col0" >25.45%</td>
#       <td id="T_89b37_row0_col1" class="data row0 col1" >25.49%</td>
#       <td id="T_89b37_row0_col2" class="data row0 col2" >32.08%</td>
#       <td id="T_89b37_row0_col3" class="data row0 col3" >19.58%</td>
#       <td id="T_89b37_row0_col4" class="data row0 col4" >28.21%</td>
#       <td id="T_89b37_row0_col5" class="data row0 col5" >31.02%</td>
#       <td id="T_89b37_row0_col6" class="data row0 col6" >36.88%</td>
#       <td id="T_89b37_row0_col7" class="data row0 col7" >14.85%</td>
#       <td id="T_89b37_row0_col8" class="data row0 col8" >28.70%</td>
#       <td id="T_89b37_row0_col9" class="data row0 col9" >26.19%</td>
#       <td id="T_89b37_row0_col10" class="data row0 col10" >33.84%</td>
#       <td id="T_89b37_row0_col11" class="data row0 col11" >30.67%</td>
#       <td id="T_89b37_row0_col12" class="data row0 col12" >29.89%</td>
#     </tr>
#     <tr>
#       <th id="T_89b37_level0_row1" class="row_heading level0 row1" >VBBR3.SA</th>
#       <td id="T_89b37_row1_col0" class="data row1 col0" >14.15%</td>
#       <td id="T_89b37_row1_col1" class="data row1 col1" >11.80%</td>
#       <td id="T_89b37_row1_col2" class="data row1 col2" >14.14%</td>
#       <td id="T_89b37_row1_col3" class="data row1 col3" >10.92%</td>
#       <td id="T_89b37_row1_col4" class="data row1 col4" >13.08%</td>
#       <td id="T_89b37_row1_col5" class="data row1 col5" >21.46%</td>
#       <td id="T_89b37_row1_col6" class="data row1 col6" >16.83%</td>
#       <td id="T_89b37_row1_col7" class="data row1 col7" >18.24%</td>
#       <td id="T_89b37_row1_col8" class="data row1 col8" >0.00%</td>
#       <td id="T_89b37_row1_col9" class="data row1 col9" >0.00%</td>
#       <td id="T_89b37_row1_col10" class="data row1 col10" >0.00%</td>
#       <td id="T_89b37_row1_col11" class="data row1 col11" >0.00%</td>
#       <td id="T_89b37_row1_col12" class="data row1 col12" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_89b37_level0_row2" class="row_heading level0 row2" >PRIO3.SA</th>
#       <td id="T_89b37_row2_col0" class="data row2 col0" >18.76%</td>
#       <td id="T_89b37_row2_col1" class="data row2 col1" >22.21%</td>
#       <td id="T_89b37_row2_col2" class="data row2 col2" >15.27%</td>
#       <td id="T_89b37_row2_col3" class="data row2 col3" >27.85%</td>
#       <td id="T_89b37_row2_col4" class="data row2 col4" >18.43%</td>
#       <td id="T_89b37_row2_col5" class="data row2 col5" >11.26%</td>
#       <td id="T_89b37_row2_col6" class="data row2 col6" >0.00%</td>
#       <td id="T_89b37_row2_col7" class="data row2 col7" >0.00%</td>
#       <td id="T_89b37_row2_col8" class="data row2 col8" >36.82%</td>
#       <td id="T_89b37_row2_col9" class="data row2 col9" >27.87%</td>
#       <td id="T_89b37_row2_col10" class="data row2 col10" >27.24%</td>
#       <td id="T_89b37_row2_col11" class="data row2 col11" >29.96%</td>
#       <td id="T_89b37_row2_col12" class
