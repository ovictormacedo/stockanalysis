# %%
import numpy as np
import pandas as pd
import yfinance as yf
import warnings
import json

warnings.filterwarnings("ignore")
pd.options.display.float_format = '{:.4%}'.format

params = json.loads(open('params.json', 'r').read())

# Date range
start = params["start_date"]
end = params["end_date"]

# Tickers of assets
OIL = 'Oil gas biofuels, exploration, refining etc'
TELCO = 'Telecommunications'
PULP_PAPER = 'Pulp and Paper'
ELECTRICAL = 'Electrical energy'
MINERALS = 'Minerals'

industry_asset = json.loads(open('stocks.json', 'r').read())
assets = []
for value in industry_asset[PULP_PAPER]:
    assets.append(value)

# Downloading data
data = yf.download(assets, start = start, end = end)

data = data.loc[:,('Adj Close', slice(None))]

data.columns = assets
# Out:
# [*********************100%%**********************]  2 of 2 completed

# %%
# Calculating returns
Y = data[assets].pct_change().dropna()

display(Y.tail())
# Out:
#             SUZB3.SA  KLBN11.SA
# Date
# 2023-10-27  -0.9009%   -1.4988%
# 2023-10-30  -0.9713%   -0.5200%
# 2023-10-31  -0.4651%   -0.1549%
# 2023-11-01   1.1682%   -0.2327%
# 2023-11-03   0.8776%   -0.5637%

# %%
import riskfolio as rp

# Building the portfolio object
port = rp.Portfolio(returns=Y)

# Calculating optimal portfolio

# Select method and estimate input parameters:

method_mu='hist' # Method to estimate expected returns based on historical data.
method_cov='hist' # Method to estimate covariance matrix based on historical data.

port.assets_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

# Estimate optimal portfolio:

model='Classic' # Could be Classic (historical), BL (Black Litterman) or FM (Factor Model)
rm = 'MV' # Risk measure used, this time will be variance
obj = 'Sharpe' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = True # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
l = 0 # Risk aversion factor, only useful when obj is 'Utility'

w_sharpe = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w_sharpe.T)

# Plotting the composition of the portfolio

ax_sharpe = rp.plot_pie(w=w_sharpe, title='Sharpe Mean Variance', others=0.05, nrow=25, cmap = "tab20",
                 height=6, width=10, ax=None)
# Out:
#          SUZB3.SA  KLBN11.SA
# weights  50.2504%   49.7496%

# %%
# Plotting frontier

points = 50 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)
# display(frontier.T.tail())

# Plotting the efficient frontier

label = 'Sharpe Adjusted Return Portfolio' # Title of point
mu = port.mu # Expected returns
cov = port.cov # Covariance matrix
returns = port.returns # Returns of the assets

ax = rp.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                      rf=rf, alpha=0.05, cmap='viridis', w=w_sharpe, label=label,
                      marker='*', s=16, c='r', height=6, width=10, ax=None)

# %%
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

# %%
# Risk Measures available:
#
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

rms = ['MV', 'MAD', 'MSV', 'FLPM', 'SLPM', 'CVaR',
       'EVaR', 'WR', 'MDD', 'ADD', 'CDaR', 'UCI', 'EDaR']

w_s = pd.DataFrame([])

for i in rms:
    w = port.optimization(model=model, rm=i, obj=obj, rf=rf, l=l, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
    
w_s.columns = rms

w_s.style.format("{:.2%}").background_gradient(cmap='YlGn')
# Out:
# <style type="text/css">
# #T_8199b_row0_col0, #T_8199b_row0_col2, #T_8199b_row0_col4, #T_8199b_row0_col5, #T_8199b_row0_col6, #T_8199b_row0_col8, #T_8199b_row0_col9, #T_8199b_row0_col10, #T_8199b_row0_col11, #T_8199b_row0_col12, #T_8199b_row1_col1, #T_8199b_row1_col3, #T_8199b_row1_col7 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_8199b_row0_col1, #T_8199b_row0_col3, #T_8199b_row0_col7, #T_8199b_row1_col0, #T_8199b_row1_col2, #T_8199b_row1_col4, #T_8199b_row1_col5, #T_8199b_row1_col6, #T_8199b_row1_col8, #T_8199b_row1_col9, #T_8199b_row1_col10, #T_8199b_row1_col11, #T_8199b_row1_col12 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# </style>
# <table id="T_8199b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8199b_level0_col0" class="col_heading level0 col0" >MV</th>
#       <th id="T_8199b_level0_col1" class="col_heading level0 col1" >MAD</th>
#       <th id="T_8199b_level0_col2" class="col_heading level0 col2" >MSV</th>
#       <th id="T_8199b_level0_col3" class="col_heading level0 col3" >FLPM</th>
#       <th id="T_8199b_level0_col4" class="col_heading level0 col4" >SLPM</th>
#       <th id="T_8199b_level0_col5" class="col_heading level0 col5" >CVaR</th>
#       <th id="T_8199b_level0_col6" class="col_heading level0 col6" >EVaR</th>
#       <th id="T_8199b_level0_col7" class="col_heading level0 col7" >WR</th>
#       <th id="T_8199b_level0_col8" class="col_heading level0 col8" >MDD</th>
#       <th id="T_8199b_level0_col9" class="col_heading level0 col9" >ADD</th>
#       <th id="T_8199b_level0_col10" class="col_heading level0 col10" >CDaR</th>
#       <th id="T_8199b_level0_col11" class="col_heading level0 col11" >UCI</th>
#       <th id="T_8199b_level0_col12" class="col_heading level0 col12" >EDaR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8199b_level0_row0" class="row_heading level0 row0" >SUZB3.SA</th>
#       <td id="T_8199b_row0_col0" class="data row0 col0" >50.25%</td>
#       <td id="T_8199b_row0_col1" class="data row0 col1" >49.65%</td>
#       <td id="T_8199b_row0_col2" class="data row0 col2" >52.36%</td>
#       <td id="T_8199b_row0_col3" class="data row0 col3" >49.07%</td>
#       <td id="T_8199b_row0_col4" class="data row0 col4" >52.40%</td>
#       <td id="T_8199b_row0_col5" class="data row0 col5" >54.29%</td>
#       <td id="T_8199b_row0_col6" class="data row0 col6" >51.58%</td>
#       <td id="T_8199b_row0_col7" class="data row0 col7" >16.35%</td>
#       <td id="T_8199b_row0_col8" class="data row0 col8" >68.25%</td>
#       <td id="T_8199b_row0_col9" class="data row0 col9" >100.00%</td>
#       <td id="T_8199b_row0_col10" class="data row0 col10" >68.25%</td>
#       <td id="T_8199b_row0_col11" class="data row0 col11" >80.13%</td>
#       <td id="T_8199b_row0_col12" class="data row0 col12" >68.25%</td>
#     </tr>
#     <tr>
#       <th id="T_8199b_level0_row1" class="row_heading level0 row1" >KLBN11.SA</th>
#       <td id="T_8199b_row1_col0" class="data row1 col0" >49.75%</td>
#       <td id="T_8199b_row1_col1" class="data row1 col1" >50.35%</td>
#       <td id="T_8199b_row1_col2" class="data row1 col2" >47.64%</td>
#       <td id="T_8199b_row1_col3" class="data row1 col3" >50.93%</td>
#       <td id="T_8199b_row1_col4" class="data row1 col4" >47.60%</td>
#       <td id="T_8199b_row1_col5" class="data row1 col5" >45.71%</td>
#       <td id="T_8199b_row1_col6" class="data row1 col6" >48.42%</td>
#       <td id="T_8199b_row1_col7" class="data row1 col7" >83.65%</td>
#       <td id="T_8199b_row1_col8" class="data row1 col8" >31.75%</td>
#       <td id="T_8199b_row1_col9" class="data row1 col9" >0.00%</td>
#       <td id="T_8199b_row1_col10" class="data row1 col10" >31.75%</td>
#       <td id="T_8199b_row1_col11" class="data row1 col11" >19.87%</td>
#       <td id="T_8199b_row1_col12" class="data row1 col12" >31.75%</td>
#     </tr>
#   </tbody>
# </table>

# %%
import riskfolio as rp

# Building the portfolio object
port = rp.Portfolio(returns=Y)

# Calculating optimal portfolio

# Select method and estimate input parameters:

method_mu='hist' # Method to estimate expected returns based on historical data.
method_cov='hist' # Method to estimate covariance matrix based on historical data.

port.assets_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

# Estimate optimal portfolio:

model='Classic' # Could be Classic (historical), BL (Black Litterman) or FM (Factor Model)
rm = 'MV' # Risk measure used, this time will be variance
obj = 'MinRisk' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = True # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
l = 0 # Risk aversion factor, only useful when obj is 'Utility'

w_min_risk = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w_min_risk.T)


# Plotting the composition of the portfolio

ax_min_risk = rp.plot_pie(w=w_min_risk, title='Min risk Variance', others=0.05, nrow=25, cmap = "tab20",
                 height=6, width=10, ax=None)
# Out:
#          SUZB3.SA  KLBN11.SA
# weights  79.8367%   20.1633%

# %%
# Plotting frontier

points = 50 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)
# display(frontier.T.tail())

# Plotting the efficient frontier

label = 'Min Risk Adjusted Return Portfolio' # Title of point
mu = port.mu # Expected returns
cov = port.cov # Covariance matrix
returns = port.returns # Returns of the assets

ax = rp.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                      rf=rf, alpha=0.05, cmap='viridis', w=w_min_risk, label=label,
                      marker='*', s=16, c='r', height=6, width=10, ax=None)

# %%
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

# %%
# Risk Measures available:
#
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

rms = ['MV', 'MAD', 'MSV', 'FLPM', 'SLPM', 'CVaR',
       'EVaR', 'WR', 'MDD', 'ADD', 'CDaR', 'UCI', 'EDaR']

w_s = pd.DataFrame([])

for i in rms:
    w = port.optimization(model=model, rm=i, obj=obj, rf=rf, l=l, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
    
w_s.columns = rms

w_s.style.format("{:.2%}").background_gradient(cmap='YlGn')
# Out:
# <style type="text/css">
# #T_e103b_row0_col0, #T_e103b_row0_col1, #T_e103b_row0_col2, #T_e103b_row0_col3, #T_e103b_row0_col4, #T_e103b_row0_col5, #T_e103b_row0_col6, #T_e103b_row0_col8, #T_e103b_row0_col9, #T_e103b_row0_col10, #T_e103b_row0_col11, #T_e103b_row0_col12, #T_e103b_row1_col7 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_e103b_row0_col7, #T_e103b_row1_col0, #T_e103b_row1_col1, #T_e103b_row1_col2, #T_e103b_row1_col3, #T_e103b_row1_col4, #T_e103b_row1_col5, #T_e103b_row1_col6, #T_e103b_row1_col8, #T_e103b_row1_col9, #T_e103b_row1_col10, #T_e103b_row1_col11, #T_e103b_row1_col12 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# </style>
# <table id="T_e103b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e103b_level0_col0" class="col_heading level0 col0" >MV</th>
#       <th id="T_e103b_level0_col1" class="col_heading level0 col1" >MAD</th>
#       <th id="T_e103b_level0_col2" class="col_heading level0 col2" >MSV</th>
#       <th id="T_e103b_level0_col3" class="col_heading level0 col3" >FLPM</th>
#       <th id="T_e103b_level0_col4" class="col_heading level0 col4" >SLPM</th>
#       <th id="T_e103b_level0_col5" class="col_heading level0 col5" >CVaR</th>
#       <th id="T_e103b_level0_col6" class="col_heading level0 col6" >EVaR</th>
#       <th id="T_e103b_level0_col7" class="col_heading level0 col7" >WR</th>
#       <th id="T_e103b_level0_col8" class="col_heading level0 col8" >MDD</th>
#       <th id="T_e103b_level0_col9" class="col_heading level0 col9" >ADD</th>
#       <th id="T_e103b_level0_col10" class="col_heading level0 col10" >CDaR</th>
#       <th id="T_e103b_level0_col11" class="col_heading level0 col11" >UCI</th>
#       <th id="T_e103b_level0_col12" class="col_heading level0 col12" >EDaR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e103b_level0_row0" class="row_heading level0 row0" >SUZB3.SA</th>
#       <td id="T_e103b_row0_col0" class="data row0 col0" >79.84%</td>
#       <td id="T_e103b_row0_col1" class="data row0 col1" >80.59%</td>
#       <td id="T_e103b_row0_col2" class="data row0 col2" >79.45%</td>
#       <td id="T_e103b_row0_col3" class="data row0 col3" >80.74%</td>
#       <td id="T_e103b_row0_col4" class="data row0 col4" >79.14%</td>
#       <td id="T_e103b_row0_col5" class="data row0 col5" >79.00%</td>
#       <td id="T_e103b_row0_col6" class="data row0 col6" >85.93%</td>
#       <td id="T_e103b_row0_col7" class="data row0 col7" >16.35%</td>
#       <td id="T_e103b_row0_col8" class="data row0 col8" >100.00%</td>
#       <td id="T_e103b_row0_col9" class="data row0 col9" >100.00%</td>
#       <td id="T_e103b_row0_col10" class="data row0 col10" >100.00%</td>
#       <td id="T_e103b_row0_col11" class="data row0 col11" >100.00%</td>
#       <td id="T_e103b_row0_col12" class="data row0 col12" >100.00%</td>
#     </tr>
#     <tr>
#       <th id="T_e103b_level0_row1" class="row_heading level0 row1" >KLBN11.SA</th>
#       <td id="T_e103b_row1_col0" class="data row1 col0" >20.16%</td>
#       <td id="T_e103b_row1_col1" class="data row1 col1" >19.41%</td>
#       <td id="T_e103b_row1_col2" class="data row1 col2" >20.55%</td>
#       <td id="T_e103b_row1_col3" class="data row1 col3" >19.26%</td>
#       <td id="T_e103b_row1_col4" class="data row1 col4" >20.86%</td>
#       <td id="T_e103b_row1_col5" class="data row1 col5" >21.00%</td>
#       <td id="T_e103b_row1_col6" class="data row1 col6" >14.07%</td>
#       <td id="T_e103b_row1_col7" class="data row1 col7" >83.65%</td>
#       <td id="T_e103b_row1_col8" class="data row1 col8" >0.00%</td>
#       <td id="T_e103b_row1_col9" class="data row1 col9" >0.00%</td>
#       <td id="T_e103b_row1_col10" class="data row1 col10" >0.00%</td>
#       <td id="T_e103b_row1_col11" class="data row1 col11" >0.00%</td>
#       <td id="T_e103b_row1_col12" class="data row1 col12" >0.00%</td>
#     </tr>
#   </tbody>
# </table>
