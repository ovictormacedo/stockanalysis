# %%
import numpy as np
import pandas as pd
import yfinance as yf
import warnings
import json

warnings.filterwarnings("ignore")
pd.options.display.float_format = '{:.4%}'.format

params = json.loads(open('../params.json', 'r').read())

# Date range
start = params["start_date"]
end = params["end_date"]

# Tickers of assets
industry_asset = json.loads(open('../stocks.json', 'r').read())
assets = []
for key, values in industry_asset.items():
    for value in values:
        assets.append(value)

# Downloading data
data = yf.download(assets, start = start, end = end)

data = data.loc[:,('Adj Close', slice(None))]

data.columns = assets
# Out:
# [*********************100%%**********************]  23 of 23 completed

# %%
# Calculating returns
Y = data[assets].pct_change().dropna()

display(Y.tail())
# Out:
#             TIMS3.SA  VIVT3.SA  SUZB3.SA  KLBN11.SA  CSAN3.SA  VBBR3.SA  \
# Date
# 2023-11-08   0.2370%  -0.1176%  -1.1678%   -1.3498%   0.0000%   1.8173%
# 2023-11-09  -0.7432%   2.7075%   0.8069%   -1.0262%  -1.4173%  -1.0854%
# 2023-11-10  -2.2464%  -0.0573%   1.9440%    2.1889%   1.1981%   1.9020%
# 2023-11-13  -0.0696%  -5.1605%  -0.7291%    0.4510%  -0.2368%   0.0718%
# 2023-11-14   1.0104%   2.7811%   1.1299%    0.5612%   8.7025%   2.1521%
#
#             PRIO3.SA  UGPA3.SA  ENAT3.SA  PETR3.SA  ...  ALUP11.SA  CPFE3.SA  \
# Date                                                ...
# 2023-11-08  -0.4508%  -2.2182%  -1.0905%   0.4821%  ...    2.2768%  -2.3639%
# 2023-11-09  -0.6926%  -0.7971%  -0.4369%  -0.1499%  ...   -1.3531%   2.1219%
# 2023-11-10   0.1878%  -1.7923%   4.5967%   1.2613%  ...    0.1770%  -0.3197%
# 2023-11-13   2.2222%  -1.7621%   0.5793%  -0.9193%  ...   -0.7951%   2.2448%
# 2023-11-14   3.3787%   3.7156%   2.2443%   1.7360%  ...    1.0240%   1.1500%
#
#             CMIG3.SA  ELET3.SA  EQTL3.SA  EGIE3.SA  VALE3.SA  GGBR3.SA  \
# Date
# 2023-11-08  -2.8620%   2.7468%  -0.2514%   4.0435%   7.2727%   0.0713%
# 2023-11-09  -1.6491%  -0.1122%  -0.1680%  -0.0580%  -0.6780%   0.4848%
# 2023-11-10   3.8900%   2.2646%   1.0659%   0.6384%  -0.0853%   1.5326%
# 2023-11-13  -0.3658%  -0.9883%   0.6661%  -0.6920%   2.2203%  -0.2096%
# 2023-11-14   1.4903%  -2.9575%   2.0007%  -0.2904%   2.3392%   3.0952%
#
#             CSNA3.SA  FESA4.SA
# Date
# 2023-11-08   0.8780%   3.1848%
# 2023-11-09  -1.7407%  -0.1210%
# 2023-11-10  -0.3730%   1.1917%
# 2023-11-13   0.2808%   1.1178%
# 2023-11-14   1.7265%   0.4935%
#
# [5 rows x 23 columns]

# %%
import riskfolio as rp

# Building the portfolio object
port = rp.Portfolio(returns=Y)

# Calculating optimal portfolio

# Select method and estimate input parameters:

method_mu='hist' # Method to estimate expected returns based on historical data.
method_cov='hist' # Method to estimate covariance matrix based on historical data.

port.assets_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

# Estimate optimal portfolio:

model='Classic' # Could be Classic (historical), BL (Black Litterman) or FM (Factor Model)
rm = 'MV' # Risk measure used, this time will be variance
obj = 'Sharpe' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = True # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
l = 0 # Risk aversion factor, only useful when obj is 'Utility'

w_sharpe = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

#display(w_sharpe.T)
keys = w_sharpe.T.keys()
filtered_keys= []
w_sharpe_filtered_weights_raw = []
total_w_sharpe_filtered_weights = 0
for key in keys:
    if w_sharpe.T[key]["weights"] > 0.01:
        filtered_keys.append(key)
        w_sharpe_filtered_weights_raw.append(w_sharpe.T[key]["weights"])
        total_w_sharpe_filtered_weights += w_sharpe.T[key]["weights"]

w_sharpe_filtered_weights = pd.DataFrame([w_sharpe_filtered_weights_raw], columns=filtered_keys)
display(w_sharpe_filtered_weights)
print(f"Total: {total_w_sharpe_filtered_weights*100}")
print(f"Symbols: {[key for key in filtered_keys]}")
    
# Plotting the composition of the portfolio

ax_sharpe = rp.plot_pie(w=w_sharpe, title='Sharpe Mean Variance', others=0.05, nrow=25, cmap = "tab20",
                 height=6, width=10, ax=None)
# Out:
#    TAEE11.SA  CPFE3.SA  CMIG3.SA  EGIE3.SA  VALE3.SA  FESA4.SA
# 0   14.4653%  17.9261%   2.2191%  21.4796%  28.3696%  15.5403%
# Total: 99.9999787523885
# Symbols: ['TAEE11.SA', 'CPFE3.SA', 'CMIG3.SA', 'EGIE3.SA', 'VALE3.SA', 'FESA4.SA']

# %%
# Plotting frontier

points = 50 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)
# display(frontier.T.tail())

# Plotting the efficient frontier

label = 'Sharpe Adjusted Return Portfolio' # Title of point
mu = port.mu # Expected returns
cov = port.cov # Covariance matrix
returns = port.returns # Returns of the assets

ax = rp.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                      rf=rf, alpha=0.05, cmap='viridis', w=w_sharpe, label=label,
                      marker='*', s=16, c='r', height=6, width=10, ax=None)

# %%
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

# %%
# Risk Measures available:
#
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

rms = ['MV', 'MAD', 'MSV', 'FLPM', 'SLPM', 'CVaR',
       'EVaR', 'WR', 'MDD', 'ADD', 'CDaR', 'UCI', 'EDaR']

w_s = pd.DataFrame([])

for i in rms:
    w = port.optimization(model=model, rm=i, obj=obj, rf=rf, l=l, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
    
w_s.columns = rms

w_s.style.format("{:.2%}").background_gradient(cmap='YlGn')
# Out:
# <style type="text/css">
# #T_4f1e3_row0_col0, #T_4f1e3_row0_col1, #T_4f1e3_row0_col2, #T_4f1e3_row0_col4, #T_4f1e3_row0_col5, #T_4f1e3_row0_col6, #T_4f1e3_row0_col7, #T_4f1e3_row1_col0, #T_4f1e3_row1_col1, #T_4f1e3_row1_col2, #T_4f1e3_row1_col3, #T_4f1e3_row1_col4, #T_4f1e3_row1_col5, #T_4f1e3_row1_col6, #T_4f1e3_row1_col7, #T_4f1e3_row1_col8, #T_4f1e3_row1_col9, #T_4f1e3_row1_col10, #T_4f1e3_row1_col11, #T_4f1e3_row1_col12, #T_4f1e3_row2_col0, #T_4f1e3_row2_col1, #T_4f1e3_row2_col2, #T_4f1e3_row2_col3, #T_4f1e3_row2_col4, #T_4f1e3_row2_col5, #T_4f1e3_row2_col6, #T_4f1e3_row2_col7, #T_4f1e3_row2_col8, #T_4f1e3_row2_col9, #T_4f1e3_row2_col10, #T_4f1e3_row2_col11, #T_4f1e3_row2_col12, #T_4f1e3_row3_col0, #T_4f1e3_row3_col1, #T_4f1e3_row3_col2, #T_4f1e3_row3_col3, #T_4f1e3_row3_col4, #T_4f1e3_row3_col5, #T_4f1e3_row3_col6, #T_4f1e3_row3_col7, #T_4f1e3_row3_col8, #T_4f1e3_row3_col9, #T_4f1e3_row3_col10, #T_4f1e3_row3_col11, #T_4f1e3_row3_col12, #T_4f1e3_row4_col0, #T_4f1e3_row4_col1, #T_4f1e3_row4_col2, #T_4f1e3_row4_col3, #T_4f1e3_row4_col4, #T_4f1e3_row4_col5, #T_4f1e3_row4_col8, #T_4f1e3_row4_col9, #T_4f1e3_row5_col0, #T_4f1e3_row5_col1, #T_4f1e3_row5_col2, #T_4f1e3_row5_col3, #T_4f1e3_row5_col4, #T_4f1e3_row5_col5, #T_4f1e3_row5_col6, #T_4f1e3_row5_col7, #T_4f1e3_row5_col8, #T_4f1e3_row5_col9, #T_4f1e3_row5_col10, #T_4f1e3_row5_col11, #T_4f1e3_row5_col12, #T_4f1e3_row6_col0, #T_4f1e3_row6_col1, #T_4f1e3_row6_col2, #T_4f1e3_row6_col3, #T_4f1e3_row6_col4, #T_4f1e3_row6_col5, #T_4f1e3_row6_col6, #T_4f1e3_row6_col7, #T_4f1e3_row6_col8, #T_4f1e3_row6_col9, #T_4f1e3_row6_col10, #T_4f1e3_row6_col11, #T_4f1e3_row6_col12, #T_4f1e3_row7_col0, #T_4f1e3_row7_col1, #T_4f1e3_row7_col2, #T_4f1e3_row7_col3, #T_4f1e3_row7_col4, #T_4f1e3_row7_col5, #T_4f1e3_row7_col6, #T_4f1e3_row7_col7, #T_4f1e3_row7_col8, #T_4f1e3_row7_col9, #T_4f1e3_row7_col10, #T_4f1e3_row7_col11, #T_4f1e3_row7_col12, #T_4f1e3_row8_col0, #T_4f1e3_row8_col1, #T_4f1e3_row8_col2, #T_4f1e3_row8_col3, #T_4f1e3_row8_col4, #T_4f1e3_row8_col5, #T_4f1e3_row8_col6, #T_4f1e3_row8_col7, #T_4f1e3_row8_col8, #T_4f1e3_row8_col9, #T_4f1e3_row8_col10, #T_4f1e3_row8_col11, #T_4f1e3_row8_col12, #T_4f1e3_row9_col0, #T_4f1e3_row9_col1, #T_4f1e3_row9_col2, #T_4f1e3_row9_col3, #T_4f1e3_row9_col4, #T_4f1e3_row9_col5, #T_4f1e3_row9_col6, #T_4f1e3_row9_col7, #T_4f1e3_row9_col8, #T_4f1e3_row9_col9, #T_4f1e3_row9_col10, #T_4f1e3_row9_col11, #T_4f1e3_row9_col12, #T_4f1e3_row10_col0, #T_4f1e3_row10_col1, #T_4f1e3_row10_col2, #T_4f1e3_row10_col3, #T_4f1e3_row10_col4, #T_4f1e3_row10_col5, #T_4f1e3_row10_col6, #T_4f1e3_row10_col7, #T_4f1e3_row10_col8, #T_4f1e3_row10_col9, #T_4f1e3_row10_col10, #T_4f1e3_row10_col11, #T_4f1e3_row10_col12, #T_4f1e3_row11_col0, #T_4f1e3_row11_col1, #T_4f1e3_row11_col2, #T_4f1e3_row11_col3, #T_4f1e3_row11_col4, #T_4f1e3_row11_col5, #T_4f1e3_row11_col6, #T_4f1e3_row11_col7, #T_4f1e3_row11_col8, #T_4f1e3_row11_col9, #T_4f1e3_row11_col10, #T_4f1e3_row11_col11, #T_4f1e3_row11_col12, #T_4f1e3_row13_col0, #T_4f1e3_row13_col1, #T_4f1e3_row13_col2, #T_4f1e3_row13_col4, #T_4f1e3_row13_col5, #T_4f1e3_row13_col6, #T_4f1e3_row13_col7, #T_4f1e3_row14_col8, #T_4f1e3_row15_col1, #T_4f1e3_row15_col2, #T_4f1e3_row15_col3, #T_4f1e3_row15_col4, #T_4f1e3_row16_col0, #T_4f1e3_row16_col1, #T_4f1e3_row16_col2, #T_4f1e3_row16_col3, #T_4f1e3_row16_col4, #T_4f1e3_row16_col5, #T_4f1e3_row16_col6, #T_4f1e3_row16_col7, #T_4f1e3_row16_col8, #T_4f1e3_row16_col9, #T_4f1e3_row16_col10, #T_4f1e3_row16_col11, #T_4f1e3_row16_col12, #T_4f1e3_row17_col0, #T_4f1e3_row17_col1, #T_4f1e3_row17_col2, #T_4f1e3_row17_col3, #T_4f1e3_row17_col4, #T_4f1e3_row17_col5, #T_4f1e3_row17_col6, #T_4f1e3_row17_col7, #T_4f1e3_row17_col8, #T_4f1e3_row17_col9, #T_4f1e3_row17_col10, #T_4f1e3_row17_col11, #T_4f1e3_row17_col12, #T_4f1e3_row20_col0, #T_4f1e3_row20_col1, #T_4f1e3_row20_col2, #T_4f1e3_row20_col3, #T_4f1e3_row20_col4, #T_4f1e3_row20_col5, #T_4f1e3_row20_col6, #T_4f1e3_row20_col7, #T_4f1e3_row20_col9, #T_4f1e3_row20_col11, #T_4f1e3_row21_col0, #T_4f1e3 ...
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_4f1e3_row0_col3 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_4f1e3_row0_col8 {
#   background-color: #95d385;
#   color: #000000;
# }
# #T_4f1e3_row0_col9 {
#   background-color: #6dc073;
#   color: #000000;
# }
# #T_4f1e3_row0_col10 {
#   background-color: #9dd688;
#   color: #000000;
# }
# #T_4f1e3_row0_col11 {
#   background-color: #55b567;
#   color: #f1f1f1;
# }
# #T_4f1e3_row0_col12, #T_4f1e3_row19_col10 {
#   background-color: #8ed082;
#   color: #000000;
# }
# #T_4f1e3_row4_col6 {
#   background-color: #69bf72;
#   color: #000000;
# }
# #T_4f1e3_row4_col7 {
#   background-color: #005d33;
#   color: #f1f1f1;
# }
# #T_4f1e3_row4_col10, #T_4f1e3_row14_col12, #T_4f1e3_row15_col11 {
#   background-color: #fcfed7;
#   color: #000000;
# }
# #T_4f1e3_row4_col11 {
#   background-color: #feffe2;
#   color: #000000;
# }
# #T_4f1e3_row4_col12, #T_4f1e3_row13_col10 {
#   background-color: #fafdcc;
#   color: #000000;
# }
# #T_4f1e3_row12_col0 {
#   background-color: #74c477;
#   color: #000000;
# }
# #T_4f1e3_row12_col1 {
#   background-color: #89ce80;
#   color: #000000;
# }
# #T_4f1e3_row12_col2 {
#   background-color: #7cc87b;
#   color: #000000;
# }
# #T_4f1e3_row12_col3 {
#   background-color: #8bce81;
#   color: #000000;
# }
# #T_4f1e3_row12_col4 {
#   background-color: #7ac77a;
#   color: #000000;
# }
# #T_4f1e3_row12_col5 {
#   background-color: #fafdc8;
#   color: #000000;
# }
# #T_4f1e3_row12_col6 {
#   background-color: #dff3a8;
#   color: #000000;
# }
# #T_4f1e3_row12_col7, #T_4f1e3_row14_col3 {
#   background-color: #c5e89a;
#   color: #000000;
# }
# #T_4f1e3_row12_col8 {
#   background-color: #0b713b;
#   color: #f1f1f1;
# }
# #T_4f1e3_row12_col9, #T_4f1e3_row12_col10, #T_4f1e3_row12_col11, #T_4f1e3_row12_col12, #T_4f1e3_row18_col7, #T_4f1e3_row18_col8, #T_4f1e3_row19_col0, #T_4f1e3_row19_col1, #T_4f1e3_row19_col2, #T_4f1e3_row19_col3, #T_4f1e3_row19_col4, #T_4f1e3_row19_col5, #T_4f1e3_row19_col6 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_4f1e3_row13_col3 {
#   background-color: #feffde;
#   color: #000000;
# }
# #T_4f1e3_row13_col8 {
#   background-color: #fbfed2;
#   color: #000000;
# }
# #T_4f1e3_row13_col9 {
#   background-color: #fdfedd;
#   color: #000000;
# }
# #T_4f1e3_row13_col11 {
#   background-color: #fdfedb;
#   color: #000000;
# }
# #T_4f1e3_row13_col12 {
#   background-color: #f8fcc0;
#   color: #000000;
# }
# #T_4f1e3_row14_col0, #T_4f1e3_row18_col5, #T_4f1e3_row22_col9 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
# }
# #T_4f1e3_row14_col1 {
#   background-color: #9fd788;
#   color: #000000;
# }
# #T_4f1e3_row14_col2, #T_4f1e3_row22_col3 {
#   background-color: #97d385;
#   color: #000000;
# }
# #T_4f1e3_row14_col4, #T_4f1e3_row18_col11 {
#   background-color: #93d284;
#   color: #000000;
# }
# #T_4f1e3_row14_col5 {
#   background-color: #2d914b;
#   color: #f1f1f1;
# }
# #T_4f1e3_row14_col6, #T_4f1e3_row15_col6, #T_4f1e3_row15_col12 {
#   background-color: #e0f3a8;
#   color: #000000;
# }
# #T_4f1e3_row14_col7 {
#   background-color: #eff9b3;
#   color: #000000;
# }
# #T_4f1e3_row14_col9 {
#   background-color: #c9e99c;
#   color: #000000;
# }
# #T_4f1e3_row14_col10 {
#   background-color: #fbfdce;
#   color: #000000;
# }
# #T_4f1e3_row14_col11 {
#   background-color: #bae394;
#   color: #000000;
# }
# #T_4f1e3_row15_col0 {
#   background-color: #fafdc9;
#   color: #000000;
# }
# #T_4f1e3_row15_col5 {
#   background-color: #f6fcb8;
#   color: #000000;
# }
# #T_4f1e3_row15_col7 {
#   background-color: #47ae60;
#   color: #f1f1f1;
# }
# #T_4f1e3_row15_col8 {
#   background-color: #d6efa2;
#   color: #000000;
# }
# #T_4f1e3_row15_col9 {
#   background-color: #fcfed4;
#   color: #000000;
# }
# #T_4f1e3_row15_col10 {
#   background-color: #dcf1a5;
#   color: #000000;
# }
# #T_4f1e3_row18_col0 {
#   background-color: #218242;
#   color: #f1f1f1;
# }
# #T_4f1e3_row18_col1 {
#   background-color: #2a8d49;
#   color: #f1f1f1;
# }

# %%
import riskfolio as rp

# Building the portfolio object
port = rp.Portfolio(returns=Y)

# Calculating optimal portfolio

# Select method and estimate input parameters:

method_mu='hist' # Method to estimate expected returns based on historical data.
method_cov='hist' # Method to estimate covariance matrix based on historical data.

port.assets_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

# Estimate optimal portfolio:

model='Classic' # Could be Classic (historical), BL (Black Litterman) or FM (Factor Model)
rm = 'MV' # Risk measure used, this time will be variance
obj = 'MinRisk' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = True # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
l = 0 # Risk aversion factor, only useful when obj is 'Utility'

w_min_risk = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w_min_risk.T)


# Plotting the composition of the portfolio

ax_min_risk = rp.plot_pie(w=w_min_risk, title='Min risk Variance', others=0.05, nrow=25, cmap = "tab20",
                 height=6, width=10, ax=None)
# Out:
#          TIMS3.SA  VIVT3.SA  SUZB3.SA  KLBN11.SA  CSAN3.SA  VBBR3.SA  \
# weights   8.5455%   1.2108%   0.0000%    0.0000%   0.0000%  15.2444%
#
#          PRIO3.SA  UGPA3.SA  ENAT3.SA  PETR3.SA  ...  ALUP11.SA  CPFE3.SA  \
# weights   0.0000%   0.0000%   0.0000%   0.0000%  ...    5.3799%   3.0876%
#
#          CMIG3.SA  ELET3.SA  EQTL3.SA  EGIE3.SA  VALE3.SA  GGBR3.SA  CSNA3.SA  \
# weights   3.5696%   8.6056%  23.6150%   8.6210%   0.0000%   9.3094%   0.0000%
#
#          FESA4.SA
# weights   0.0000%
#
# [1 rows x 23 columns]

# %%
# Plotting frontier

points = 50 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)
# display(frontier.T.tail())

# Plotting the efficient frontier

label = 'Max Risk Adjusted Return Portfolio' # Title of point
mu = port.mu # Expected returns
cov = port.cov # Covariance matrix
returns = port.returns # Returns of the assets

ax = rp.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                      rf=rf, alpha=0.05, cmap='viridis', w=w_min_risk, label=label,
                      marker='*', s=16, c='r', height=6, width=10, ax=None)

# %%
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

# %%
# Risk Measures available:
#
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

rms = ['MV', 'MAD', 'MSV', 'FLPM', 'SLPM', 'CVaR',
       'EVaR', 'WR', 'MDD', 'ADD', 'CDaR', 'UCI', 'EDaR']

w_s = pd.DataFrame([])

for i in rms:
    w = port.optimization(model=model, rm=i, obj=obj, rf=rf, l=l, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
    
w_s.columns = rms

w_s.style.format("{:.2%}").background_gradient(cmap='YlGn')
# Out:
# <style type="text/css">
# #T_344ed_row0_col0 {
#   background-color: #b2df90;
#   color: #000000;
# }
# #T_344ed_row0_col1, #T_344ed_row0_col3, #T_344ed_row0_col7, #T_344ed_row1_col1, #T_344ed_row1_col3, #T_344ed_row2_col0, #T_344ed_row2_col2, #T_344ed_row2_col3, #T_344ed_row2_col4, #T_344ed_row2_col5, #T_344ed_row2_col6, #T_344ed_row2_col7, #T_344ed_row2_col8, #T_344ed_row2_col9, #T_344ed_row2_col10, #T_344ed_row2_col11, #T_344ed_row2_col12, #T_344ed_row3_col0, #T_344ed_row3_col1, #T_344ed_row3_col2, #T_344ed_row3_col3, #T_344ed_row3_col4, #T_344ed_row3_col5, #T_344ed_row3_col6, #T_344ed_row3_col7, #T_344ed_row3_col8, #T_344ed_row3_col9, #T_344ed_row3_col10, #T_344ed_row3_col11, #T_344ed_row3_col12, #T_344ed_row4_col0, #T_344ed_row4_col1, #T_344ed_row4_col2, #T_344ed_row4_col3, #T_344ed_row4_col4, #T_344ed_row4_col5, #T_344ed_row4_col8, #T_344ed_row4_col10, #T_344ed_row4_col11, #T_344ed_row4_col12, #T_344ed_row5_col3, #T_344ed_row5_col7, #T_344ed_row5_col8, #T_344ed_row5_col9, #T_344ed_row5_col11, #T_344ed_row5_col12, #T_344ed_row6_col0, #T_344ed_row6_col1, #T_344ed_row6_col2, #T_344ed_row6_col3, #T_344ed_row6_col4, #T_344ed_row6_col5, #T_344ed_row6_col6, #T_344ed_row6_col7, #T_344ed_row6_col8, #T_344ed_row6_col9, #T_344ed_row6_col10, #T_344ed_row6_col11, #T_344ed_row6_col12, #T_344ed_row7_col0, #T_344ed_row7_col1, #T_344ed_row7_col2, #T_344ed_row7_col3, #T_344ed_row7_col4, #T_344ed_row7_col6, #T_344ed_row7_col7, #T_344ed_row7_col8, #T_344ed_row7_col9, #T_344ed_row7_col10, #T_344ed_row7_col11, #T_344ed_row7_col12, #T_344ed_row8_col0, #T_344ed_row8_col1, #T_344ed_row8_col2, #T_344ed_row8_col3, #T_344ed_row8_col4, #T_344ed_row8_col8, #T_344ed_row8_col9, #T_344ed_row8_col10, #T_344ed_row8_col11, #T_344ed_row8_col12, #T_344ed_row9_col0, #T_344ed_row9_col1, #T_344ed_row9_col2, #T_344ed_row9_col3, #T_344ed_row9_col4, #T_344ed_row9_col5, #T_344ed_row9_col6, #T_344ed_row9_col7, #T_344ed_row9_col8, #T_344ed_row9_col9, #T_344ed_row9_col10, #T_344ed_row9_col11, #T_344ed_row9_col12, #T_344ed_row10_col0, #T_344ed_row10_col1, #T_344ed_row10_col2, #T_344ed_row10_col3, #T_344ed_row10_col4, #T_344ed_row10_col5, #T_344ed_row10_col6, #T_344ed_row10_col7, #T_344ed_row10_col8, #T_344ed_row10_col9, #T_344ed_row10_col10, #T_344ed_row10_col11, #T_344ed_row10_col12, #T_344ed_row11_col0, #T_344ed_row11_col1, #T_344ed_row11_col2, #T_344ed_row11_col3, #T_344ed_row11_col4, #T_344ed_row11_col5, #T_344ed_row11_col6, #T_344ed_row11_col7, #T_344ed_row11_col8, #T_344ed_row11_col10, #T_344ed_row11_col11, #T_344ed_row11_col12, #T_344ed_row13_col3, #T_344ed_row13_col7, #T_344ed_row14_col3, #T_344ed_row14_col5, #T_344ed_row14_col6, #T_344ed_row14_col7, #T_344ed_row14_col8, #T_344ed_row15_col3, #T_344ed_row15_col5, #T_344ed_row15_col6, #T_344ed_row15_col7, #T_344ed_row15_col8, #T_344ed_row15_col10, #T_344ed_row16_col1, #T_344ed_row16_col3, #T_344ed_row16_col5, #T_344ed_row16_col8, #T_344ed_row16_col9, #T_344ed_row16_col10, #T_344ed_row16_col11, #T_344ed_row16_col12, #T_344ed_row17_col3, #T_344ed_row17_col8, #T_344ed_row17_col9, #T_344ed_row17_col10, #T_344ed_row17_col11, #T_344ed_row17_col12, #T_344ed_row18_col3, #T_344ed_row19_col0, #T_344ed_row19_col1, #T_344ed_row19_col2, #T_344ed_row19_col3, #T_344ed_row19_col5, #T_344ed_row19_col6, #T_344ed_row19_col7, #T_344ed_row20_col3, #T_344ed_row20_col9, #T_344ed_row21_col0, #T_344ed_row21_col1, #T_344ed_row21_col2, #T_344ed_row21_col3, #T_344ed_row21_col4, #T_344ed_row21_col5, #T_344ed_row21_col6, #T_344ed_row21_col7, #T_344ed_row21_col8, #T_344ed_row21_col9, #T_344ed_row21_col10, #T_344ed_row21_col11, #T_344ed_row21_col12, #T_344ed_row22_col0, #T_344ed_row22_col1, #T_344ed_row22_col2, #T_344ed_row22_col3, #T_344ed_row22_col4, #T_344ed_row22_col9, #T_344ed_row22_col10, #T_344ed_row22_col11, #T_344ed_row22_col12 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_344ed_row0_col2 {
#   background-color: #a7db8c;
#   color: #000000;
# }
# #T_344ed_row0_col4 {
#   background-color: #77c679;
#   color: #000000;
# }
# #T_344ed_row0_col5 {
#   background-color: #dcf1a5;
#   color: #000000;
# }
# #T_344ed_row0_col6 {
#   background-color: #f9fdc5;
#   color: #000000;
# }
# #T_344ed_row0_col8 {
#   background-color: #75c578;
#   color: #000000;
# }
# #T_344ed_row0_col9 {
#   background-color: #c1e698;
#   color: #000000;
# }
# #T_344ed_row0_col10 {
#   background-color: #53b466;
#   color: #f1f1f1;
# }
# #T_344ed_row0_col11 {
#   background-color: #81ca7d;
#   color: #000000;
# }
# #T_344ed_row0_col12 {
#   background-color: #55b567;
#   color: #f1f1f1;
# }
# #T_344ed_row1_col0, #T_344ed_row1_col12 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_344ed_row1_col2, #T_344ed_row19_col10 {
#   background-color: #fcfed7;
#   color: #000000;
# }
# #T_344ed_row1_col4 {
#   background-color: #fdfedd;
#   color: #000000;
# }
# #T_344ed_row1_col5, #T_344ed_row15_col12 {
#   background-color: #fcfed4;
#   color: #000000;
# }
# #T_344ed_row1_col6 {
#   background-color: #bae394;
#   color: #000000;
# }
# #T_344ed_row1_col7, #T_344ed_row13_col10 {
#   background-color: #ccea9d;
#   color: #000000;
# }
# #T_344ed_row1_col8 {
#   background-color: #fdfeda;
#   color: #000000;
# }
# #T_344ed_row1_col9 {
#   background-color: #fbfdce;
#   color: #000000;
# }
# #T_344ed_row1_col10 {
#   background-color: #f3fab6;
#   color: #000000;
# }
# #T_344ed_row1_col11, #T_344ed_row15_col4 {
#   background-color: #fbfdcf;
#   color: #000000;
# }
# #T_344ed_row2_col1, #T_344ed_row14_col1, #T_344ed_row15_col1, #T_344ed_row18_col1 {
#   background-color: #ffffe4;
#   color: #000000;
# }
# #T_344ed_row4_col6 {
#   background-color: #eff9b3;
#   color: #000000;
# }
# #T_344ed_row4_col7 {
#   background-color: #ebf7b0;
#   color: #000000;
# }
# #T_344ed_row4_col9, #T_344ed_row17_col1 {
#   background-color: #feffe1;
#   color: #000000;
# }
# #T_344ed_row5_col0 {
#   background-color: #3ca458;
#   color: #f1f1f1;
# }
# #T_344ed_row5_col1, #T_344ed_row5_col10, #T_344ed_row13_col1, #T_344ed_row20_col1 {
#   background-color: #feffe2;
#   color: #000000;
# }
# #T_344ed_row5_col2 {
#   background-color: #5fba6c;
#   color: #f1f1f1;
# }
# #T_344ed_row5_col4 {
#   background-color: #47ae60;
#   color: #f1f1f1;
# }
# #T_344ed_row5_col5, #T_344ed_row22_col7 {
#   background-color: #f7fcb9;
#   color: #000000;
# }
# #T_344ed_row5_col6, #T_344ed_row20_col4 {
#   background-color: #9ad587;
#   color: #000000;
# }
# #T_344ed_row7_col5, #T_344ed_row15_col2 {
#   background-color: #fbfed2;
#   color: #000000;
# }
# #T_344ed_row8_col5, #T_344ed_row14_col4 {
#   background-color: #e7f6ad;
#   color: #000000;
# }
# #T_344ed_row8_col6 {
#   background-color: #bde496;
#   color: #000000;
# }
# #T_344ed_row8_col7 {
#   background-color: #ddf2a6;
#   color: #000000;
# }
# #T_344ed_row11_col9 {
#   background-color: #feffdf;
#   color: #000000;
# }
# #T_344ed_row12_col0 {
#   background-color: #66bd70;
#   color: #f1f1f1;
# }
# #T_344ed_row12_col1, #T_344ed_row12_col3, #T_344ed_row12_col8, #T_344ed_row12_col9, #T_344ed_row12_col11, #T_344ed_row17_col0, #T_344ed_row17_col2, #T_344ed_row17_col4, #T_344ed_row17_col5, #T_344ed_row17_col6, #T_344ed_row18_col7, #T_344ed_row18_col10, #T_344ed_row18_col12 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_344ed_row12_col2 {
#   background-color: #389f55;
#   color: #f1f1f1;
# }
# #T_344ed_row12_col4 {
#   background-color: #1e8041;
#   color: #f1f1f1;
# }
# #T_344ed_row12_col5 {
#   background-color: #d2eda0;
#   color: #000000;
# }
# #T_344ed_row12_col6, #T_344ed_row20_col6 {
#   background-color: #359c53;
#   color: #f1f1f1;
# }
# #T_344ed_row12_col7 {
#   background-color: #74c477;
#   color: #000000;
# }
# #T_344ed_row12_col10, #T_344ed_row17_col7 {
#   background-color: #208242;
#   color: #f1f1f1;
# }
# #T_344ed_row12_col12 {
#   background-color: #004629;
#   color: #f1f1f1;
# }
# #T_344ed_row13_col0 {
#   background-color: #def2a7;
#   color: #000000;
# }
# #T_344ed_row13_col2 {
#   background-color: #aedd8e;
#   color: #000000;
# }
# #T_344ed_row13_col4 {
#   background-color: #5cb86b;
#   color: #f1f1f1;
# }
# #T_344ed_row13_col5 {
#   background-color: #40aa5c;
#   color: #f1f1f1;
# }
# #T_344ed_row13_col6, #T_344ed_row16_col7 {
#   background-color: #e9f6af;
#   color: #000000;
# }
# #T_344ed_row13_col8 {
#   background-color: #89ce80;
#   color: #000000;
# }
# #T_344ed_row13_col9 {
#   background-color: #f9fdc4;
#   color:
