# %%
import numpy as np
import pandas as pd
import yfinance as yf
import warnings
import json

warnings.filterwarnings("ignore")
pd.options.display.float_format = '{:.4%}'.format

params = json.loads(open('../params.json', 'r').read())

# Date range
start = params["start_date"]
end = params["end_date"]

# Tickers of assets
OIL = 'Oil gas biofuels, exploration, refining etc'
TELCO = 'Telecommunications'
PULP_PAPER = 'Pulp and Paper'
ELECTRICAL = 'Electrical energy'
MINERALS = 'Minerals'

industry_asset = json.loads(open('../stocks.json', 'r').read())
assets = []
for value in industry_asset[MINERALS]:
    assets.append(value)

# Downloading data
data = yf.download(assets, start = start, end = end)

data = data.loc[:,('Adj Close', slice(None))]

data.columns = assets
# Out:
# [*********************100%%**********************]  4 of 4 completed

# %%
# Calculating returns
Y = data[assets].pct_change().dropna()

display(Y.tail())
# Out:
#             VALE3.SA  GGBR3.SA  CSNA3.SA  FESA4.SA
# Date
# 2023-10-30   1.1434%  -0.3714%   0.3469%   0.9028%
# 2023-10-31   2.2609%   0.7249%  -0.9383%   1.2027%
# 2023-11-01   1.7857%  -3.1462%   0.9472%   1.9130%
# 2023-11-03   5.8480%   1.1890%   3.4568%   1.2514%
# 2023-11-06   0.0789%   0.4826%   0.5728%   0.4214%

# %%
import riskfolio as rp

# Building the portfolio object
port = rp.Portfolio(returns=Y)

# Calculating optimal portfolio

# Select method and estimate input parameters:

method_mu='hist' # Method to estimate expected returns based on historical data.
method_cov='hist' # Method to estimate covariance matrix based on historical data.

port.assets_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

# Estimate optimal portfolio:

model='Classic' # Could be Classic (historical), BL (Black Litterman) or FM (Factor Model)
rm = 'MV' # Risk measure used, this time will be variance
obj = 'Sharpe' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = True # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
l = 0 # Risk aversion factor, only useful when obj is 'Utility'

w_sharpe = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w_sharpe.T)

# Plotting the composition of the portfolio

ax_sharpe = rp.plot_pie(w=w_sharpe, title='Sharpe Mean Variance', others=0.05, nrow=25, cmap = "tab20",
                 height=6, width=10, ax=None)
# Out:
#          VALE3.SA  GGBR3.SA  CSNA3.SA  FESA4.SA
# weights  20.9508%   0.0000%  79.0492%   0.0000%

# %%
# Plotting frontier

points = 50 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)
# display(frontier.T.tail())

# Plotting the efficient frontier

label = 'Sharpe Adjusted Return Portfolio' # Title of point
mu = port.mu # Expected returns
cov = port.cov # Covariance matrix
returns = port.returns # Returns of the assets

ax = rp.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                      rf=rf, alpha=0.05, cmap='viridis', w=w_sharpe, label=label,
                      marker='*', s=16, c='r', height=6, width=10, ax=None)

# %%
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

# %%
# Risk Measures available:
#
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

rms = ['MV', 'MAD', 'MSV', 'FLPM', 'SLPM', 'CVaR',
       'EVaR', 'WR', 'MDD', 'ADD', 'CDaR', 'UCI', 'EDaR']

w_s = pd.DataFrame([])

for i in rms:
    w = port.optimization(model=model, rm=i, obj=obj, rf=rf, l=l, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
    
w_s.columns = rms

w_s.style.format("{:.2%}").background_gradient(cmap='YlGn')
# Out:
# <style type="text/css">
# #T_9c99c_row0_col0 {
#   background-color: #d5eea1;
#   color: #000000;
# }
# #T_9c99c_row0_col1 {
#   background-color: #bde496;
#   color: #000000;
# }
# #T_9c99c_row0_col2 {
#   background-color: #77c679;
#   color: #000000;
# }
# #T_9c99c_row0_col3 {
#   background-color: #a9db8c;
#   color: #000000;
# }
# #T_9c99c_row0_col4 {
#   background-color: #74c477;
#   color: #000000;
# }
# #T_9c99c_row0_col5 {
#   background-color: #62bb6e;
#   color: #f1f1f1;
# }
# #T_9c99c_row0_col6 {
#   background-color: #187b3f;
#   color: #f1f1f1;
# }
# #T_9c99c_row0_col7 {
#   background-color: #298c48;
#   color: #f1f1f1;
# }
# #T_9c99c_row0_col8, #T_9c99c_row0_col10, #T_9c99c_row0_col12 {
#   background-color: #a4d98a;
#   color: #000000;
# }
# #T_9c99c_row0_col9, #T_9c99c_row0_col11, #T_9c99c_row1_col0, #T_9c99c_row1_col1, #T_9c99c_row1_col2, #T_9c99c_row1_col3, #T_9c99c_row1_col4, #T_9c99c_row1_col5, #T_9c99c_row1_col6, #T_9c99c_row1_col7, #T_9c99c_row1_col8, #T_9c99c_row1_col9, #T_9c99c_row1_col10, #T_9c99c_row1_col11, #T_9c99c_row1_col12, #T_9c99c_row3_col0, #T_9c99c_row3_col1, #T_9c99c_row3_col2, #T_9c99c_row3_col3, #T_9c99c_row3_col4, #T_9c99c_row3_col5, #T_9c99c_row3_col6, #T_9c99c_row3_col8, #T_9c99c_row3_col9, #T_9c99c_row3_col10, #T_9c99c_row3_col11, #T_9c99c_row3_col12 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_9c99c_row2_col0, #T_9c99c_row2_col1, #T_9c99c_row2_col2, #T_9c99c_row2_col3, #T_9c99c_row2_col4, #T_9c99c_row2_col5, #T_9c99c_row2_col6, #T_9c99c_row2_col7, #T_9c99c_row2_col8, #T_9c99c_row2_col9, #T_9c99c_row2_col10, #T_9c99c_row2_col11, #T_9c99c_row2_col12 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_9c99c_row3_col7 {
#   background-color: #fbfed2;
#   color: #000000;
# }
# </style>
# <table id="T_9c99c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c99c_level0_col0" class="col_heading level0 col0" >MV</th>
#       <th id="T_9c99c_level0_col1" class="col_heading level0 col1" >MAD</th>
#       <th id="T_9c99c_level0_col2" class="col_heading level0 col2" >MSV</th>
#       <th id="T_9c99c_level0_col3" class="col_heading level0 col3" >FLPM</th>
#       <th id="T_9c99c_level0_col4" class="col_heading level0 col4" >SLPM</th>
#       <th id="T_9c99c_level0_col5" class="col_heading level0 col5" >CVaR</th>
#       <th id="T_9c99c_level0_col6" class="col_heading level0 col6" >EVaR</th>
#       <th id="T_9c99c_level0_col7" class="col_heading level0 col7" >WR</th>
#       <th id="T_9c99c_level0_col8" class="col_heading level0 col8" >MDD</th>
#       <th id="T_9c99c_level0_col9" class="col_heading level0 col9" >ADD</th>
#       <th id="T_9c99c_level0_col10" class="col_heading level0 col10" >CDaR</th>
#       <th id="T_9c99c_level0_col11" class="col_heading level0 col11" >UCI</th>
#       <th id="T_9c99c_level0_col12" class="col_heading level0 col12" >EDaR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c99c_level0_row0" class="row_heading level0 row0" >VALE3.SA</th>
#       <td id="T_9c99c_row0_col0" class="data row0 col0" >20.95%</td>
#       <td id="T_9c99c_row0_col1" class="data row0 col1" >24.91%</td>
#       <td id="T_9c99c_row0_col2" class="data row0 col2" >33.46%</td>
#       <td id="T_9c99c_row0_col3" class="data row0 col3" >27.76%</td>
#       <td id="T_9c99c_row0_col4" class="data row0 col4" >33.71%</td>
#       <td id="T_9c99c_row0_col5" class="data row0 col5" >35.45%</td>
#       <td id="T_9c99c_row0_col6" class="data row0 col6" >43.99%</td>
#       <td id="T_9c99c_row0_col7" class="data row0 col7" >40.62%</td>
#       <td id="T_9c99c_row0_col8" class="data row0 col8" >28.41%</td>
#       <td id="T_9c99c_row0_col9" class="data row0 col9" >0.00%</td>
#       <td id="T_9c99c_row0_col10" class="data row0 col10" >28.41%</td>
#       <td id="T_9c99c_row0_col11" class="data row0 col11" >0.11%</td>
#       <td id="T_9c99c_row0_col12" class="data row0 col12" >28.41%</td>
#     </tr>
#     <tr>
#       <th id="T_9c99c_level0_row1" class="row_heading level0 row1" >GGBR3.SA</th>
#       <td id="T_9c99c_row1_col0" class="data row1 col0" >0.00%</td>
#       <td id="T_9c99c_row1_col1" class="data row1 col1" >0.00%</td>
#       <td id="T_9c99c_row1_col2" class="data row1 col2" >0.00%</td>
#       <td id="T_9c99c_row1_col3" class="data row1 col3" >0.00%</td>
#       <td id="T_9c99c_row1_col4" class="data row1 col4" >0.00%</td>
#       <td id="T_9c99c_row1_col5" class="data row1 col5" >0.00%</td>
#       <td id="T_9c99c_row1_col6" class="data row1 col6" >0.00%</td>
#       <td id="T_9c99c_row1_col7" class="data row1 col7" >0.00%</td>
#       <td id="T_9c99c_row1_col8" class="data row1 col8" >0.00%</td>
#       <td id="T_9c99c_row1_col9" class="data row1 col9" >0.00%</td>
#       <td id="T_9c99c_row1_col10" class="data row1 col10" >0.00%</td>
#       <td id="T_9c99c_row1_col11" class="data row1 col11" >0.00%</td>
#       <td id="T_9c99c_row1_col12" class="data row1 col12" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_9c99c_level0_row2" class="row_heading level0 row2" >CSNA3.SA</th>
#       <td id="T_9c99c_row2_col0" class="data row2 col0" >79.05%</td>
#       <td id="T_9c99c_row2_col1" class="data row2 col1" >75.09%</td>
#       <td id="T_9c99c_row2_col2" class="data row2 col2" >66.54%</td>
#       <td id="T_9c99c_row2_col3" class="data row2 col3" >72.24%</td>
#       <td id="T_9c99c_row2_col4" class="data row2 col4" >66.29%</td>
#       <td id="T_9c99c_row2_col5" class="data row2 col5" >64.55%</td>
#       <td id="T_9c99c_row2_col6" class="data row2 col6" >56.01%</td>
#       <td id="T_9c99c_row2_col7" class="data row2 col7" >56.12%</td>
#       <td id="T_9c99c_row2_col8" class="data row2 col8" >71.59%</td>
#       <td id="T_9c99c_row2_col9" class="data row2 col9" >100.00%</td>
#       <td id="T_9c99c_row2_col10" class="data row2 col10" >71.59%</td>
#       <td id="T_9c99c_row2_col11" class="data row2 col11" >99.89%</td>
#       <td id="T_9c99c_row2_col12" class="data row2 col12" >71.59%</td>
#     </tr>
#     <tr>
#       <th id="T_9c99c_level0_row3" class="row_heading level0 row3" >FESA4.SA</th>
#       <td id="T_9c99c_row3_col0" class="data row3 col0" >0.00%</td>
#       <td id="T_9c99c_row3_col1" class="data row3 col1" >0.00%</td>
#       <td id="T_9c99c_row3_col2" class="data row3 col2" >0.00%</td>
#       <td id="T_9c99c_row3_col3" class="data row3 col3" >0.00%</td>
#       <td id="T_9c99c_row3_col4" class="data row3 col4" >0.00%</td>
#       <td id="T_9c99c_row3_col5" class="data row3 col5" >0.00%</td>
#       <td id="T_9c99c_row3_col6" class="data row3 col6" >0.00%</td>
#       <td id="T_9c99c_row3_col7" class="data row3 col7" >3.26%</td>
#       <td id="T_9c99c_row3_col8" class="data row3 col8" >0.00%</td>
#       <td id="T_9c99c_row3_col9" class="data row3 col9" >0.00%</td>
#       <td id="T_9c99c_row3_col10" class="data row3 col10" >0.00%</td>
#       <td id="T_9c99c_row3_col11" class="data row3 col11" >0.00%</td>
#       <td id="T_9c99c_row3_col12" class="data row3 col12" >0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
import riskfolio as rp

# Building the portfolio object
port = rp.Portfolio(returns=Y)

# Calculating optimal portfolio

# Select method and estimate input parameters:

method_mu='hist' # Method to estimate expected returns based on historical data.
method_cov='hist' # Method to estimate covariance matrix based on historical data.

port.assets_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

# Estimate optimal portfolio:

model='Classic' # Could be Classic (historical), BL (Black Litterman) or FM (Factor Model)
rm = 'MV' # Risk measure used, this time will be variance
obj = 'MinRisk' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = True # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
l = 0 # Risk aversion factor, only useful when obj is 'Utility'

w_min_risk = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w_min_risk.T)


# Plotting the composition of the portfolio

ax_min_risk = rp.plot_pie(w=w_min_risk, title='Min risk Variance', others=0.05, nrow=25, cmap = "tab20",
                 height=6, width=10, ax=None)
# Out:
#          VALE3.SA  GGBR3.SA  CSNA3.SA  FESA4.SA
# weights   0.0000%  23.0869%  44.7659%  32.1472%

# %%
# Plotting frontier

points = 50 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)
# display(frontier.T.tail())

# Plotting the efficient frontier

label = 'Min Risk Adjusted Return Portfolio' # Title of point
mu = port.mu # Expected returns
cov = port.cov # Covariance matrix
returns = port.returns # Returns of the assets

ax = rp.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                      rf=rf, alpha=0.05, cmap='viridis', w=w_min_risk, label=label,
                      marker='*', s=16, c='r', height=6, width=10, ax=None)

# %%
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

# %%
# Risk Measures available:
#
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

rms = ['MV', 'MAD', 'MSV', 'FLPM', 'SLPM', 'CVaR',
       'EVaR', 'WR', 'MDD', 'ADD', 'CDaR', 'UCI', 'EDaR']

w_s = pd.DataFrame([])

for i in rms:
    w = port.optimization(model=model, rm=i, obj=obj, rf=rf, l=l, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
    
w_s.columns = rms

w_s.style.format("{:.2%}").background_gradient(cmap='YlGn')
# Out:
# <style type="text/css">
# #T_9f1d5_row0_col0, #T_9f1d5_row0_col1, #T_9f1d5_row0_col2, #T_9f1d5_row0_col3, #T_9f1d5_row0_col4, #T_9f1d5_row0_col5, #T_9f1d5_row0_col6, #T_9f1d5_row0_col7, #T_9f1d5_row0_col8, #T_9f1d5_row0_col9, #T_9f1d5_row0_col10, #T_9f1d5_row0_col11, #T_9f1d5_row0_col12, #T_9f1d5_row3_col9, #T_9f1d5_row3_col11 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_9f1d5_row1_col0 {
#   background-color: #70c275;
#   color: #000000;
# }
# #T_9f1d5_row1_col1 {
#   background-color: #c7e89a;
#   color: #000000;
# }
# #T_9f1d5_row1_col2 {
#   background-color: #b5e092;
#   color: #000000;
# }
# #T_9f1d5_row1_col3 {
#   background-color: #d0ec9f;
#   color: #000000;
# }
# #T_9f1d5_row1_col4 {
#   background-color: #c1e698;
#   color: #000000;
# }
# #T_9f1d5_row1_col5 {
#   background-color: #d6efa2;
#   color: #000000;
# }
# #T_9f1d5_row1_col6, #T_9f1d5_row2_col5 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_9f1d5_row1_col7 {
#   background-color: #5ab76a;
#   color: #f1f1f1;
# }
# #T_9f1d5_row1_col8 {
#   background-color: #056c39;
#   color: #f1f1f1;
# }
# #T_9f1d5_row1_col9, #T_9f1d5_row1_col11, #T_9f1d5_row3_col0 {
#   background-color: #2b8e4a;
#   color: #f1f1f1;
# }
# #T_9f1d5_row1_col10 {
#   background-color: #10743c;
#   color: #f1f1f1;
# }
# #T_9f1d5_row1_col12 {
#   background-color: #0e743c;
#   color: #f1f1f1;
# }
# #T_9f1d5_row2_col0, #T_9f1d5_row2_col1, #T_9f1d5_row2_col2, #T_9f1d5_row2_col3, #T_9f1d5_row2_col4, #T_9f1d5_row2_col6, #T_9f1d5_row2_col7, #T_9f1d5_row2_col8, #T_9f1d5_row2_col9, #T_9f1d5_row2_col10, #T_9f1d5_row2_col11, #T_9f1d5_row2_col12, #T_9f1d5_row3_col5 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_9f1d5_row3_col1 {
#   background-color: #167a3f;
#   color: #f1f1f1;
# }
# #T_9f1d5_row3_col2 {
#   background-color: #004a2b;
#   color: #f1f1f1;
# }
# #T_9f1d5_row3_col3 {
#   background-color: #11753d;
#   color: #f1f1f1;
# }
# #T_9f1d5_row3_col4 {
#   background-color: #005730;
#   color: #f1f1f1;
# }
# #T_9f1d5_row3_col6 {
#   background-color: #066d39;
#   color: #f1f1f1;
# }
# #T_9f1d5_row3_col7 {
#   background-color: #e4f4ab;
#   color: #000000;
# }
# #T_9f1d5_row3_col8 {
#   background-color: #fcfed6;
#   color: #000000;
# }
# #T_9f1d5_row3_col10 {
#   background-color: #f9fdc5;
#   color: #000000;
# }
# #T_9f1d5_row3_col12 {
#   background-color: #f9fdc7;
#   color: #000000;
# }
# </style>
# <table id="T_9f1d5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9f1d5_level0_col0" class="col_heading level0 col0" >MV</th>
#       <th id="T_9f1d5_level0_col1" class="col_heading level0 col1" >MAD</th>
#       <th id="T_9f1d5_level0_col2" class="col_heading level0 col2" >MSV</th>
#       <th id="T_9f1d5_level0_col3" class="col_heading level0 col3" >FLPM</th>
#       <th id="T_9f1d5_level0_col4" class="col_heading level0 col4" >SLPM</th>
#       <th id="T_9f1d5_level0_col5" class="col_heading level0 col5" >CVaR</th>
#       <th id="T_9f1d5_level0_col6" class="col_heading level0 col6" >EVaR</th>
#       <th id="T_9f1d5_level0_col7" class="col_heading level0 col7" >WR</th>
#       <th id="T_9f1d5_level0_col8" class="col_heading level0 col8" >MDD</th>
#       <th id="T_9f1d5_level0_col9" class="col_heading level0 col9" >ADD</th>
#       <th id="T_9f1d5_level0_col10" class="col_heading level0 col10" >CDaR</th>
#       <th id="T_9f1d5_level0_col11" class="col_heading level0 col11" >UCI</th>
#       <th id="T_9f1d5_level0_col12" class="col_heading level0 col12" >EDaR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9f1d5_level0_row0" class="row_heading level0 row0" >VALE3.SA</th>
#       <td id="T_9f1d5_row0_col0" class="data row0 col0" >0.00%</td>
#       <td id="T_9f1d5_row0_col1" class="data row0 col1" >0.00%</td>
#       <td id="T_9f1d5_row0_col2" class="data row0 col2" >0.00%</td>
#       <td id="T_9f1d5_row0_col3" class="data row0 col3" >0.00%</td>
#       <td id="T_9f1d5_row0_col4" class="data row0 col4" >0.00%</td>
#       <td id="T_9f1d5_row0_col5" class="data row0 col5" >0.00%</td>
#       <td id="T_9f1d5_row0_col6" class="data row0 col6" >0.00%</td>
#       <td id="T_9f1d5_row0_col7" class="data row0 col7" >0.00%</td>
#       <td id="T_9f1d5_row0_col8" class="data row0 col8" >0.00%</td>
#       <td id="T_9f1d5_row0_col9" class="data row0 col9" >0.00%</td>
#       <td id="T_9f1d5_row0_col10" class="data row0 col10" >0.00%</td>
#       <td id="T_9f1d5_row0_col11" class="data row0 col11" >0.00%</td>
#       <td id="T_9f1d5_row0_col12" class="data row0 col12" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_9f1d5_level0_row1" class="row_heading level0 row1" >GGBR3.SA</th>
#       <td id="T_9f1d5_row1_col0" class="data row1 col0" >23.09%</td>
#       <td id="T_9f1d5_row1_col1" class="data row1 col1" >14.44%</td>
#       <td id="T_9f1d5_row1_col2" class="data row1 col2" >15.14%</td>
#       <td id="T_9f1d5_row1_col3" class="data row1 col3" >13.17%</td>
#       <td id="T_9f1d5_row1_col4" class="data row1 col4" >14.15%</td>
#       <td id="T_9f1d5_row1_col5" class="data row1 col5" >14.49%</td>
#       <td id="T_9f1d5_row1_col6" class="data row1 col6" >22.20%</td>
#       <td id="T_9f1d5_row1_col7" class="data row1 col7" >31.96%</td>
#       <td id="T_9f1d5_row1_col8" class="data row1 col8" >45.13%</td>
#       <td id="T_9f1d5_row1_col9" class="data row1 col9" >41.74%</td>
#       <td id="T_9f1d5_row1_col10" class="data row1 col10" >42.78%</td>
#       <td id="T_9f1d5_row1_col11" class="data row1 col11" >41.74%</td>
#       <td id="T_9f1d5_row1_col12" class="data row1 col12" >43.05%</td>
#     </tr>
#     <tr>
#       <th id="T_9f1d5_level0_row2" class="row_heading level0 row2" >CSNA3.SA</th>
#       <td id="T_9f1d5_row2_col0" class="data row2 col0" >44.77%</td>
#       <td id="T_9f1d5_row2_col1" class="data row2 col1" >47.72%</td>
#       <td id="T_9f1d5_row2_col2" class="data row2 col2" >42.92%</td>
#       <td id="T_9f1d5_row2_col3" class="data row2 col3" >47.86%</td>
#       <td id="T_9f1d5_row2_col4" class="data row2 col4" >44.33%</td>
#       <td id="T_9f1d5_row2_col5" class="data row2 col5" >29.59%</td>
#       <td id="T_9f1d5_row2_col6" class="data row2 col6" >42.02%</td>
#       <td id="T_9f1d5_row2_col7" class="data row2 col7" >56.38%</td>
#       <td id="T_9f1d5_row2_col8" class="data row2 col8" >52.52%</td>
#       <td id="T_9f1d5_row2_col9" class="data row2 col9" >58.26%</td>
#       <td id="T_9f1d5_row2_col10" class="data row2 col10" >52.32%</td>
#       <td id="T_9f1d5_row2_col11" class="data row2 col11" >58.26%</td>
#       <td id="T_9f1d5_row2_col12" class="data row2 col12" >52.31%</td>
#     </tr>
#     <tr>
#       <th id="T_9f1d5_level0_row3" class="row_heading level0 row3" >FESA4.SA</th>
#       <td id="T_9f1d5_row3_col0" class="data row3 col0" >32.15%</td>
#       <td id="T_9f1d5_row3_col1" class="data row3 col1" >37.84%</td>
#       <td id="T_9f1d5_row3_col2" class="data row3 col2" >41.94%</td>
#       <td id="T_9f1d5_row3_col3" class="data row3 col3" >38.97%</td>
#       <td id="T_9f1d5_row3_col4" class="data row3 col4" >41.51%</td>
#       <td id="T_9f1d5_row3_col5" class="data row3 col5" >55.92%</td>
#       <td id="T_9f1d5_row3_col6" class="data row3 col6" >35.79%</td>
#       <td id="T_9f1d5_row3_col7" class="data row3 col7" >11.66%</td>
#       <td id="T_9f1d5_row3_col8" class="data row3 col8" >2.35%</td>
#       <td id="T_9f1d5_row3_col9" class="data row3 col9" >0.00%</td>
#       <td id="T_9f1d5_row3_col10" class="data row3 col10" >4.90%</td>
#       <td id="T_9f1d5_row3_col11" class="data row3 col11" >0.00%</td>
#       <td id="T_9f1d5_row3_col12" class="data row3 col12" >4.64%</td>
#     </tr>
#   </tbody>
# </table>
