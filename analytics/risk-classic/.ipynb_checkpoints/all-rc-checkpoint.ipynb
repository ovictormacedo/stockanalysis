# %%
import numpy as np
import pandas as pd
import yfinance as yf
import warnings
import json

warnings.filterwarnings("ignore")
pd.options.display.float_format = '{:.4%}'.format

params = json.loads(open('../params.json', 'r').read())

# Date range
start = "2022-02-06"
end = "2024-02-06"

# Tickers of assets
industry_asset = json.loads(open('../stocks.json', 'r').read())
assets = []
for key, values in industry_asset.items():
    for value in values:
        assets.append(value)

# Downloading data
data = yf.download(assets, start = start, end = end)

data = data.loc[:,('Adj Close', slice(None))]

data.columns = assets
# Out:
# [*********************100%%**********************]  23 of 23 completed

# %%
# Calculating returns
Y = data[assets].pct_change().dropna()

display(Y.tail())
# Out:
#             TIMS3.SA  VIVT3.SA  SUZB3.SA  KLBN11.SA  CSAN3.SA  VBBR3.SA  \
# Date
# 2024-01-30  -0.8856%   0.1997%  -2.1038%    0.0548%  -0.9403%  -0.7426%
# 2024-01-31   0.0000%  -0.3322%   1.2001%    0.0548%  -1.0050%   1.1970%
# 2024-02-01   1.5120%   1.1333%   0.5240%    1.5873%  -0.9024%  -0.8625%
# 2024-02-02  -1.2525%  -0.5933%  -2.2497%   -3.2866%  -2.5612%  -1.3174%
# 2024-02-05   0.3085%   0.3979%   0.7859%    0.7799%   1.4603%   1.2594%
#
#             PRIO3.SA  UGPA3.SA  ENAT3.SA  PETR3.SA  ...  ALUP11.SA  CPFE3.SA  \
# Date                                                ...
# 2024-01-30  -1.6149%  -2.6777%  -0.5142%  -1.7619%  ...   -0.7428%  -0.4485%
# 2024-01-31   1.4922%   0.1058%   0.6163%   2.4877%  ...   -0.4209%  -0.0237%
# 2024-02-01   1.9358%  -0.7400%   0.9682%   1.1290%  ...   -0.8924%   1.8975%
# 2024-02-02  -2.2836%  -0.4260%  -0.6262%  -1.3955%  ...   -0.4265%  -1.4665%
# 2024-02-05   0.4428%   0.5348%  -0.3938%  -0.3680%  ...    0.8567%   0.0000%
#
#             CMIG3.SA  ELET3.SA  EQTL3.SA  EGIE3.SA  VALE3.SA  GGBR3.SA  \
# Date
# 2024-01-30  -1.4969%   2.5591%  -0.9247%  -1.7182%  -0.3938%  -0.5638%
# 2024-01-31  -0.3629%  -0.9213%   0.0000%   1.0490%   1.2581%  -1.4830%
# 2024-02-01  -1.7755%  -1.0074%   1.6195%   1.9031%   1.0295%  -0.4575%
# 2024-02-02  -1.6222%   0.4697%  -1.3236%   0.1698%  -2.8812%  -2.0311%
# 2024-02-05  -0.9423%   0.7986%  -0.6570%   1.0734%   1.9537%  -0.8626%
#
#             CSNA3.SA  FESA4.SA
# Date
# 2024-01-30   1.4342%  -0.1962%
# 2024-01-31   1.7566%   0.9434%
# 2024-02-01  -1.1368%   2.0639%
# 2024-02-02  -0.6388%  -0.0191%
# 2024-02-05   1.4145%   0.8968%
#
# [5 rows x 23 columns]

# %%
import riskfolio as rp

# Building the portfolio object
port = rp.Portfolio(returns=Y)

# Calculating optimal portfolio

# Select method and estimate input parameters:

method_mu='hist' # Method to estimate expected returns based on historical data.
method_cov='hist' # Method to estimate covariance matrix based on historical data.

port.assets_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

# Estimate optimal portfolio:

model='Classic' # Could be Classic (historical), BL (Black Litterman) or FM (Factor Model)
rm = 'MV' # Risk measure used, this time will be variance
obj = 'Sharpe' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = True # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
l = 0 # Risk aversion factor, only useful when obj is 'Utility'

w_sharpe = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

#display(w_sharpe.T)
keys = w_sharpe.T.keys()
filtered_keys= []
w_sharpe_filtered_weights_raw = []
total_w_sharpe_filtered_weights = 0
for key in keys:
    if w_sharpe.T[key]["weights"] > 0.01:
        filtered_keys.append(key)
        w_sharpe_filtered_weights_raw.append(w_sharpe.T[key]["weights"])
        total_w_sharpe_filtered_weights += w_sharpe.T[key]["weights"]

w_sharpe_filtered_weights = pd.DataFrame([w_sharpe_filtered_weights_raw], columns=filtered_keys)
display(w_sharpe_filtered_weights)
print(f"Total: {total_w_sharpe_filtered_weights*100}")
print(f"Symbols: {[key for key in filtered_keys]}")
    
# Plotting the composition of the portfolio

ax_sharpe = rp.plot_pie(w=w_sharpe, title='Sharpe Mean Variance', others=0.05, nrow=25, cmap = "tab20",
                 height=6, width=10, ax=None)
# Out:
#    TIMS3.SA  PETR3.SA  TAEE11.SA  CPFE3.SA  CMIG3.SA  EGIE3.SA  VALE3.SA
# 0   1.0906%  14.2097%   21.5303%  25.2124%   3.4057%  22.4051%  10.8814%
# Total: 98.73519949467907
# Symbols: ['TIMS3.SA', 'PETR3.SA', 'TAEE11.SA', 'CPFE3.SA', 'CMIG3.SA', 'EGIE3.SA', 'VALE3.SA']

# %%
# Plotting frontier

points = 50 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)
# display(frontier.T.tail())

# Plotting the efficient frontier

label = 'Sharpe Adjusted Return Portfolio' # Title of point
mu = port.mu # Expected returns
cov = port.cov # Covariance matrix
returns = port.returns # Returns of the assets

ax = rp.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                      rf=rf, alpha=0.05, cmap='viridis', w=w_sharpe, label=label,
                      marker='*', s=16, c='r', height=6, width=10, ax=None)

# %%
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

# %%
# Risk Measures available:
#
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

rms = ['MV', 'MAD', 'MSV', 'FLPM', 'SLPM', 'CVaR',
       'EVaR', 'WR', 'MDD', 'ADD', 'CDaR', 'UCI', 'EDaR']

w_s = pd.DataFrame([])

for i in rms:
    w = port.optimization(model=model, rm=i, obj=obj, rf=rf, l=l, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
    
w_s.columns = rms

w_s.style.format("{:.2%}").background_gradient(cmap='YlGn')
# Out:
# <style type="text/css">
# #T_7f97d_row0_col0, #T_7f97d_row18_col1 {
#   background-color: #fcfed6;
#   color: #000000;
# }
# #T_7f97d_row0_col1 {
#   background-color: #feffe2;
#   color: #000000;
# }
# #T_7f97d_row0_col2, #T_7f97d_row0_col3, #T_7f97d_row0_col4, #T_7f97d_row0_col5, #T_7f97d_row0_col8, #T_7f97d_row0_col10, #T_7f97d_row0_col12, #T_7f97d_row1_col1, #T_7f97d_row1_col3, #T_7f97d_row2_col1, #T_7f97d_row2_col3, #T_7f97d_row3_col0, #T_7f97d_row3_col1, #T_7f97d_row3_col2, #T_7f97d_row3_col3, #T_7f97d_row3_col4, #T_7f97d_row3_col5, #T_7f97d_row3_col6, #T_7f97d_row3_col7, #T_7f97d_row3_col8, #T_7f97d_row3_col9, #T_7f97d_row3_col10, #T_7f97d_row3_col11, #T_7f97d_row3_col12, #T_7f97d_row4_col0, #T_7f97d_row4_col1, #T_7f97d_row4_col2, #T_7f97d_row4_col3, #T_7f97d_row4_col4, #T_7f97d_row4_col5, #T_7f97d_row4_col6, #T_7f97d_row4_col7, #T_7f97d_row4_col8, #T_7f97d_row4_col9, #T_7f97d_row4_col10, #T_7f97d_row4_col11, #T_7f97d_row4_col12, #T_7f97d_row5_col0, #T_7f97d_row5_col1, #T_7f97d_row5_col2, #T_7f97d_row5_col3, #T_7f97d_row5_col4, #T_7f97d_row5_col5, #T_7f97d_row5_col6, #T_7f97d_row5_col7, #T_7f97d_row5_col8, #T_7f97d_row5_col9, #T_7f97d_row5_col10, #T_7f97d_row5_col11, #T_7f97d_row5_col12, #T_7f97d_row6_col0, #T_7f97d_row6_col1, #T_7f97d_row6_col2, #T_7f97d_row6_col3, #T_7f97d_row6_col4, #T_7f97d_row6_col5, #T_7f97d_row6_col6, #T_7f97d_row6_col7, #T_7f97d_row6_col8, #T_7f97d_row6_col9, #T_7f97d_row6_col10, #T_7f97d_row6_col11, #T_7f97d_row6_col12, #T_7f97d_row7_col0, #T_7f97d_row7_col1, #T_7f97d_row7_col2, #T_7f97d_row7_col3, #T_7f97d_row7_col4, #T_7f97d_row7_col5, #T_7f97d_row7_col8, #T_7f97d_row7_col9, #T_7f97d_row7_col10, #T_7f97d_row7_col11, #T_7f97d_row7_col12, #T_7f97d_row8_col0, #T_7f97d_row8_col1, #T_7f97d_row8_col2, #T_7f97d_row8_col3, #T_7f97d_row8_col4, #T_7f97d_row8_col5, #T_7f97d_row8_col6, #T_7f97d_row8_col7, #T_7f97d_row8_col8, #T_7f97d_row8_col9, #T_7f97d_row8_col10, #T_7f97d_row8_col11, #T_7f97d_row8_col12, #T_7f97d_row9_col3, #T_7f97d_row9_col7, #T_7f97d_row9_col8, #T_7f97d_row9_col9, #T_7f97d_row9_col10, #T_7f97d_row9_col12, #T_7f97d_row10_col0, #T_7f97d_row10_col1, #T_7f97d_row10_col2, #T_7f97d_row10_col3, #T_7f97d_row10_col4, #T_7f97d_row10_col5, #T_7f97d_row10_col6, #T_7f97d_row10_col7, #T_7f97d_row11_col0, #T_7f97d_row11_col1, #T_7f97d_row11_col2, #T_7f97d_row11_col3, #T_7f97d_row11_col4, #T_7f97d_row11_col5, #T_7f97d_row11_col6, #T_7f97d_row11_col7, #T_7f97d_row11_col8, #T_7f97d_row11_col10, #T_7f97d_row11_col11, #T_7f97d_row11_col12, #T_7f97d_row13_col0, #T_7f97d_row13_col1, #T_7f97d_row13_col2, #T_7f97d_row13_col3, #T_7f97d_row13_col4, #T_7f97d_row13_col5, #T_7f97d_row13_col6, #T_7f97d_row13_col7, #T_7f97d_row13_col8, #T_7f97d_row13_col9, #T_7f97d_row13_col10, #T_7f97d_row13_col11, #T_7f97d_row13_col12, #T_7f97d_row14_col3, #T_7f97d_row15_col3, #T_7f97d_row15_col5, #T_7f97d_row15_col12, #T_7f97d_row16_col0, #T_7f97d_row16_col1, #T_7f97d_row16_col2, #T_7f97d_row16_col3, #T_7f97d_row16_col4, #T_7f97d_row16_col8, #T_7f97d_row16_col9, #T_7f97d_row16_col10, #T_7f97d_row16_col11, #T_7f97d_row16_col12, #T_7f97d_row17_col0, #T_7f97d_row17_col1, #T_7f97d_row17_col2, #T_7f97d_row17_col3, #T_7f97d_row17_col4, #T_7f97d_row17_col5, #T_7f97d_row17_col6, #T_7f97d_row17_col7, #T_7f97d_row17_col8, #T_7f97d_row17_col9, #T_7f97d_row17_col10, #T_7f97d_row17_col11, #T_7f97d_row17_col12, #T_7f97d_row18_col3, #T_7f97d_row19_col3, #T_7f97d_row20_col0, #T_7f97d_row20_col1, #T_7f97d_row20_col2, #T_7f97d_row20_col3, #T_7f97d_row20_col4, #T_7f97d_row20_col5, #T_7f97d_row20_col6, #T_7f97d_row20_col7, #T_7f97d_row20_col8, #T_7f97d_row20_col9, #T_7f97d_row20_col10, #T_7f97d_row20_col11, #T_7f97d_row20_col12, #T_7f97d_row21_col0, #T_7f97d_row21_col1, #T_7f97d_row21_col2, #T_7f97d_row21_col3, #T_7f97d_row21_col4, #T_7f97d_row21_col5, #T_7f97d_row21_col6, #T_7f97d_row21_col7, #T_7f97d_row21_col8, #T_7f97d_row21_col9, #T_7f97d_row21_col10, #T_7f97d_row21_col11, #T_7f97d_row21_col12, #T_7f97d_row22_col0, #T_7f97d_row22_col1, #T_7f97d_row22_col2, #T_7f97d_row22_col3, #T_7f97d_row22_col4, #T_7f97d_row22_col5, #T_7f97d_row22_col6, #T_7f97d_row22_col7, #T_7f97d_row22_col8, #T_7f97d_row22_col9, #T_7f97d_row22_col10, #T_7f97d_row22_col1 ...
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_7f97d_row0_col6 {
#   background-color: #f4fbb7;
#   color: #000000;
# }
# #T_7f97d_row0_col7 {
#   background-color: #dbf1a4;
#   color: #000000;
# }
# #T_7f97d_row0_col9 {
#   background-color: #a2d88a;
#   color: #000000;
# }
# #T_7f97d_row0_col11 {
#   background-color: #f8fcbd;
#   color: #000000;
# }
# #T_7f97d_row1_col0 {
#   background-color: #fdfed9;
#   color: #000000;
# }
# #T_7f97d_row1_col2 {
#   background-color: #f7fcb9;
#   color: #000000;
# }
# #T_7f97d_row1_col4 {
#   background-color: #f2fab5;
#   color: #000000;
# }
# #T_7f97d_row1_col5 {
#   background-color: #b6e192;
#   color: #000000;
# }
# #T_7f97d_row1_col6, #T_7f97d_row18_col12 {
#   background-color: #ecf7b1;
#   color: #000000;
# }
# #T_7f97d_row1_col7 {
#   background-color: #e1f3a9;
#   color: #000000;
# }
# #T_7f97d_row1_col8 {
#   background-color: #4ab062;
#   color: #f1f1f1;
# }
# #T_7f97d_row1_col9 {
#   background-color: #c4e799;
#   color: #000000;
# }
# #T_7f97d_row1_col10 {
#   background-color: #2e924c;
#   color: #f1f1f1;
# }
# #T_7f97d_row1_col11 {
#   background-color: #90d083;
#   color: #000000;
# }
# #T_7f97d_row1_col12, #T_7f97d_row14_col4 {
#   background-color: #3aa257;
#   color: #f1f1f1;
# }
# #T_7f97d_row2_col0, #T_7f97d_row9_col1, #T_7f97d_row15_col1, #T_7f97d_row15_col8 {
#   background-color: #feffe1;
#   color: #000000;
# }
# #T_7f97d_row2_col2, #T_7f97d_row2_col4 {
#   background-color: #fbfed0;
#   color: #000000;
# }
# #T_7f97d_row2_col5, #T_7f97d_row7_col6 {
#   background-color: #e2f4aa;
#   color: #000000;
# }
# #T_7f97d_row2_col6 {
#   background-color: #5fba6c;
#   color: #f1f1f1;
# }
# #T_7f97d_row2_col7, #T_7f97d_row12_col1, #T_7f97d_row12_col2, #T_7f97d_row12_col3, #T_7f97d_row12_col4, #T_7f97d_row12_col8, #T_7f97d_row12_col9, #T_7f97d_row12_col10, #T_7f97d_row12_col11, #T_7f97d_row12_col12, #T_7f97d_row14_col0, #T_7f97d_row18_col5, #T_7f97d_row18_col6 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_7f97d_row2_col8, #T_7f97d_row9_col2 {
#   background-color: #c9e99c;
#   color: #000000;
# }
# #T_7f97d_row2_col9 {
#   background-color: #f1fab5;
#   color: #000000;
# }
# #T_7f97d_row2_col10 {
#   background-color: #d9f0a3;
#   color: #000000;
# }
# #T_7f97d_row2_col11 {
#   background-color: #d5eea1;
#   color: #000000;
# }
# #T_7f97d_row2_col12, #T_7f97d_row14_col10 {
#   background-color: #d6efa2;
#   color: #000000;
# }
# #T_7f97d_row7_col7, #T_7f97d_row15_col10 {
#   background-color: #f9fdc7;
#   color: #000000;
# }
# #T_7f97d_row9_col0, #T_7f97d_row18_col2 {
#   background-color: #5cb86b;
#   color: #f1f1f1;
# }
# #T_7f97d_row9_col4 {
#   background-color: #c8e99b;
#   color: #000000;
# }
# #T_7f97d_row9_col5 {
#   background-color: #e0f3a8;
#   color: #000000;
# }
# #T_7f97d_row9_col6 {
#   background-color: #8ed082;
#   color: #000000;
# }
# #T_7f97d_row9_col11 {
#   background-color: #ffffe4;
#   color: #000000;
# }
# #T_7f97d_row10_col8 {
#   background-color: #88cd7f;
#   color: #000000;
# }
# #T_7f97d_row10_col9 {
#   background-color: #86cc7f;
#   color: #000000;
# }
# #T_7f97d_row10_col10 {
#   background-color: #68be71;
#   color: #000000;
# }
# #T_7f97d_row10_col11 {
#   background-color: #3fa85b;
#   color: #f1f1f1;
# }
# #T_7f97d_row10_col12 {
#   background-color: #66bd70;
#   color: #f1f1f1;
# }
# #T_7f97d_row11_col9 {
#   background-color: #fafdcb;
#   color: #000000;
# }
# #T_7f97d_row12_col0 {
#   background-color: #066d39;
#   color: #f1f1f1;
# }
# #T_7f97d_row12_col5 {
#   background-color: #016937;
#   color: #f1f1f1;
# }
# #T_7f97d_row12_col6 {
#   background-color: #329850;
#   color: #f1f1f1;
# }
# #T_7f97d_row12_col7 {
#   background-color: #81ca7d;
#   color: #000000;
# }
# #T_7f97d_row14_col1 {
#   background-color: #fcfed4;
#   color: #000000;
# }
# #T_7f97d_row14_col2 {
#   background-color: #45ad5f;
#   color: #f1f1f1;
# }
# #T_7f97d_row14_col5 {
#   background-color: #1e8041;
#   color: #f1f1f1;
# }
# #T_7f97d_row14_col6 {
#   background-color: #1a7d40;
#   color: #f1f1f1;
# }
# #T_7f97d_row14_col7 {
#   background-color: #77c679;
#   color: #000000;
# }
# #T_7f97d_

# %%
import riskfolio as rp

# Building the portfolio object
port = rp.Portfolio(returns=Y)

# Calculating optimal portfolio

# Select method and estimate input parameters:

method_mu='hist' # Method to estimate expected returns based on historical data.
method_cov='hist' # Method to estimate covariance matrix based on historical data.

port.assets_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

# Estimate optimal portfolio:

model='Classic' # Could be Classic (historical), BL (Black Litterman) or FM (Factor Model)
rm = 'MV' # Risk measure used, this time will be variance
obj = 'MinRisk' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = True # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
l = 0 # Risk aversion factor, only useful when obj is 'Utility'

w_min_risk = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

# display(w_min_risk.T)

keys = w_min_risk.T.keys()
filtered_keys= []
w_min_risk_filtered_weights_raw = []
total_w_min_risk_filtered_weights = 0
for key in keys:
    if w_min_risk.T[key]["weights"] > 0.01:
        filtered_keys.append(key)
        w_min_risk_filtered_weights_raw.append(w_min_risk.T[key]["weights"])
        total_w_min_risk_filtered_weights += w_min_risk.T[key]["weights"]

w_min_risk_filtered_weights = pd.DataFrame([w_min_risk_filtered_weights_raw], columns=filtered_keys)
display(w_min_risk_filtered_weights)
print(f"Total: {total_w_min_risk_filtered_weights*100}")
print(f"Symbols: {[key for key in filtered_keys]}")


# Plotting the composition of the portfolio

ax_min_risk = rp.plot_pie(w=w_min_risk, title='Min risk Variance', others=0.05, nrow=25, cmap = "tab20",
                 height=6, width=10, ax=None)
# Out:
#    TIMS3.SA  VBBR3.SA  TAEE11.SA  ALUP11.SA  CPFE3.SA  ELET3.SA  EQTL3.SA  \
# 0   9.2778%  13.6420%    7.9111%    3.3658%   3.1952%  11.3652%  25.7759%
#
#    EGIE3.SA  GGBR3.SA  FESA4.SA
# 0   7.7325%   6.8984%  10.2597%
# Total: 99.42365166074117
# Symbols: ['TIMS3.SA', 'VBBR3.SA', 'TAEE11.SA', 'ALUP11.SA', 'CPFE3.SA', 'ELET3.SA', 'EQTL3.SA', 'EGIE3.SA', 'GGBR3.SA', 'FESA4.SA']

# %%
# Plotting frontier

points = 50 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)
# display(frontier.T.tail())

# Plotting the efficient frontier

label = 'Max Risk Adjusted Return Portfolio' # Title of point
mu = port.mu # Expected returns
cov = port.cov # Covariance matrix
returns = port.returns # Returns of the assets

ax = rp.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                      rf=rf, alpha=0.05, cmap='viridis', w=w_min_risk, label=label,
                      marker='*', s=16, c='r', height=6, width=10, ax=None)

# %%
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

# %%
# Risk Measures available:
#
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

rms = ['MV', 'MAD', 'MSV', 'FLPM', 'SLPM', 'CVaR',
       'EVaR', 'WR', 'MDD', 'ADD', 'CDaR', 'UCI', 'EDaR']

w_s = pd.DataFrame([])

for i in rms:
    w = port.optimization(model=model, rm=i, obj=obj, rf=rf, l=l, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
    
w_s.columns = rms

w_s.style.format("{:.2%}").background_gradient(cmap='YlGn')
# Out:
# <style type="text/css">
# #T_5a8fc_row0_col0 {
#   background-color: #b2df90;
#   color: #000000;
# }
# #T_5a8fc_row0_col1 {
#   background-color: #fbfdcf;
#   color: #000000;
# }
# #T_5a8fc_row0_col2 {
#   background-color: #7cc87b;
#   color: #000000;
# }
# #T_5a8fc_row0_col3, #T_5a8fc_row0_col8, #T_5a8fc_row0_col10, #T_5a8fc_row0_col12, #T_5a8fc_row1_col0, #T_5a8fc_row1_col1, #T_5a8fc_row1_col3, #T_5a8fc_row2_col0, #T_5a8fc_row2_col1, #T_5a8fc_row2_col2, #T_5a8fc_row2_col3, #T_5a8fc_row2_col4, #T_5a8fc_row2_col5, #T_5a8fc_row2_col6, #T_5a8fc_row2_col7, #T_5a8fc_row2_col8, #T_5a8fc_row2_col10, #T_5a8fc_row2_col12, #T_5a8fc_row3_col0, #T_5a8fc_row3_col1, #T_5a8fc_row3_col2, #T_5a8fc_row3_col3, #T_5a8fc_row3_col4, #T_5a8fc_row3_col5, #T_5a8fc_row3_col6, #T_5a8fc_row3_col7, #T_5a8fc_row3_col8, #T_5a8fc_row3_col9, #T_5a8fc_row3_col10, #T_5a8fc_row3_col11, #T_5a8fc_row3_col12, #T_5a8fc_row4_col0, #T_5a8fc_row4_col1, #T_5a8fc_row4_col2, #T_5a8fc_row4_col3, #T_5a8fc_row4_col4, #T_5a8fc_row4_col5, #T_5a8fc_row4_col6, #T_5a8fc_row4_col7, #T_5a8fc_row4_col8, #T_5a8fc_row4_col9, #T_5a8fc_row4_col10, #T_5a8fc_row4_col11, #T_5a8fc_row4_col12, #T_5a8fc_row5_col3, #T_5a8fc_row6_col0, #T_5a8fc_row6_col1, #T_5a8fc_row6_col2, #T_5a8fc_row6_col3, #T_5a8fc_row6_col4, #T_5a8fc_row6_col5, #T_5a8fc_row6_col6, #T_5a8fc_row6_col7, #T_5a8fc_row6_col9, #T_5a8fc_row6_col11, #T_5a8fc_row7_col0, #T_5a8fc_row7_col1, #T_5a8fc_row7_col2, #T_5a8fc_row7_col3, #T_5a8fc_row7_col4, #T_5a8fc_row7_col5, #T_5a8fc_row7_col6, #T_5a8fc_row7_col7, #T_5a8fc_row7_col8, #T_5a8fc_row7_col9, #T_5a8fc_row7_col10, #T_5a8fc_row7_col11, #T_5a8fc_row7_col12, #T_5a8fc_row8_col0, #T_5a8fc_row8_col1, #T_5a8fc_row8_col2, #T_5a8fc_row8_col3, #T_5a8fc_row8_col4, #T_5a8fc_row8_col8, #T_5a8fc_row8_col9, #T_5a8fc_row8_col10, #T_5a8fc_row8_col11, #T_5a8fc_row8_col12, #T_5a8fc_row9_col0, #T_5a8fc_row9_col1, #T_5a8fc_row9_col2, #T_5a8fc_row9_col3, #T_5a8fc_row9_col4, #T_5a8fc_row9_col7, #T_5a8fc_row9_col8, #T_5a8fc_row9_col9, #T_5a8fc_row9_col10, #T_5a8fc_row9_col11, #T_5a8fc_row9_col12, #T_5a8fc_row10_col0, #T_5a8fc_row10_col1, #T_5a8fc_row10_col2, #T_5a8fc_row10_col3, #T_5a8fc_row10_col4, #T_5a8fc_row10_col5, #T_5a8fc_row10_col6, #T_5a8fc_row10_col7, #T_5a8fc_row11_col1, #T_5a8fc_row11_col2, #T_5a8fc_row11_col3, #T_5a8fc_row11_col4, #T_5a8fc_row11_col5, #T_5a8fc_row13_col3, #T_5a8fc_row13_col8, #T_5a8fc_row13_col9, #T_5a8fc_row13_col10, #T_5a8fc_row13_col11, #T_5a8fc_row13_col12, #T_5a8fc_row14_col3, #T_5a8fc_row14_col5, #T_5a8fc_row14_col6, #T_5a8fc_row14_col7, #T_5a8fc_row15_col0, #T_5a8fc_row15_col1, #T_5a8fc_row15_col2, #T_5a8fc_row15_col3, #T_5a8fc_row15_col4, #T_5a8fc_row15_col5, #T_5a8fc_row15_col6, #T_5a8fc_row15_col7, #T_5a8fc_row15_col8, #T_5a8fc_row15_col9, #T_5a8fc_row15_col10, #T_5a8fc_row15_col11, #T_5a8fc_row15_col12, #T_5a8fc_row16_col3, #T_5a8fc_row16_col8, #T_5a8fc_row17_col3, #T_5a8fc_row17_col6, #T_5a8fc_row17_col7, #T_5a8fc_row18_col3, #T_5a8fc_row18_col8, #T_5a8fc_row19_col0, #T_5a8fc_row19_col1, #T_5a8fc_row19_col2, #T_5a8fc_row19_col3, #T_5a8fc_row19_col4, #T_5a8fc_row19_col5, #T_5a8fc_row19_col6, #T_5a8fc_row19_col7, #T_5a8fc_row19_col10, #T_5a8fc_row19_col12, #T_5a8fc_row20_col3, #T_5a8fc_row20_col8, #T_5a8fc_row20_col9, #T_5a8fc_row20_col10, #T_5a8fc_row20_col11, #T_5a8fc_row20_col12, #T_5a8fc_row21_col0, #T_5a8fc_row21_col1, #T_5a8fc_row21_col2, #T_5a8fc_row21_col3, #T_5a8fc_row21_col4, #T_5a8fc_row21_col5, #T_5a8fc_row21_col6, #T_5a8fc_row21_col7, #T_5a8fc_row21_col8, #T_5a8fc_row21_col9, #T_5a8fc_row21_col10, #T_5a8fc_row21_col11, #T_5a8fc_row21_col12, #T_5a8fc_row22_col3, #T_5a8fc_row22_col7, #T_5a8fc_row22_col8, #T_5a8fc_row22_col9, #T_5a8fc_row22_col10, #T_5a8fc_row22_col11, #T_5a8fc_row22_col12 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_5a8fc_row0_col4 {
#   background-color: #4cb063;
#   color: #f1f1f1;
# }
# #T_5a8fc_row0_col5 {
#   background-color: #bce395;
#   color: #000000;
# }
# #T_5a8fc_row0_col6, #T_5a8fc_row0_col7, #T_5a8fc_row5_col5, #T_5a8fc_row5_col8, #T_5a8fc_row12_col1, #T_5a8fc_row12_col3, #T_5a8fc_row12_col9, #T_5a8fc_row12_col10, #T_5a8fc_row12_col11, #T_5a8fc_row12_col12, #T_5a8fc_row17_col0, #T_5a8fc_row17_col2, #T_5a8fc_row17_col4 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_5a8fc_row0_col9 {
#   background-color: #8dcf81;
#   color: #000000;
# }
# #T_5a8fc_row0_col11 {
#   background-color: #f4fbb7;
#   color: #000000;
# }
# #T_5a8fc_row1_col2 {
#   background-color: #feffdf;
#   color: #000000;
# }
# #T_5a8fc_row1_col4, #T_5a8fc_row1_col5, #T_5a8fc_row11_col12, #T_5a8fc_row18_col1 {
#   background-color: #fbfed2;
#   color: #000000;
# }
# #T_5a8fc_row1_col6 {
#   background-color: #f3fab6;
#   color: #000000;
# }
# #T_5a8fc_row1_col7 {
#   background-color: #f9fdc5;
#   color: #000000;
# }
# #T_5a8fc_row1_col8 {
#   background-color: #b3e091;
#   color: #000000;
# }
# #T_5a8fc_row1_col9 {
#   background-color: #e2f4aa;
#   color: #000000;
# }
# #T_5a8fc_row1_col10, #T_5a8fc_row13_col4 {
#   background-color: #b1df90;
#   color: #000000;
# }
# #T_5a8fc_row1_col11, #T_5a8fc_row13_col2 {
#   background-color: #b8e293;
#   color: #000000;
# }
# #T_5a8fc_row1_col12, #T_5a8fc_row16_col5 {
#   background-color: #95d385;
#   color: #000000;
# }
# #T_5a8fc_row2_col9, #T_5a8fc_row14_col0 {
#   background-color: #f7fcba;
#   color: #000000;
# }
# #T_5a8fc_row2_col11, #T_5a8fc_row11_col6 {
#   background-color: #eff9b3;
#   color: #000000;
# }
# #T_5a8fc_row5_col0, #T_5a8fc_row16_col6 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_5a8fc_row5_col1, #T_5a8fc_row13_col0 {
#   background-color: #f6fcb8;
#   color: #000000;
# }
# #T_5a8fc_row5_col2 {
#   background-color: #31974f;
#   color: #f1f1f1;
# }
# #T_5a8fc_row5_col4 {
#   background-color: #2e924c;
#   color: #f1f1f1;
# }
# #T_5a8fc_row5_col6 {
#   background-color: #53b466;
#   color: #f1f1f1;
# }
# #T_5a8fc_row5_col7, #T_5a8fc_row9_col5 {
#   background-color: #fdfed9;
#   color: #000000;
# }
# #T_5a8fc_row5_col9 {
#   background-color: #298c48;
#   color: #f1f1f1;
# }
# #T_5a8fc_row5_col10 {
#   background-color: #006335;
#   color: #f1f1f1;
# }
# #T_5a8fc_row5_col11 {
#   background-color: #086e3a;
#   color: #f1f1f1;
# }
# #T_5a8fc_row5_col12 {
#   background-color: #005c32;
#   color: #f1f1f1;
# }
# #T_5a8fc_row6_col8, #T_5a8fc_row20_col1 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_5a8fc_row6_col10 {
#   background-color: #e5f5ac;
#   color: #000000;
# }
# #T_5a8fc_row6_col12, #T_5a8fc_row11_col10 {
#   background-color: #fcfed4;
#   color: #000000;
# }
# #T_5a8fc_row8_col5 {
#   background-color: #c9e99c;
#   color: #000000;
# }
# #T_5a8fc_row8_col6 {
#   background-color: #61bb6d;
#   color: #f1f1f1;
# }
# #T_5a8fc_row8_col7, #T_5a8fc_row20_col4 {
#   background-color: #bae394;
#   color: #000000;
# }
# #T_5a8fc_row9_col6, #T_5a8fc_row14_col1, #T_5a8fc_row16_col10 {
#   background-color: #fcfed6;
#   color: #000000;
# }
# #T_5a8fc_row10_col8 {
#   background-color: #7fc97c;
#   color: #000000;
# }
# #T_5a8fc_row10_col9 {
#   background-color: #66bd70;
#   color: #f1f1f1;
# }
# #T_5a8fc_row10_col10, #T_5a8fc_row20_col6 {
#   background-color: #208242;
#   color: #f1f1f1;
# }
# #T_5a8fc_row10_col11, #T_5a8fc_row14_col9 {
#   background-color: #5fba6c;
#   color: #f1f1f1;
# }
# #T_5a8fc_row10_col12 {
#   background-color: #1c7e40;
#   color: #f1f1f1;
# }
# #T_5a8fc_row11_col0 {
#   background-color: #feffde;
#   color: #000000;
# }
# #T_5a8fc_row11_col7, #T_5a8fc_row12_col0 {
#   background-color: #c5e89a;
#   color: #000000;
# }
# #T_5a8fc_row11_col8 {
#   background-color: #fafdc8;
#   color: #000000;
# }
# #T_5a8fc_row11_col9, #T_5a8fc_row11_col11 {
#   background-color: #ebf7b0;
#   color: #000000;
# }
# #T_5a8fc_row12_col2 {
#   background-color: #42ab5d;
#   color: #f1f1f1;
# }
# #T_5a8fc_row12_col4 {
#   background-color: #1a7d40;
#   color: #f1f1f1;
# }
# #T_5a8fc_row12_col5 {
#   background-color: #2c8f4b;
#   color: #f1f1f1;
# }
# #T_5a8fc_row12_col6 {
#   background-color: #43ac5e;
#   color: #f1f1f1;
# }
# #T_5a8fc_row12_col7, #T_5a8fc_row18_col10, #T_5a8fc_row20_col7 {
#   background-color: #9dd688;
#   color: #000000;
# }
# #T_5a8fc_row12_col8 {
#   background-color: #13773d;
#   color: #f1f1f1;
# }
# #T_5a8fc_row13_col1 {
#   background-color: #feffe2;
#   color: #000000;
# }
# #T_5a8fc_row13_col5 {
#   background-color: #86cc7f;
#   color: #000
