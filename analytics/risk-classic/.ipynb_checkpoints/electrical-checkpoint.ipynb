# %%
import numpy as np
import pandas as pd
import yfinance as yf
import warnings
import json

warnings.filterwarnings("ignore")
pd.options.display.float_format = '{:.4%}'.format

params = json.loads(open('../params.json', 'r').read())

# Date range
start = params["start_date"]
end = params["end_date"]

# Tickers of assets
OIL = 'Oil gas biofuels, exploration, refining etc'
TELCO = 'Telecommunications'
PULP_PAPER = 'Pulp and Paper'
ELECTRICAL = 'Electrical energy'
MINERALS = 'Minerals'

industry_asset = json.loads(open('../stocks.json', 'r').read())
assets = []
for value in industry_asset[ELECTRICAL]:
    assets.append(value)

# Downloading data
data = yf.download(assets, start = start, end = end)

data = data.loc[:,('Adj Close', slice(None))]

data.columns = assets
# Out:
# [*********************100%%**********************]  9 of 9 completed

# %%
# Calculating returns
Y = data[assets].pct_change().dropna()

display(Y.tail())
# Out:
#             ENGI11.SA  GPAR3.SA  TAEE11.SA  ALUP11.SA  CPFE3.SA  CMIG3.SA  \
# Date
# 2023-10-30   -0.4254%   1.5395%   -1.2549%   -1.5515%   0.0000%  -1.5582%
# 2023-10-31   -0.3204%   1.5161%    1.1800%   -0.1017%   1.4265%   1.0624%
# 2023-11-01    0.8214%   7.0130%    1.5251%    2.2646%   3.4443%   2.7033%
# 2023-11-03    1.5941%   2.1238%    1.7379%    1.6920%   2.3862%   1.1072%
# 2023-11-06    0.8020%   1.0101%    1.1291%    0.0245%   0.5149%   0.6405%
#
#             ELET3.SA  EQTL3.SA  EGIE3.SA
# Date
# 2023-10-30  -2.0677%   0.0000%  -0.6184%
# 2023-10-31   1.0877%   0.0000%   0.1185%
# 2023-11-01   2.0886%   0.0000%   0.5919%
# 2023-11-03   2.0149%  11.1111%   2.1771%
# 2023-11-06   1.1243%   0.0000%   1.3245%

# %%
import riskfolio as rp

# Building the portfolio object
port = rp.Portfolio(returns=Y)

# Calculating optimal portfolio

# Select method and estimate input parameters:

method_mu='hist' # Method to estimate expected returns based on historical data.
method_cov='hist' # Method to estimate covariance matrix based on historical data.

port.assets_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

# Estimate optimal portfolio:

model='Classic' # Could be Classic (historical), BL (Black Litterman) or FM (Factor Model)
rm = 'MV' # Risk measure used, this time will be variance
obj = 'Sharpe' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = True # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
l = 0 # Risk aversion factor, only useful when obj is 'Utility'

w_sharpe = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w_sharpe.T)

# Plotting the composition of the portfolio

ax_sharpe = rp.plot_pie(w=w_sharpe, title='Sharpe Mean Variance', others=0.05, nrow=25, cmap = "tab20",
                 height=6, width=10, ax=None)
# Out:
#          ENGI11.SA  GPAR3.SA  TAEE11.SA  ALUP11.SA  CPFE3.SA  CMIG3.SA  \
# weights   38.6140%   0.0000%    0.0000%   12.2621%   0.0000%   0.0000%
#
#          ELET3.SA  EQTL3.SA  EGIE3.SA
# weights  23.9737%  25.1501%   0.0000%

# %%
# Plotting frontier

points = 50 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)
# display(frontier.T.tail())

# Plotting the efficient frontier

label = 'Sharpe Adjusted Return Portfolio' # Title of point
mu = port.mu # Expected returns
cov = port.cov # Covariance matrix
returns = port.returns # Returns of the assets

ax = rp.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                      rf=rf, alpha=0.05, cmap='viridis', w=w_sharpe, label=label,
                      marker='*', s=16, c='r', height=6, width=10, ax=None)

# %%
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

# %%
# Risk Measures available:
#
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

rms = ['MV', 'MAD', 'MSV', 'FLPM', 'SLPM', 'CVaR',
       'EVaR', 'WR', 'MDD', 'ADD', 'CDaR', 'UCI', 'EDaR']

w_s = pd.DataFrame([])

for i in rms:
    w = port.optimization(model=model, rm=i, obj=obj, rf=rf, l=l, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
    
w_s.columns = rms

w_s.style.format("{:.2%}").background_gradient(cmap='YlGn')
# Out:
# <style type="text/css">
# #T_a3ec3_row0_col0, #T_a3ec3_row0_col2, #T_a3ec3_row0_col4, #T_a3ec3_row0_col5, #T_a3ec3_row0_col8, #T_a3ec3_row0_col10, #T_a3ec3_row0_col12, #T_a3ec3_row3_col6, #T_a3ec3_row6_col7, #T_a3ec3_row7_col1, #T_a3ec3_row7_col3, #T_a3ec3_row7_col9, #T_a3ec3_row7_col11 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_a3ec3_row0_col1 {
#   background-color: #feffde;
#   color: #000000;
# }
# #T_a3ec3_row0_col3, #T_a3ec3_row1_col0, #T_a3ec3_row1_col1, #T_a3ec3_row1_col2, #T_a3ec3_row1_col3, #T_a3ec3_row1_col4, #T_a3ec3_row1_col5, #T_a3ec3_row1_col6, #T_a3ec3_row1_col7, #T_a3ec3_row1_col8, #T_a3ec3_row2_col0, #T_a3ec3_row2_col1, #T_a3ec3_row2_col2, #T_a3ec3_row2_col3, #T_a3ec3_row2_col4, #T_a3ec3_row2_col5, #T_a3ec3_row2_col6, #T_a3ec3_row2_col7, #T_a3ec3_row2_col8, #T_a3ec3_row2_col9, #T_a3ec3_row2_col10, #T_a3ec3_row2_col11, #T_a3ec3_row2_col12, #T_a3ec3_row3_col3, #T_a3ec3_row3_col9, #T_a3ec3_row3_col11, #T_a3ec3_row4_col0, #T_a3ec3_row4_col1, #T_a3ec3_row4_col2, #T_a3ec3_row4_col3, #T_a3ec3_row4_col4, #T_a3ec3_row4_col5, #T_a3ec3_row4_col6, #T_a3ec3_row4_col7, #T_a3ec3_row4_col8, #T_a3ec3_row4_col9, #T_a3ec3_row4_col10, #T_a3ec3_row4_col11, #T_a3ec3_row4_col12, #T_a3ec3_row5_col0, #T_a3ec3_row5_col1, #T_a3ec3_row5_col2, #T_a3ec3_row5_col3, #T_a3ec3_row5_col4, #T_a3ec3_row5_col5, #T_a3ec3_row5_col6, #T_a3ec3_row5_col7, #T_a3ec3_row5_col8, #T_a3ec3_row5_col9, #T_a3ec3_row5_col10, #T_a3ec3_row5_col11, #T_a3ec3_row5_col12, #T_a3ec3_row6_col3, #T_a3ec3_row6_col8, #T_a3ec3_row6_col9, #T_a3ec3_row6_col10, #T_a3ec3_row6_col11, #T_a3ec3_row6_col12, #T_a3ec3_row8_col0, #T_a3ec3_row8_col1, #T_a3ec3_row8_col2, #T_a3ec3_row8_col3, #T_a3ec3_row8_col4, #T_a3ec3_row8_col5, #T_a3ec3_row8_col6, #T_a3ec3_row8_col7, #T_a3ec3_row8_col8, #T_a3ec3_row8_col9, #T_a3ec3_row8_col10, #T_a3ec3_row8_col11, #T_a3ec3_row8_col12 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_a3ec3_row0_col6 {
#   background-color: #004629;
#   color: #f1f1f1;
# }
# #T_a3ec3_row0_col7 {
#   background-color: #12763d;
#   color: #f1f1f1;
# }
# #T_a3ec3_row0_col9 {
#   background-color: #7fc97c;
#   color: #000000;
# }
# #T_a3ec3_row0_col11 {
#   background-color: #006737;
#   color: #f1f1f1;
# }
# #T_a3ec3_row1_col9 {
#   background-color: #f3fab6;
#   color: #000000;
# }
# #T_a3ec3_row1_col10 {
#   background-color: #fbfed2;
#   color: #000000;
# }
# #T_a3ec3_row1_col11 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_a3ec3_row1_col12 {
#   background-color: #fbfdce;
#   color: #000000;
# }
# #T_a3ec3_row3_col0 {
#   background-color: #c1e698;
#   color: #000000;
# }
# #T_a3ec3_row3_col1 {
#   background-color: #ffffe4;
#   color: #000000;
# }
# #T_a3ec3_row3_col2, #T_a3ec3_row3_col4 {
#   background-color: #86cc7f;
#   color: #000000;
# }
# #T_a3ec3_row3_col5 {
#   background-color: #68be71;
#   color: #000000;
# }
# #T_a3ec3_row3_col7 {
#   background-color: #f7fcb9;
#   color: #000000;
# }
# #T_a3ec3_row3_col8 {
#   background-color: #f5fbb8;
#   color: #000000;
# }
# #T_a3ec3_row3_col10 {
#   background-color: #ceeb9e;
#   color: #000000;
# }
# #T_a3ec3_row3_col12 {
#   background-color: #e6f5ac;
#   color: #000000;
# }
# #T_a3ec3_row6_col0 {
#   background-color: #43ac5e;
#   color: #f1f1f1;
# }
# #T_a3ec3_row6_col1 {
#   background-color: #feffe2;
#   color: #000000;
# }
# #T_a3ec3_row6_col2 {
#   background-color: #30954f;
#   color: #f1f1f1;
# }
# #T_a3ec3_row6_col4 {
#   background-color: #31974f;
#   color: #f1f1f1;
# }
# #T_a3ec3_row6_col5 {
#   background-color: #f7fcbc;
#   color: #000000;
# }
# #T_a3ec3_row6_col6 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
# }
# #T_a3ec3_row7_col0 {
#   background-color: #3ba358;
#   color: #f1f1f1;
# }
# #T_a3ec3_row7_col2 {
#   background-color: #00472a;
#   color: #f1f1f1;
# }
# #T_a3ec3_row7_col4 {
#   background-color: #00522e;
#   color: #f1f1f1;
# }
# #T_a3ec3_row7_col5 {
#   background-color: #9ad587;
#   color: #000000;
# }
# #T_a3ec3_row7_col6 {
#   background-color: #379e54;
#   color: #f1f1f1;
# }
# #T_a3ec3_row7_col7 {
#   background-color: #a2d88a;
#   color: #000000;
# }
# #T_a3ec3_row7_col8 {
#   background-color: #1a7d40;
#   color: #f1f1f1;
# }
# #T_a3ec3_row7_col10 {
#   background-color: #69bf72;
#   color: #000000;
# }
# #T_a3ec3_row7_col12 {
#   background-color: #258745;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a3ec3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3ec3_level0_col0" class="col_heading level0 col0" >MV</th>
#       <th id="T_a3ec3_level0_col1" class="col_heading level0 col1" >MAD</th>
#       <th id="T_a3ec3_level0_col2" class="col_heading level0 col2" >MSV</th>
#       <th id="T_a3ec3_level0_col3" class="col_heading level0 col3" >FLPM</th>
#       <th id="T_a3ec3_level0_col4" class="col_heading level0 col4" >SLPM</th>
#       <th id="T_a3ec3_level0_col5" class="col_heading level0 col5" >CVaR</th>
#       <th id="T_a3ec3_level0_col6" class="col_heading level0 col6" >EVaR</th>
#       <th id="T_a3ec3_level0_col7" class="col_heading level0 col7" >WR</th>
#       <th id="T_a3ec3_level0_col8" class="col_heading level0 col8" >MDD</th>
#       <th id="T_a3ec3_level0_col9" class="col_heading level0 col9" >ADD</th>
#       <th id="T_a3ec3_level0_col10" class="col_heading level0 col10" >CDaR</th>
#       <th id="T_a3ec3_level0_col11" class="col_heading level0 col11" >UCI</th>
#       <th id="T_a3ec3_level0_col12" class="col_heading level0 col12" >EDaR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3ec3_level0_row0" class="row_heading level0 row0" >ENGI11.SA</th>
#       <td id="T_a3ec3_row0_col0" class="data row0 col0" >38.61%</td>
#       <td id="T_a3ec3_row0_col1" class="data row0 col1" >2.12%</td>
#       <td id="T_a3ec3_row0_col2" class="data row0 col2" >31.70%</td>
#       <td id="T_a3ec3_row0_col3" class="data row0 col3" >0.00%</td>
#       <td id="T_a3ec3_row0_col4" class="data row0 col4" >32.19%</td>
#       <td id="T_a3ec3_row0_col5" class="data row0 col5" >48.09%</td>
#       <td id="T_a3ec3_row0_col6" class="data row0 col6" >30.21%</td>
#       <td id="T_a3ec3_row0_col7" class="data row0 col7" >34.64%</td>
#       <td id="T_a3ec3_row0_col8" class="data row0 col8" >52.20%</td>
#       <td id="T_a3ec3_row0_col9" class="data row0 col9" >29.64%</td>
#       <td id="T_a3ec3_row0_col10" class="data row0 col10" >53.39%</td>
#       <td id="T_a3ec3_row0_col11" class="data row0 col11" >45.41%</td>
#       <td id="T_a3ec3_row0_col12" class="data row0 col12" >49.87%</td>
#     </tr>
#     <tr>
#       <th id="T_a3ec3_level0_row1" class="row_heading level0 row1" >GPAR3.SA</th>
#       <td id="T_a3ec3_row1_col0" class="data row1 col0" >0.00%</td>
#       <td id="T_a3ec3_row1_col1" class="data row1 col1" >0.00%</td>
#       <td id="T_a3ec3_row1_col2" class="data row1 col2" >0.00%</td>
#       <td id="T_a3ec3_row1_col3" class="data row1 col3" >0.00%</td>
#       <td id="T_a3ec3_row1_col4" class="data row1 col4" >0.00%</td>
#       <td id="T_a3ec3_row1_col5" class="data row1 col5" >0.00%</td>
#       <td id="T_a3ec3_row1_col6" class="data row1 col6" >0.00%</td>
#       <td id="T_a3ec3_row1_col7" class="data row1 col7" >0.00%</td>
#       <td id="T_a3ec3_row1_col8" class="data row1 col8" >0.00%</td>
#       <td id="T_a3ec3_row1_col9" class="data row1 col9" >8.86%</td>
#       <td id="T_a3ec3_row1_col10" class="data row1 col10" >2.92%</td>
#       <td id="T_a3ec3_row1_col11" class="data row1 col11" >2.71%</td>
#       <td id="T_a3ec3_row1_col12" class="data row1 col12" >3.48%</td>
#     </tr>
#     <tr>
#       <th id="T_a3ec3_level0_row2" class="row_heading level0 row2" >TAEE11.SA</th>
#       <td id="T_a3ec3_row2_col0" class="data row2 col0" >0.00%</td>
#       <td id="T_a3ec3_row2_col1" class="data row2 col1" >0.00%</td>
#       <td id="T_a3ec3_row2_col2" class="data row2 col2" >0.00%</td>
#       <td id="T_a3ec3_row2_col3" class="data row2 col3" >0.00%</td>
#       <td id="T_a3ec3_row2_col4" class="data row2 col4" >0.00%</td>
#       <td id="T_a3ec3_row2_col5" class="data row2 col5" >0.00%</td>
#       <td id="T_a3ec3_row2_col6" class="data row2 col6" >0.00%</td>
#       <td id="T_a3ec3_row2_col7" class="data row2 col7" >0.00%</td>
#       <td id="T_a3ec3_row2_col8" class="data row2 col8" >0.00%</td>
#       <td id="T_a3ec3_row2_col9" class="data row2 col9" >0.00%</td>
#       <t

# %%
import riskfolio as rp

# Building the portfolio object
port = rp.Portfolio(returns=Y)

# Calculating optimal portfolio

# Select method and estimate input parameters:

method_mu='hist' # Method to estimate expected returns based on historical data.
method_cov='hist' # Method to estimate covariance matrix based on historical data.

port.assets_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

# Estimate optimal portfolio:

model='Classic' # Could be Classic (historical), BL (Black Litterman) or FM (Factor Model)
rm = 'MV' # Risk measure used, this time will be variance
obj = 'MinRisk' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = True # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
l = 0 # Risk aversion factor, only useful when obj is 'Utility'

w_min_risk = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w_min_risk.T)


# Plotting the composition of the portfolio

ax_min_risk = rp.plot_pie(w=w_min_risk, title='Min risk Variance', others=0.05, nrow=25, cmap = "tab20",
                 height=6, width=10, ax=None)
# Out:
#          ENGI11.SA  GPAR3.SA  TAEE11.SA  ALUP11.SA  CPFE3.SA  CMIG3.SA  \
# weights   11.8879%   4.5071%    0.0000%   29.3115%   0.0000%   0.0000%
#
#          ELET3.SA  EQTL3.SA  EGIE3.SA
# weights   0.0000%  22.1305%  32.1630%

# %%
# Plotting frontier

points = 50 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)
# display(frontier.T.tail())

# Plotting the efficient frontier

label = 'Max Risk Adjusted Return Portfolio' # Title of point
mu = port.mu # Expected returns
cov = port.cov # Covariance matrix
returns = port.returns # Returns of the assets

ax = rp.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                      rf=rf, alpha=0.05, cmap='viridis', w=w_min_risk, label=label,
                      marker='*', s=16, c='r', height=6, width=10, ax=None)

# %%
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

# %%
# Risk Measures available:
#
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

rms = ['MV', 'MAD', 'MSV', 'FLPM', 'SLPM', 'CVaR',
       'EVaR', 'WR', 'MDD', 'ADD', 'CDaR', 'UCI', 'EDaR']

w_s = pd.DataFrame([])

for i in rms:
    w = port.optimization(model=model, rm=i, obj=obj, rf=rf, l=l, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
    
w_s.columns = rms

w_s.style.format("{:.2%}").background_gradient(cmap='YlGn')
# Out:
# <style type="text/css">
# #T_041ca_row0_col0, #T_041ca_row1_col7 {
#   background-color: #afde8f;
#   color: #000000;
# }
# #T_041ca_row0_col1 {
#   background-color: #ffffe4;
#   color: #000000;
# }
# #T_041ca_row0_col2 {
#   background-color: #d2eda0;
#   color: #000000;
# }
# #T_041ca_row0_col3, #T_041ca_row0_col6, #T_041ca_row0_col7, #T_041ca_row1_col1, #T_041ca_row1_col3, #T_041ca_row2_col0, #T_041ca_row2_col1, #T_041ca_row2_col2, #T_041ca_row2_col3, #T_041ca_row2_col4, #T_041ca_row2_col5, #T_041ca_row2_col6, #T_041ca_row2_col7, #T_041ca_row2_col8, #T_041ca_row2_col9, #T_041ca_row2_col10, #T_041ca_row2_col11, #T_041ca_row2_col12, #T_041ca_row3_col3, #T_041ca_row3_col9, #T_041ca_row4_col0, #T_041ca_row4_col1, #T_041ca_row4_col2, #T_041ca_row4_col3, #T_041ca_row4_col4, #T_041ca_row4_col5, #T_041ca_row4_col6, #T_041ca_row4_col7, #T_041ca_row4_col8, #T_041ca_row4_col9, #T_041ca_row4_col10, #T_041ca_row4_col11, #T_041ca_row4_col12, #T_041ca_row5_col0, #T_041ca_row5_col1, #T_041ca_row5_col2, #T_041ca_row5_col3, #T_041ca_row5_col4, #T_041ca_row5_col5, #T_041ca_row5_col7, #T_041ca_row5_col8, #T_041ca_row5_col9, #T_041ca_row5_col10, #T_041ca_row5_col11, #T_041ca_row5_col12, #T_041ca_row6_col0, #T_041ca_row6_col1, #T_041ca_row6_col2, #T_041ca_row6_col3, #T_041ca_row6_col4, #T_041ca_row6_col5, #T_041ca_row6_col6, #T_041ca_row6_col7, #T_041ca_row6_col8, #T_041ca_row6_col9, #T_041ca_row6_col10, #T_041ca_row6_col11, #T_041ca_row6_col12, #T_041ca_row8_col3, #T_041ca_row8_col6, #T_041ca_row8_col7, #T_041ca_row8_col8, #T_041ca_row8_col9, #T_041ca_row8_col10, #T_041ca_row8_col11, #T_041ca_row8_col12 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_041ca_row0_col4 {
#   background-color: #c0e597;
#   color: #000000;
# }
# #T_041ca_row0_col5 {
#   background-color: #2c8f4b;
#   color: #f1f1f1;
# }
# #T_041ca_row0_col8, #T_041ca_row0_col10, #T_041ca_row0_col12, #T_041ca_row3_col4, #T_041ca_row3_col5, #T_041ca_row3_col6, #T_041ca_row3_col7, #T_041ca_row7_col1, #T_041ca_row7_col2, #T_041ca_row7_col3, #T_041ca_row7_col9, #T_041ca_row7_col11, #T_041ca_row8_col0 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_041ca_row0_col9 {
#   background-color: #95d385;
#   color: #000000;
# }
# #T_041ca_row0_col11 {
#   background-color: #68be71;
#   color: #000000;
# }
# #T_041ca_row1_col0 {
#   background-color: #f4fbb7;
#   color: #000000;
# }
# #T_041ca_row1_col2 {
#   background-color: #e3f4aa;
#   color: #000000;
# }
# #T_041ca_row1_col4 {
#   background-color: #e8f6ae;
#   color: #000000;
# }
# #T_041ca_row1_col5 {
#   background-color: #c1e698;
#   color: #000000;
# }
# #T_041ca_row1_col6 {
#   background-color: #c5e89a;
#   color: #000000;
# }
# #T_041ca_row1_col8 {
#   background-color: #cbea9c;
#   color: #000000;
# }
# #T_041ca_row1_col9 {
#   background-color: #edf8b2;
#   color: #000000;
# }
# #T_041ca_row1_col10 {
#   background-color: #f3fab6;
#   color: #000000;
# }
# #T_041ca_row1_col11 {
#   background-color: #eaf7af;
#   color: #000000;
# }
# #T_041ca_row1_col12 {
#   background-color: #e7f6ad;
#   color: #000000;
# }
# #T_041ca_row3_col0, #T_041ca_row7_col12 {
#   background-color: #005d33;
#   color: #f1f1f1;
# }
# #T_041ca_row3_col1 {
#   background-color: #feffde;
#   color: #000000;
# }
# #T_041ca_row3_col2 {
#   background-color: #00482a;
#   color: #f1f1f1;
# }
# #T_041ca_row3_col8, #T_041ca_row8_col2 {
#   background-color: #167a3f;
#   color: #f1f1f1;
# }
# #T_041ca_row3_col10 {
#   background-color: #93d284;
#   color: #000000;
# }
# #T_041ca_row3_col11 {
#   background-color: #fbfdcf;
#   color: #000000;
# }
# #T_041ca_row3_col12 {
#   background-color: #4cb063;
#   color: #f1f1f1;
# }
# #T_041ca_row5_col6 {
#   background-color: #fcfed7;
#   color: #000000;
# }
# #T_041ca_row7_col0 {
#   background-color: #31974f;
#   color: #f1f1f1;
# }
# #T_041ca_row7_col4 {
#   background-color: #005530;
#   color: #f1f1f1;
# }
# #T_041ca_row7_col5 {
#   background-color: #49af61;
#   color: #f1f1f1;
# }
# #T_041ca_row7_col6 {
#   background-color: #88cd7f;
#   color: #000000;
# }
# #T_041ca_row7_col7 {
#   background-color: #72c376;
#   color: #000000;
# }
# #T_041ca_row7_col8 {
#   background-color: #005f34;
#   color: #f1f1f1;
# }
# #T_041ca_row7_col10 {
#   background-color: #218242;
#   color: #f1f1f1;
# }
# #T_041ca_row8_col1 {
#   background-color: #fdfedd;
#   color: #000000;
# }
# #T_041ca_row8_col4 {
#   background-color: #45ad5f;
#   color: #f1f1f1;
# }
# #T_041ca_row8_col5 {
#   background-color: #005a31;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_041ca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_041ca_level0_col0" class="col_heading level0 col0" >MV</th>
#       <th id="T_041ca_level0_col1" class="col_heading level0 col1" >MAD</th>
#       <th id="T_041ca_level0_col2" class="col_heading level0 col2" >MSV</th>
#       <th id="T_041ca_level0_col3" class="col_heading level0 col3" >FLPM</th>
#       <th id="T_041ca_level0_col4" class="col_heading level0 col4" >SLPM</th>
#       <th id="T_041ca_level0_col5" class="col_heading level0 col5" >CVaR</th>
#       <th id="T_041ca_level0_col6" class="col_heading level0 col6" >EVaR</th>
#       <th id="T_041ca_level0_col7" class="col_heading level0 col7" >WR</th>
#       <th id="T_041ca_level0_col8" class="col_heading level0 col8" >MDD</th>
#       <th id="T_041ca_level0_col9" class="col_heading level0 col9" >ADD</th>
#       <th id="T_041ca_level0_col10" class="col_heading level0 col10" >CDaR</th>
#       <th id="T_041ca_level0_col11" class="col_heading level0 col11" >UCI</th>
#       <th id="T_041ca_level0_col12" class="col_heading level0 col12" >EDaR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_041ca_level0_row0" class="row_heading level0 row0" >ENGI11.SA</th>
#       <td id="T_041ca_row0_col0" class="data row0 col0" >11.89%</td>
#       <td id="T_041ca_row0_col1" class="data row0 col1" >0.46%</td>
#       <td id="T_041ca_row0_col2" class="data row0 col2" >8.37%</td>
#       <td id="T_041ca_row0_col3" class="data row0 col3" >0.00%</td>
#       <td id="T_041ca_row0_col4" class="data row0 col4" >10.51%</td>
#       <td id="T_041ca_row0_col5" class="data row0 col5" >19.98%</td>
#       <td id="T_041ca_row0_col6" class="data row0 col6" >0.00%</td>
#       <td id="T_041ca_row0_col7" class="data row0 col7" >0.00%</td>
#       <td id="T_041ca_row0_col8" class="data row0 col8" >33.44%</td>
#       <td id="T_041ca_row0_col9" class="data row0 col9" >27.06%</td>
#       <td id="T_041ca_row0_col10" class="data row0 col10" >42.84%</td>
#       <td id="T_041ca_row0_col11" class="data row0 col11" >30.09%</td>
#       <td id="T_041ca_row0_col12" class="data row0 col12" >37.00%</td>
#     </tr>
#     <tr>
#       <th id="T_041ca_level0_row1" class="row_heading level0 row1" >GPAR3.SA</th>
#       <td id="T_041ca_row1_col0" class="data row1 col0" >4.51%</td>
#       <td id="T_041ca_row1_col1" class="data row1 col1" >0.03%</td>
#       <td id="T_041ca_row1_col2" class="data row1 col2" >6.41%</td>
#       <td id="T_041ca_row1_col3" class="data row1 col3" >0.00%</td>
#       <td id="T_041ca_row1_col4" class="data row1 col4" >6.17%</td>
#       <td id="T_041ca_row1_col5" class="data row1 col5" >8.91%</td>
#       <td id="T_041ca_row1_col6" class="data row1 col6" >16.99%</td>
#       <td id="T_041ca_row1_col7" class="data row1 col7" >19.51%</td>
#       <td id="T_041ca_row1_col8" class="data row1 col8" >9.71%</td>
#       <td id="T_041ca_row1_col9" class="data row1 col9" >10.30%</td>
#       <td id="T_041ca_row1_col10" class="data row1 col10" >6.19%</td>
#       <td id="T_041ca_row1_col11" class="data row1 col11" >10.14%</td>
#       <td id="T_041ca_row1_col12" class="data row1 col12" >7.19%</td>
#     </tr>
#     <tr>
#       <th id="T_041ca_level0_row2" class="row_heading level0 row2" >TAEE11.SA</th>
#       <td id="T_041ca_row2_col0" class="data row2 col0" >0.00%</td>
#       <td id="T_041ca_row2_col1" class="data row2 col1" >0.14%</td>
#       <td id="T_041ca_row2_col2" class="data row2 col2" >0.00%</td>
#       <td id="T_041ca_row2_col3" class="data row2 col3" >0.00%</td>
#       <td id="T_041ca_row2_col4" class="data row2 col4" >0.00%</td>
#       <td id="T_041ca_row2_col5" class="data row2 col5" >0.00%</td>
#       <td id="T_041ca_row2_col6" class="data row2 col6" >0.00%</td>
#       <td id="T_041ca_row2_col7" class="data row2 col7" >0.00
