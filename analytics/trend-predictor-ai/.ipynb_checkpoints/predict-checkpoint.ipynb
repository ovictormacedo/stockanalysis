# %%
import numpy as np
import pandas as pd
import yfinance as yf
import warnings
import json

warnings.filterwarnings("ignore")
pd.options.display.float_format = '{:.4%}'.format

params = json.loads(open('../params.json', 'r').read())

# Date range
start = "2018-01-01"
end = "2023-11-01"

# Tickers of assets
industry_asset = json.loads(open('../stocks.json', 'r').read())
assets = []
for key, values in industry_asset.items():
    for value in values:
        assets.append(value)

# Downloading data
data = yf.download(assets, start=start, end=end, interval="1wk")
# Out:
# [*********************100%%**********************]  23 of 23 completed

# %%
from ta import trend, volume as volume_ta, momentum

THRESHOLD = 10

def get_trend(data_prices, i):
    trend = float(0.5)
    if 100 * (data_prices[i] / data_prices[i-1]) - 100 >= THRESHOLD:
        trend = float(1.0)
    elif 100 * (data_prices[i] / data_prices[i-1]) - 100 <= 0:
        trend = float(0.0)
    return trend

def get_trend_open(data_open, data_close, i):
    trend = float(0.5)
    if 100 * (data_open[i] / data_close[i-1]) - 100 >= THRESHOLD:
        trend = float(1.0)
    elif 100 * (data_open[i] / data_close[i-1]) - 100 <= 0:
        trend = float(0.0)
    return trend

def is_the_last_date(i, size):
    return i == size-1

indicators = {
    asset: {
        "date": [],
        "open": [],
        "close": [],
        "high": [],
        "low": [],
        "volume": [],
        "trend_open": [],
        "trend_close": [],
        "trend_high": [],
        "trend_low": [],
        "next_trend_open": [],
        "next_trend_close": [],
        "next_trend_high": [],
        "next_trend_low": [],
        "aroon": [],
        "aroon_down": [],
        "aroon_up": [],
        "cmf": [],
        "mfi": [],
        "ppo": [],
        "pvo": [],
        "rsi": [],
        "stc": [],
        "volume_rsi": [], 
        "williamsr": []
    }
    for asset in assets
}

dates = [d.to_pydatetime().strftime('%Y-%m-%d %H:%M:%S') for d in data.index]

for asset in assets:
    if int(dates[0][0:4]) > 2018:
        print(f"{int(dates[0][0:4])} is too new, skipping it.")
        continue

    high = data["High"][asset].astype(float)
    low = data["Low"][asset].astype(float)
    open = data["Open"][asset].astype(float)
    close = data["Close"][asset].astype(float)
    volume = data["Volume"][asset].astype(float)

    # AROON indicator
    aroon = trend.AroonIndicator(high, low).aroon_indicator()
    aroon_down = trend.AroonIndicator(high, low).aroon_down()
    aroon_up = trend.AroonIndicator(high, low).aroon_up()

    # CMF indicator
    indicator_calc = volume_ta.ChaikinMoneyFlowIndicator(high, low, close, volume)
    cmf = indicator_calc.chaikin_money_flow()

    # MFI indicator
    mfi = volume_ta.MFIIndicator(high, low, close, volume).money_flow_index()

    # PPO indicator
    indicator_calc = momentum.PercentagePriceOscillator(close)
    ppo = indicator_calc.ppo()

    # PVO indicator
    indicator_calc = momentum.PercentageVolumeOscillator(volume)
    pvo = indicator_calc.pvo()

    # RSI indicator
    rsi = momentum.RSIIndicator(close).rsi()

    # STC indicator
    stc = trend.STCIndicator(close, 12, 5, 3, 3, 3).stc()

    # VOLUME RSI indicator
    volume_rsi = momentum.RSIIndicator(volume).rsi()

    # WILLIAMS R indicator
    williamsr = momentum.WilliamsRIndicator(high, low, close).williams_r()

    data_len = len(williamsr)

    first_not_nan = True
    for i in range(1, data_len):
        if (
            not np.isnan(aroon[i]) and
            not np.isnan(aroon_up[i]) and
            not np.isnan(aroon_down[i]) and
            not np.isnan(cmf[i]) and
            not np.isnan(mfi[i]) and
            not np.isnan(ppo[i]) and
            not np.isnan(pvo[i]) and
            not np.isnan(rsi[i]) and
            not np.isnan(stc[i]) and
            not np.isnan(volume_rsi[i]) and
            not np.isnan(williamsr[i])
        ):
            if first_not_nan:
                first_not_nan = False
                continue

            trend_high = get_trend(high, i)
            trend_low = get_trend(low, i)
            trend_open = get_trend_open(open, close, i)
            trend_close = get_trend(close, i)

            next_trend_high = float(0.0) if is_the_last_date(i, data_len) else get_trend(high, i+1)
            next_trend_low = float(0.0) if is_the_last_date(i, data_len) else get_trend(low, i+1)
            next_trend_open = float(0.0) if is_the_last_date(i, data_len) else get_trend_open(open, close, i+1)
            next_trend_close = float(0.0) if is_the_last_date(i, data_len) else get_trend(close, i+1)

            indicators[asset]["date"].append(dates[i])
            indicators[asset]["high"].append(high[i])
            indicators[asset]["low"].append(low[i])
            indicators[asset]["open"].append(open[i])
            indicators[asset]["close"].append(close[i])
            indicators[asset]["volume"].append(close[i])
            indicators[asset]["aroon"].append(aroon[i])
            indicators[asset]["aroon_down"].append(aroon_down[i])
            indicators[asset]["aroon_up"].append(aroon_up[i])
            indicators[asset]["cmf"].append(cmf[i])
            indicators[asset]["mfi"].append(mfi[i])
            indicators[asset]["ppo"].append(ppo[i])
            indicators[asset]["pvo"].append(pvo[i])
            indicators[asset]["rsi"].append(rsi[i])
            indicators[asset]["stc"].append(stc[i])
            indicators[asset]["volume_rsi"].append(volume_rsi[i])
            indicators[asset]["williamsr"].append(williamsr[i])
            indicators[asset]["trend_high"].append(trend_high)
            indicators[asset]["trend_low"].append(trend_low)
            indicators[asset]["trend_open"].append(trend_open)
            indicators[asset]["trend_close"].append(trend_close)
            indicators[asset]["next_trend_high"].append(next_trend_high)
            indicators[asset]["next_trend_low"].append(next_trend_low)
            indicators[asset]["next_trend_open"].append(next_trend_open)
            indicators[asset]["next_trend_close"].append(next_trend_close)

# %%
from sklearn.preprocessing import MinMaxScaler

indicators_reshaped = {
    asset: {
        "open": [],
        "close": [],
        "high": [],
        "low": [],
        "volume": [],
        "trend_open": [],
        "trend_close": [],
        "trend_high": [],
        "trend_low": [],
        "next_trend_open": [],
        "next_trend_close": [],
        "next_trend_high": [],
        "next_trend_low": [],
        "aroon": [],
        "aroon_down": [],
        "aroon_up": [],
        "cmf": [],
        "mfi": [],
        "ppo": [],
        "pvo": [],
        "rsi": [],
        "stc": [],
        "volume_rsi": [], 
        "williamsr": []
    }
    for asset in assets
}

indicators_scaled = {
    asset: {
        "trend_open": [],
        "trend_close": [],
        "trend_high": [],
        "trend_low": [],
        "aroon": [],
        "aroon_down": [],
        "aroon_up": [],
        "cmf": [],
        "mfi": [],
        "ppo": [],
        "pvo": [],
        "rsi": [],
        "stc": [],
        "volume_rsi": [], 
        "williamsr": []
    }
    for asset in assets
}

indicators_scalers = {
    asset: {
        "trend_open": None,
        "trend_close": None,
        "trend_high": None,
        "trend_low": None,
        "aroon": None,
        "aroon_down": None,
        "aroon_up": None,
        "cmf": None,
        "mfi": None,
        "ppo": None,
        "pvo": None,
        "rsi": None,
        "stc": None,
        "volume_rsi": None, 
        "williamsr": None
    }
    for asset in assets
}

for asset in assets:
    # Reshape data
    for index, row in indicators[asset].items():
        if index not in ["date"]:
            indicators_reshaped[asset][index] = np.array(row)
            indicators_reshaped[asset][index] = indicators_reshaped[asset][index].reshape(-1, 1)

    # Create scalers
    for index, row in indicators_scalers[asset].items():
        indicators_scalers[asset][index] = MinMaxScaler(feature_range=(0, 1))

    # Discretize data
    for index, row in indicators_reshaped[asset].items():
        if index not in ["open", "close", "high", "low", "volume", "next_trend_open", "next_trend_close", "next_trend_high", "next_trend_low"]:
            indicators_scaled[asset][index] = indicators_scalers[asset][index].fit_transform(indicators_reshaped[asset][index])

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1'
import tensorflow as tf

keras = tf.keras

for asset in assets:
    # This is related to the filter about the data being too new (> 2018)
    if len(indicators[asset]["date"]) == 0:
        continue
    
    model_input = [
        indicators_scaled[asset]["trend_high"][-1],
        indicators_scaled[asset]["trend_low"][-1],
        indicators_scaled[asset]["trend_open"][-1],
        indicators_scaled[asset]["trend_close"][-1],
        indicators_scaled[asset]["aroon"][-1],
        indicators_scaled[asset]["aroon_down"][-1],
        indicators_scaled[asset]["aroon_up"][-1],
        indicators_scaled[asset]["cmf"][-1],
        indicators_scaled[asset]["mfi"][-1],
        indicators_scaled[asset]["ppo"][-1],
        indicators_scaled[asset]["pvo"][-1],
        indicators_scaled[asset]["rsi"][-1],
        indicators_scaled[asset]["stc"][-1],
        indicators_scaled[asset]["williamsr"][-1]
    ]
    
    model = keras.models.load_model(f"trained-models/{asset}_high")
    prediction = model.predict(np.array([model_input]), verbose=0)
    print(round(prediction[0][0], 1))
                                         
    model = keras.models.load_model(f"trained-models/{asset}_low")
    prediction = model.predict(np.array([model_input]), verbose=0)
    print(round(prediction[0][0], 1))             
                                         
    model = keras.models.load_model(f"trained-models/{asset}_open")
    prediction = model.predict(np.array([model_input]), verbose=0)
    print(round(prediction[0][0], 1))
                                         
    model = keras.models.load_model(f"trained-models/{asset}_close")
    prediction = model.predict(np.array([model_input]), verbose=0)
    print(round(prediction[0][0], 1))
# Out:
# 2023-10-30 00:00:00
# 0.5
# 0.3
# 0.2
# 0.3
# 2023-10-30 00:00:00
# 0.3
# 0.2
# 0.2
# 0.1
# 2023-10-30 00:00:00
# 0.2
# 0.0
# 0.3
# 0.3
# 2023-10-30 00:00:00
# 0.2
# 0.1
# 0.2
# 0.2
# 2023-10-30 00:00:00
# 0.3
# 0.4
# 0.3
# 0.4
# 2023-10-30 00:00:00
# 0.4
# 0.2
# 0.1
# 0.0
# 2023-10-30 00:00:00
# 0.3
# 0.4
# 0.3
# 0.0
# 2023-10-30 00:00:00
# 0.4
# 0.3
# 0.1
# 0.3
# 2023-10-30 00:00:00
# 0.2
# 0.2
# 0.3
# 0.3
# 2023-10-30 00:00:00
# 0.1
# 0.0
# 0.2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 42
#      39 prediction = model.predict(np.array([model_input]), verbose=0)
#      40 print(round(prediction[0][0], 1))
# ---> 42 model = keras.models.load_model(f"trained-models/{asset}_close")
#      43 prediction = model.predict(np.array([model_input]), verbose=0)
#      44 print(round(prediction[0][0], 1))
#
# File ~/Documents/Projects/stock-analysis/.conda/lib/python3.10/site-packages/keras/saving/saving_api.py:212, in load_model(filepath, custom_objects, compile, safe_mode, **kwargs)
#     204     return saving_lib.load_model(
#     205         filepath,
#     206         custom_objects=custom_objects,
#     207         compile=compile,
#     208         safe_mode=safe_mode,
#     209     )
#     211 # Legacy case.
# --> 212 return legacy_sm_saving_lib.load_model(
#     213     filepath, custom_objects=custom_objects, compile=compile, **kwargs
#     214 )
#
# File ~/Documents/Projects/stock-analysis/.conda/lib/python3.10/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Documents/Projects/stock-analysis/.conda/lib/python3.10/site-packages/keras/saving/legacy/save.py:235, in load_model(filepath, custom_objects, compile, options)
#     230     raise IOError(
#     231         f"No file or directory found at {filepath_str}"
#     232     )
#     234 if tf.io.gfile.isdir(filepath_str):
# --> 235     return saved_model_load.load(
#     236         filepath_str, compile, options
#     237     )
#     238 else:
#     239     if h5py is None:
#
# File ~/Documents/Projects/stock-analysis/.conda/lib/python3.10/site-packages/keras/saving/legacy/saved_model/load.py:144, in load(path, compile, options)
#     140 with warnings.catch_warnings():
#     141     warnings.filterwarnings(
#     142         "ignore", message="Trying to load ShardedVariables"
#     143     )
# --> 144     loaded = tf.__internal__.saved_model.load_partial(
#     145         path, nodes_to_load, options=options
#     146     )
#     148 # Finalize the loaded layers and remove the extra tracked dependencies.
#     149 keras_loader.finalize_objects()
#
# File ~/Documents/Projects/stock-analysis/.conda/lib/python3.10/site-packages/tensorflow/python/saved_model/load.py:966, in load_partial(export_dir, filters, tags, options)
#     964 with ops.init_scope():
#     965   try:
# --> 966     loader = Loader(object_graph_proto, saved_model_proto, export_dir,
#     967                     ckpt_options, options, filters)
#     968   except errors.NotFoundError as err:
#     969     raise FileNotFoundError(
#     970         str(err) + "\n You may be trying to load on a different device "
#     971         "from the computational device. Consider setting the "
#     972         "`experimental_io_device` option in `tf.saved_model.LoadOptions` "
#     973         "to the io_device such as '/job:localhost'.")
#
# File ~/Documents/Projects/stock-analysis/.conda/lib/python3.10/site-packages/tensorflow/python/saved_model/load.py:192, in Loader.__init__(self, object_graph_proto, saved_model_proto, export_dir, ckpt_options, save_options, filters)
#     189 # Order all nodes or filtered nodes using the dependencies.
#     190 self._ordered_node_ids = self._generate_ordered_node_ids()
# --> 192 self._load_all()
#     194 if not save_options.experimental_skip_checkpoint:
#     195   self._restore_checkpoint()
#
# File ~/Documents/Projects/stock-analysis/.conda/lib/python3.10/site-packages/tensorflow/python/saved_model/load.py:289, in Loader._load_all(self)
#     287 def _load_all(self):
#     288   """Loads all nodes and functions from the SavedModel and their edges."""
# --> 289   self._load_nodes()
#     290   self._load_edges()
#     292   # Set up concrete functions that aren't part of the object graph
#     293   # (e.g. gradient functions)
#
# File ~/Documents/Projects/stock-analysis/.conda/lib/python3.10/site-packages/tensorflow/python/saved_model/load.py:498, in Loader._load_nodes(self)
#     495 optimizer_object = nodes[optimizer_node_id]
#     496 optimized_variable = nodes[
#     497     slot_variable_proto.original_variable_node_id]
# --> 498 slot_variable = optimizer_object.add_slot(
#     499     var=optimized_variable,
#     500     slot_name=slot_variable_proto.slot_name)
#     501 nodes[slot_variable_proto.slot_variable_node_id] = slot_variable
#     502 node_setters[slot_variable_proto.slot_variable_node_id] = setattr
#
# File ~/Documents/Projects/stock-analysis/.conda/lib/python3.10/site-packages/keras/optimizers/legacy/optimizer_v2.py:1059, in OptimizerV2.add_slot(self, var, slot_name, initializer, shape)
#    1048         raise ValueError(
#    1049             "Trying to create optimizer slot variable under the "
#    1050             "scope for tf.distribute.Strategy ({}), which is "
#    (...)
#    1055             "outside the scope.".format(strategy, var)
#    1056         )
#    1058     with strategy.extended.colocate_vars_with(var):
# -> 1059         weight = tf.Variable(
#    1060             name=f"{var._shared_name}/{slot_name}",
#    1061             dtype=var.dtype,
#    1062             trainable=False,
#    1063             initial_value=initial_value,
#    1064         )
#    1065 backend.track_variable(weight)
#    1066 slot_dict[slot_name] = weight
#
# File ~/Documents/Projects/stock-analysis/.conda/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Documents/Projects/stock-analysis/.conda/lib/python3.10/site-packages/tensorflow/python/ops/variables.py:287, in VariableMetaclass.__call__(cls, *args, **kwargs)
#     285   return cls._variable_v1_call(*args, **kwargs)
#     286 elif cls is Variable:
# --> 287   return cls._variable_v2_call(*args, **kwargs)
#     288 else:
#     289   return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#
# File ~/Documents/Projects/stock-analysis/.conda/lib/python3.10/site-packages/tensorflow/python/ops/variables.py:266, in VariableMetaclass._variable_v2_call(cls, initial_value, trainable, validate_shape, caching_device, name, variable_def, dtype, import_scope, constraint, synchronization, aggregation, shape, experimental_enable_variable_lifting)
#     264 if aggregation is None:
#     265   aggregation = VariableAggregation.NONE
# --> 266 return previous_getter(
#     267     initial_value=initial_value,
#     268     trainable=trainable,
#     269     validate_shape=validate_shape,
#     270     caching_device=caching_device,
#     271     name=name,
#     272     variable_def=variable_def,
#     273     dtype=dtype,
#     274     import_scope=import_scope,
#     275     constraint=constraint,
#     276     synchronization=synchronization,
#     277     aggregation=aggregation,
#     278     shape=shape,
#     279     experimental_enable_variable_lifting=experimental_enable_variable_lifting,
#     280     )
#
# File ~/Documents/Projects/stock-analysis/.conda/lib/python3.10/site-packages/tensorflow/python/ops/variables.py:259, in VariableMetaclass._variable_v2_call.<locals>.<lambda>(**kws)
#     243 def _variable_v2_call(cls,
#     244                       initial_value=None,
#     245                       trainable=None,
#    (...)
#     256                       experimental_enable_variable_lifting=None,
#     257                       ):
#     258   """Call on Variable class. Useful to force the signature."""
# --> 259   previous_getter = lambda **kws: default_variable_creator_v2(None, **kws)
#     260   for _, getter in ops.get_default_graph()._variable_creator_stack:  # pylint: disable=protected-access
#     261     previous_getter = _make_getter(getter, previous_getter)
#
# File ~/Documents/Projects/stock-analysis/.conda/lib/python3.10/site-packages/tensorflow/python/ops/variable_scope.py:2759, in default_variable_creator_v2(next_creator, **kwargs)
#    2755 shape = kwargs.get("shape", None)
#    2756 experimental_enable_variable_lifting = kwargs.get(
#    2757     "experimental_enable_variable_lifting", None)
# -> 2759 return resource_variable_ops.ResourceVariable(
#    2760     initial_value=initial_value,
#    2761     trainable=trainable,
#    2762     validate_shape=validate_shape,
#    2763     caching_device=caching_device,
#    2764     name=name,
#    2765     dtype=dtype,
#    2766     constraint=constraint,
#    2767     variable_def=variable_def,
#    2768     import_scope=import_scope,
#    2769     distribute_strategy=distribute_strategy,
#    2770     synchronization=synchronization,
#    2771     aggregation=aggregation,
#    2772     shape=shape,
#    2773     experimental_enable_variable_lifting=experimental_enable_variable_lifting,
#    2774     )
#
# File ~/Documents/Projects/stock-analysis/.conda/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/Documents/Projects/stock-analysis/.conda/lib/python3.10/site-packages/tensorflow/python/ops/variables.py:289, in VariableMetaclass.__call__(cls, *args, **kwargs)
#     287   return cls._variable_v2_call(*args, **kwargs)
#     288 else:
# --> 289   return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#
# File ~/Documents/Projects/stock-analysis/.conda/lib/python3.10/site-packages/tensorflow/python/ops/resource_variable_ops.py:1768, in ResourceVariable.__init__(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, variable_def, import_scope, constraint, distribute_strategy, synchronization, aggregation, shape, handle, experimental_enable_variable_lifting)
#    1763   self._init_from_handle(trainable=trainable,
#    1764                          shape=shape,
#    1765                          dtype=dtype,
#    1766                          handle=handle)
#    1767 else:
# -> 1768   self._init_from_args(
#    1769       initial_value=initial_value,
#    1770       trainable=trainable,
#    1771       collections=collections,
#    1772       caching_device=caching_device,
#    1773       name=name,
#    1774       dtype=dtype,
#    1775       constraint=constraint,
#    1776       synchronization=synchronization,
#    1777       aggregation=aggregation,
#    1778       shape=shape,
#    1779       distribute_strategy=distribute_strategy,
#    1780       validate_shape=validate_shape,
#    1781       experimental_enable_variable_lifting=experimental_enable_variable_lifting,
#    1782       )
#
# File ~/Documents/Projects/stock-analysis/.conda/lib/python3.10/site-packages/tensorflow/python/ops/resource_variable_ops.py:2052, in ResourceVariable._init_from_args(self, initial_value, trainable, collections, caching_device, name, dtype, constraint, synchronization, aggregation, distribute_strategy, shape, validate_shape, experimental_enable_variable_lifting)
#    2050     ops.add_to_collections(ops.GraphKeys.GLOBAL_STEP, self)
#    2051 initial_value = initial_value if self._in_graph_mode else None
# -> 2052 super(ResourceVariable, self).__init__(
#    2053     trainable=trainable,
#    2054     shape=shape,
#    2055     dtype=dtype,
#    2056     handle=handle,
#    2057     synchronization=synchronization,
#    2058     constraint=constraint,
#    2059     aggregation=aggregation,
#    2060     distribute_strategy=distribute_strategy,
#    2061     name=name,
#    2062     unique_id=unique_id,
#    2063     handle_name=handle_name,
#    2064     graph_element=graph_element,
#    2065     initial_value=initial_value,
#    2066     initializer_op=initializer_op,
#    2067     is_initialized_op=is_initialized_op,
#    2068     cached_value=cached_value,
#    2069     caching_device=caching_device,
#    2070     validate_shape=validate_shape,
#    2071 )
#
# File ~/Documents/Projects/stock-analysis/.conda/lib/python3.10/site-packages/tensorflow/python/ops/resource_variable_ops.py:416, in BaseResourceVariable.__init__(self, trainable, shape, dtype, handle, constraint, synchronization, aggregation, distribute_strategy, name, unique_id, handle_name, graph_element, initial_value, initializer_op, is_initialized_op, cached_value, save_slice_info, caching_device, in_graph_mode, validate_shape, **unused_kwargs)
#     363 """Creates a variable from a handle.
#     364
#     365 Args:
#    (...)
#     413     `initial_value` must be known.
#     414 """
#     415 if in_graph_mode is None:
# --> 416   with ops.init_scope():
#     417     self._in_graph_mode = not context.executing_eagerly()
#     418 else:
#
# KeyboardInterrupt:
