# %%
import numpy as np
import pandas as pd
import yfinance as yf
import warnings
import json

warnings.filterwarnings("ignore")
pd.options.display.float_format = '{:.4%}'.format

params = json.loads(open('../params.json', 'r').read())

# Date range
start = "2022-02-06"
end = "2024-02-06"

# Tickers of assets
industry_asset = json.loads(open('../stocks.json', 'r').read())
assets = []
for key, values in industry_asset.items():
    for value in values:
        assets.append(value)

# Downloading data
data = yf.download(assets, start = start, end = end)
data = data.loc[:,('Adj Close', slice(None))]
data.columns = assets
# Out:
# [*********************100%%**********************]  23 of 23 completed

# %%
# Calculating returns

Y = data.pct_change().dropna()

display(Y.head())
# Out:
#             TIMS3.SA  VIVT3.SA  SUZB3.SA  KLBN11.SA  CSAN3.SA  VBBR3.SA  \
# Date
# 2022-02-08  -0.9138%  -0.1163%   0.3521%   -1.6415%   1.3469%  -0.4718%
# 2022-02-09  -0.1203%   0.5242%   0.7719%    0.8570%   1.2213%   1.0479%
# 2022-02-10   0.9233%   0.2897%  -0.4526%   -0.1789%   0.1065%  -0.3457%
# 2022-02-11  -1.1535%  -1.2709%   0.9094%   -0.2240%  -1.4179%   0.3716%
# 2022-02-14   0.4427%  -2.0480%   0.9705%    0.0000%  -0.2517%   0.0247%
#
#             PRIO3.SA  UGPA3.SA  ENAT3.SA  PETR3.SA  ...  ALUP11.SA  CPFE3.SA  \
# Date                                                ...
# 2022-02-08  -0.9265%  -2.1073%  -0.8053%  -1.0000%  ...    0.8800%  -1.4374%
# 2022-02-09   2.5339%   1.6960%  -0.9511%   1.0101%  ...   -1.1499%   0.0858%
# 2022-02-10   0.0000%   2.0526%   0.8665%  -0.1250%  ...   -1.0429%   1.7143%
# 2022-02-11  -1.9417%   3.1427%  -0.7894%  -0.7927%  ...   -3.1212%   4.4944%
# 2022-02-14   0.2700%  -0.3656%   1.5914%   0.3785%  ...    0.1255%  -2.5806%
#
#             CMIG3.SA  ELET3.SA  EQTL3.SA  EGIE3.SA  VALE3.SA  GGBR3.SA  \
# Date
# 2022-02-08  -1.2412%  -0.1486%  -0.6600%   2.1260%   0.7829%   1.3980%
# 2022-02-09   2.6393%   0.2316%   0.5581%   5.0558%   1.2712%   0.0219%
# 2022-02-10   1.0204%  -3.6964%   0.1321%  -1.2031%   1.1855%   2.6912%
# 2022-02-11   4.2424%  -1.0966%  -0.8181%  -0.4298%   0.1378%  -2.0241%
# 2022-02-14   2.7132%   1.1088%  -0.2129%  -0.1439%   0.6194%  -0.4349%
#
#             CSNA3.SA  FESA4.SA
# Date
# 2022-02-08  -0.4951%   0.3259%
# 2022-02-09   2.9399%   2.7203%
# 2022-02-10   0.3515%  -2.0158%
# 2022-02-11   0.0438%   0.5244%
# 2022-02-14   0.9628%  -0.0200%
#
# [5 rows x 23 columns]

# %%
import riskfolio as rp

# Building the portfolio object
port = rp.Portfolio(returns=Y)

# Calculating optimal portfolio

# Select method and estimate input parameters:

method_mu='hist' # Method to estimate expected returns based on historical data.
method_cov='hist' # Method to estimate covariance matrix based on historical data.

port.assets_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

# Configuring short weights options

port.sht = True # Allows to use Short Weights

port.uppersht = 0.3 # Maximum value of sum of short weights in absolute value
port.upperlng = 1.3 # Maximum value of sum of positive weights
port.budget = 1.0 # port.upperlng - port.uppersht

# Estimate optimal portfolio:

model='Classic' # Could be Classic (historical), BL (Black Litterman) or FM (Factor Model)
rm = 'MV' # Risk measure used, this time will be variance
obj = 'Sharpe' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = True # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
l = 0 # Risk aversion factor, only useful when obj is 'Utility'

w = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w.T)
# Out:
#          TIMS3.SA  VIVT3.SA  SUZB3.SA  KLBN11.SA  CSAN3.SA  VBBR3.SA  \
# weights   6.4026%   2.7787%   2.4934%  -22.8836%  -2.9851%   0.0000%
#
#          PRIO3.SA  UGPA3.SA  ENAT3.SA  PETR3.SA  ...  ALUP11.SA  CPFE3.SA  \
# weights  -0.0000%   0.0000%   0.0000%  17.6170%  ...    0.0000%  24.4988%
#
#          CMIG3.SA  ELET3.SA  EQTL3.SA  EGIE3.SA  VALE3.SA  GGBR3.SA  CSNA3.SA  \
# weights   7.5320%   0.0000%   0.0000%  25.0936%  17.7967%   0.0000%  -4.1314%
#
#          FESA4.SA
# weights   0.0000%
#
# [1 rows x 23 columns]

# %%
# Plotting the composition of the portfolio

ax = rp.plot_pie(w=w, title='Sharpe Mean Variance', others=0.05, nrow=25, cmap = "tab20",
                 height=6, width=10, ax=None)

# %%
points = 50 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)

display(frontier.T.head())
# Out:
#    TIMS3.SA  VIVT3.SA  SUZB3.SA  KLBN11.SA  CSAN3.SA  VBBR3.SA  PRIO3.SA  \
# 0  11.8718%   0.0170%  -1.0834%   -4.9569% -10.8712%  15.3640%  -1.9408%
# 1  12.3021%   1.4556%   0.8380%  -11.5007%  -9.8201%   8.4452%  -3.4803%
# 2  12.2511%   1.8615%   1.2049%  -13.9004%  -8.5283%   5.1243%  -2.8504%
# 3  12.3029%   2.1544%   1.5362%  -15.6240%  -7.3201%   2.3980%  -2.0052%
# 4  12.2488%   2.4145%   1.7615%  -17.1090%  -6.3004%   0.1919%  -1.2704%
#
#    UGPA3.SA  ENAT3.SA  PETR3.SA  ...  ALUP11.SA  CPFE3.SA  CMIG3.SA  ELET3.SA  \
# 0  -0.0722%  -1.0641%   3.8351%  ...    6.8142%   5.2003%   1.4884%   8.9801%
# 1  -0.0694%  -0.5807%   9.1641%  ...    4.8108%  10.4779%   3.4496%   7.5316%
# 2  -0.0000%  -0.0000%  11.0073%  ...    3.6801%  12.8763%   4.2913%   7.1104%
# 3  -0.0000%  -0.0000%  12.5773%  ...    2.8533%  14.8156%   4.9813%   6.7606%
# 4  -0.0000%   0.0000%  13.8223%  ...    2.0662%  16.4303%   5.5633%   6.4671%
#
#    EQTL3.SA  EGIE3.SA  VALE3.SA  GGBR3.SA  CSNA3.SA  FESA4.SA
# 0  22.6480%   8.5102%  -1.2765%  15.7217%  -0.6608%  10.6270%
# 1  16.3991%  14.0959%   5.8934%  10.3383%  -4.0568%   6.7396%
# 2  13.6016%  16.7553%   8.3727%   7.2474%  -4.7208%   4.6479%
# 3  11.4288%  18.8492%  10.1974%   4.6815%  -5.0507%   2.9486%
# 4   9.5355%  20.7005%  11.7007%   2.3667%  -5.3201%   1.5062%
#
# [5 rows x 23 columns]

# %%
# Plotting the efficient frontier

label = 'Max Risk Adjusted Return Portfolio' # Title of point
mu = port.mu # Expected returns
cov = port.cov # Covariance matrix
returns = port.returns # Returns of the assets

ax = rp.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                      rf=rf, alpha=0.05, cmap='viridis', w=w, label=label,
                      marker='*', s=16, c='r', height=6, width=10, ax=None)

# %%
# Plotting efficient frontier composition
# This chart doesn't work well will short weights and leverage

ax = rp.plot_frontier_area(w_frontier=frontier, cmap="tab20", height=6, width=10, ax=None)

# %%
# Building the portfolio object
port = rp.Portfolio(returns=Y[assets])

# Calculating optimal portfolio

# Select method and estimate input parameters:

method_mu='hist' # Method to estimate expected returns based on historical data.
method_cov='hist' # Method to estimate covariance matrix based on historical data.

port.assets_stats(method_mu=method_mu, method_cov=method_cov, d=0.94)

# Configuring short weights options

port.sht = True # Allows to use Short Weights
port.uppersht = 0.3 # Maximum value of sum of short weights in absolute value
port.upperlng = 1.6 # Maximum value of sum of total weights (Budget greater than 1 means leverage)

# Configuring leverage
port.budget = 1.3 # port.upperlng - port.uppersht

# Estimate optimal portfolio:

model='Classic' # Could be Classic (historical), BL (Black Litterman) or FM (Factor Model)
rm = 'MV' # Risk measure used, this time will be variance
obj = "Sharpe" # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = True # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
l = 0 # Risk aversion factor, only useful when obj is 'Utility'

w = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w.T)
# Out:
#          TIMS3.SA  VIVT3.SA  SUZB3.SA  KLBN11.SA  CSAN3.SA  VBBR3.SA  \
# weights   7.4681%   3.3707%   2.8797%  -26.5259%  -1.9081%   0.0000%
#
#          PRIO3.SA  UGPA3.SA  ENAT3.SA  PETR3.SA  ...  ALUP11.SA  CPFE3.SA  \
# weights  -0.0000%   0.0000%   0.0000%  22.0181%  ...    0.0000%  31.8366%
#
#          CMIG3.SA  ELET3.SA  EQTL3.SA  EGIE3.SA  VALE3.SA  GGBR3.SA  CSNA3.SA  \
# weights   9.1490%   0.0000%   0.0000%  32.3754%  20.3086%   0.0000%  -1.5659%
#
#          FESA4.SA
# weights   0.0000%
#
# [1 rows x 23 columns]

# %%
# Plotting the composition of the portfolio

ax = rp.plot_pie(w=w, title='Sharpe Mean Variance', others=0.05, nrow=25, cmap = "tab20",
                 height=6, width=10, ax=None)

# %%
points = 50 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)

display(frontier.T.head())
# Out:
#    TIMS3.SA  VIVT3.SA  SUZB3.SA  KLBN11.SA  CSAN3.SA  VBBR3.SA  PRIO3.SA  \
# 0  15.0865%   0.0000%  -0.9275%   -6.3473% -13.9128%  19.6797%  -2.3014%
# 1  15.0988%   1.3709%   0.0000%  -13.5798% -11.2445%  11.3309%  -1.8303%
# 2  15.2130%   1.8382%   0.2960%  -16.2467%  -9.3841%   7.1731%  -0.5065%
# 3  15.3730%   2.2688%   0.7948%  -18.1206%  -7.7720%   3.8679%  -0.0000%
# 4  15.4850%   2.7171%   1.2483%  -19.5549%  -6.2753%   1.1692%  -0.0000%
#
#    UGPA3.SA  ENAT3.SA  PETR3.SA  ...  ALUP11.SA  CPFE3.SA  CMIG3.SA  ELET3.SA  \
# 0  -0.0000%  -0.8742%   4.2893%  ...    8.6816%   6.5971%   1.8499%  11.8165%
# 1  -0.0000%  -0.0000%  10.1032%  ...    5.6143%  13.2484%   4.2922%  10.3342%
# 2  -0.0000%   0.0000%  12.5918%  ...    4.3323%  16.2481%   5.3587%   9.8023%
# 3  -0.0000%   0.0000%  14.6177%  ...    3.2430%  18.6450%   6.1707%   9.3903%
# 4  -0.0000%   0.0000%  16.3527%  ...    2.1467%  20.6949%   6.8384%   9.0519%
#
#    EQTL3.SA  EGIE3.SA  VALE3.SA  GGBR3.SA  CSNA3.SA  FESA4.SA
# 0  29.4833%  10.9905%  -1.5570%  20.2789%  -0.7380%  13.7671%
# 1  21.5078%  18.5345%   5.6099%  11.9647%  -3.3455%   8.3312%
# 2  18.1735%  21.7734%   8.4353%   7.9973%  -3.8627%   5.7066%
# 3  15.5293%  24.3506%  10.5586%   4.7189%  -4.1074%   3.6168%
# 4  13.2087%  26.6601%  12.2424%   1.6286%  -4.1698%   1.8108%
#
# [5 rows x 23 columns]

# %%
# Plotting the efficient frontier

label = 'Max Risk Adjusted Return Portfolio' # Title of point
mu = port.mu # Expected returns
cov = port.cov # Covariance matrix
returns = port.returns # Returns of the assets

ax = rp.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                      rf=rf, alpha=0.05, cmap='viridis', w=w, label=label,
                      marker='*', s=16, c='r', height=6, width=10, ax=None)

# %%
# Plotting efficient frontier composition
# This chart doesn't work well will short weights and leverage

ax = rp.plot_frontier_area(w_frontier=frontier, cmap="tab20", height=6, width=10, ax=None)

# %%
rm = 'CVaR' # Risk measure

w = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)

display(w.T)
# Out:
#          TIMS3.SA  VIVT3.SA  SUZB3.SA  KLBN11.SA  CSAN3.SA  VBBR3.SA  \
# weights   5.1865%   8.1467%  14.3914%  -26.2455%  -3.7545%   0.0000%
#
#          PRIO3.SA  UGPA3.SA  ENAT3.SA  PETR3.SA  ...  ALUP11.SA  CPFE3.SA  \
# weights  -0.0000%  -0.0000%   0.1425%  13.9307%  ...    0.0000%  25.7545%
#
#          CMIG3.SA  ELET3.SA  EQTL3.SA  EGIE3.SA  VALE3.SA  GGBR3.SA  CSNA3.SA  \
# weights   4.3698%  15.0031%   0.0000%  39.7361%   9.0991%   0.0000%  -0.0000%
#
#          FESA4.SA
# weights   0.0000%
#
# [1 rows x 23 columns]

# %%
ax = rp.plot_pie(w=w, title='Sharpe Mean CVaR', others=0.05, nrow=25, cmap = "tab20",
                 height=6, width=10, ax=None)

# %%
points = 50 # Number of points of the frontier

frontier = port.efficient_frontier(model=model, rm=rm, points=points, rf=rf, hist=hist)

display(frontier.T.head())
# Out:
#    TIMS3.SA  VIVT3.SA  SUZB3.SA  KLBN11.SA  CSAN3.SA  VBBR3.SA  PRIO3.SA  \
# 0  17.1483%   0.6097%  -0.7146%   -5.6722%  -8.9158%   8.4728%  -0.0000%
# 1  10.8108%   2.6235%   0.0000%  -23.3896%  -2.9195%  12.0020%  -0.0000%
# 2  10.7235%   1.1015%   0.0000%  -28.2205%  -1.5265%   8.0904%  -0.0000%
# 3  11.2508%   0.0000%   1.2325%  -30.0000%  -0.0000%   0.3529%  -0.0000%
# 4   5.3912%   5.6339%   4.3768%  -28.1973%  -1.8027%   0.0000%  -0.0000%
#
#    UGPA3.SA  ENAT3.SA  PETR3.SA  ...  ALUP11.SA  CPFE3.SA  CMIG3.SA  ELET3.SA  \
# 0  -0.0000%   1.8955%  14.4900%  ...   21.4411%   3.7427%  -2.6801%   3.8060%
# 1   0.0000%   4.1525%  21.5002%  ...   24.8494%  11.0636%   0.0000%   1.2737%
# 2  -0.0000%   4.4678%  27.2679%  ...   22.3507%  15.5610%   0.5542%   0.0000%
# 3   0.0000%   4.0479%  29.1009%  ...   20.9962%  17.2234%   1.5312%   1.1218%
# 4   0.0000%   6.5322%  17.3164%  ...   17.1725%  21.5780%   6.2317%   5.7619%
#
#    EQTL3.SA  EGIE3.SA  VALE3.SA  GGBR3.SA  CSNA3.SA  FESA4.SA
# 0  18.3865%  22.6538%  -5.2600%  23.5781%  -0.0000%   8.5674%
# 1   8.4744%  26.7635%   2.5845%   8.4884%  -0.3756%   3.0843%
# 2   2.5083%  34.4096%   3.9794%   7.2108%  -0.0000%   2.2877%
# 3   0.0000%  42.2920%   6.7358%   1.9486%  -0.0000%   2.1523%
# 4   0.0000%  40.4375%   7.6931%   0.0000%  -0.0000%   0.0000%
#
# [5 rows x 23 columns]

# %%
label = 'Max Risk Adjusted Return Portfolio' # Title of point

ax = rp.plot_frontier(w_frontier=frontier, mu=mu, cov=cov, returns=returns, rm=rm,
                      rf=rf, alpha=0.05, cmap='viridis', w=w, label=label,
                      marker='*', s=16, c='r', height=6, width=10, ax=None)

# %%
# Plotting efficient frontier composition
# This chart doesn't work well will short weights and leverage

ax = rp.plot_frontier_area(w_frontier=frontier, cmap="tab20", height=6, width=10, ax=None)

# %%
# Risk Measures available:
#
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'WR': Worst Realization (Minimax)
# 'MDD': Maximum Drawdown of uncompounded cumulative returns (Calmar Ratio).
# 'ADD': Average Drawdown of uncompounded cumulative returns.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

rms = ['MV', 'MAD', 'MSV', 'FLPM', 'SLPM', 'CVaR',
       'EVaR', 'WR', 'MDD', 'ADD', 'CDaR', 'UCI', 'EDaR']

w_s = pd.DataFrame([])

for i in rms:
    w = port.optimization(model=model, rm=i, obj=obj, rf=rf, l=l, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
    
w_s.columns = rms
w_s.style.format("{:.2%}").background_gradient(cmap='YlGn')
# Out:
# <style type="text/css">
# #T_be14c_row0_col0, #T_be14c_row18_col10 {
#   background-color: #56b568;
#   color: #f1f1f1;
# }
# #T_be14c_row0_col1, #T_be14c_row21_col11 {
#   background-color: #fafdc9;
#   color: #000000;
# }
# #T_be14c_row0_col2, #T_be14c_row2_col4 {
#   background-color: #84cb7e;
#   color: #000000;
# }
# #T_be14c_row0_col3, #T_be14c_row1_col3, #T_be14c_row2_col3, #T_be14c_row3_col0, #T_be14c_row3_col1, #T_be14c_row3_col2, #T_be14c_row3_col3, #T_be14c_row3_col4, #T_be14c_row3_col5, #T_be14c_row3_col6, #T_be14c_row3_col7, #T_be14c_row3_col9, #T_be14c_row3_col11, #T_be14c_row4_col3, #T_be14c_row5_col3, #T_be14c_row6_col3, #T_be14c_row7_col3, #T_be14c_row8_col3, #T_be14c_row9_col3, #T_be14c_row10_col3, #T_be14c_row11_col3, #T_be14c_row13_col3, #T_be14c_row14_col3, #T_be14c_row15_col3, #T_be14c_row16_col3, #T_be14c_row17_col3, #T_be14c_row18_col3, #T_be14c_row19_col3, #T_be14c_row20_col3, #T_be14c_row21_col3, #T_be14c_row21_col8, #T_be14c_row21_col10, #T_be14c_row21_col12, #T_be14c_row22_col3 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_be14c_row0_col4, #T_be14c_row1_col2, #T_be14c_row11_col0, #T_be14c_row15_col2, #T_be14c_row15_col6 {
#   background-color: #7ac77a;
#   color: #000000;
# }
# #T_be14c_row0_col5, #T_be14c_row2_col8, #T_be14c_row15_col8 {
#   background-color: #83cb7d;
#   color: #000000;
# }
# #T_be14c_row0_col6 {
#   background-color: #72c376;
#   color: #000000;
# }
# #T_be14c_row0_col7, #T_be14c_row2_col2, #T_be14c_row4_col7, #T_be14c_row5_col0, #T_be14c_row5_col7, #T_be14c_row6_col0, #T_be14c_row6_col7, #T_be14c_row7_col0, #T_be14c_row8_col0, #T_be14c_row8_col7, #T_be14c_row10_col7, #T_be14c_row11_col7, #T_be14c_row13_col0, #T_be14c_row15_col7, #T_be14c_row16_col0, #T_be14c_row17_col0, #T_be14c_row17_col7, #T_be14c_row19_col7, #T_be14c_row20_col0, #T_be14c_row21_col7, #T_be14c_row22_col0, #T_be14c_row22_col7 {
#   background-color: #8dcf81;
#   color: #000000;
# }
# #T_be14c_row0_col8, #T_be14c_row7_col8, #T_be14c_row8_col8, #T_be14c_row9_col8, #T_be14c_row11_col8, #T_be14c_row13_col8, #T_be14c_row16_col8, #T_be14c_row18_col8, #T_be14c_row20_col8, #T_be14c_row22_col8 {
#   background-color: #ddf1a6;
#   color: #000000;
# }
# #T_be14c_row0_col9, #T_be14c_row9_col4 {
#   background-color: #30954f;
#   color: #f1f1f1;
# }
# #T_be14c_row0_col10, #T_be14c_row10_col0, #T_be14c_row13_col9 {
#   background-color: #7ec97b;
#   color: #000000;
# }
# #T_be14c_row0_col11, #T_be14c_row15_col5 {
#   background-color: #88cd7f;
#   color: #000000;
# }
# #T_be14c_row0_col12, #T_be14c_row14_col8, #T_be14c_row16_col10, #T_be14c_row21_col4 {
#   background-color: #acdd8e;
#   color: #000000;
# }
# #T_be14c_row1_col0 {
#   background-color: #75c578;
#   color: #000000;
# }
# #T_be14c_row1_col1 {
#   background-color: #fafdc8;
#   color: #000000;
# }
# #T_be14c_row1_col4, #T_be14c_row1_col5, #T_be14c_row11_col9 {
#   background-color: #6fc174;
#   color: #000000;
# }
# #T_be14c_row1_col6 {
#   background-color: #8ed082;
#   color: #000000;
# }
# #T_be14c_row1_col7 {
#   background-color: #81ca7d;
#   color: #000000;
# }
# #T_be14c_row1_col8 {
#   background-color: #2e924c;
#   color: #f1f1f1;
# }
# #T_be14c_row1_col9, #T_be14c_row10_col8, #T_be14c_row16_col6 {
#   background-color: #66bd70;
#   color: #f1f1f1;
# }
# #T_be14c_row1_col10, #T_be14c_row9_col5, #T_be14c_row15_col0, #T_be14c_row19_col8 {
#   background-color: #49af61;
#   color: #f1f1f1;
# }
# #T_be14c_row1_col11, #T_be14c_row14_col11 {
#   background-color: #4cb063;
#   color: #f1f1f1;
# }
# #T_be14c_row1_col12, #T_be14c_row16_col5 {
#   background-color: #40aa5c;
#   color: #f1f1f1;
# }
# #T_be14c_row2_col0 {
#   background-color: #79c679;
#   color: #000000;
# }
# #T_be14c_row2_col1 {
#   background-color: #f8fcc0;
#   color: #000000;
# }
# #T_be14c_row2_col5 {
#   background-color: #45ad5f;
#   color: #f1f1f1;
# }
# #T_be14c_row2_col6, #T_be14c_row14_col9, #T_be14c_row18_col11 {
#   background-color: #359c53;
#   color: #f1f1f1;
# }
# #T_be14c_row2_col7 {
#   background-color: #15793e;
#   color: #f1f1f1;
# }
# #T_be14c_row2_col9 {
#   background-color: #238443;
#   color: #f1f1f1;
# }
# #T_be14c_row2_col10, #T_be14c_row5_col5, #T_be14c_row6_col5, #T_be14c_row7_col5, #T_be14c_row10_col5, #T_be14c_row11_col5, #T_be14c_row13_col5, #T_be14c_row16_col11, #T_be14c_row17_col5, #T_be14c_row20_col5, #T_be14c_row21_col5, #T_be14c_row22_col5 {
#   background-color: #a4d98a;
#   color: #000000;
# }
# #T_be14c_row2_col11, #T_be14c_row13_col7, #T_be14c_row15_col9, #T_be14c_row16_col7 {
#   background-color: #5ab76a;
#   color: #f1f1f1;
# }
# #T_be14c_row2_col12, #T_be14c_row17_col10 {
#   background-color: #9ad587;
#   color: #000000;
# }
# #T_be14c_row3_col8, #T_be14c_row8_col1 {
#   background-color: #fcfed4;
#   color: #000000;
# }
# #T_be14c_row3_col10 {
#   background-color: #f1fab5;
#   color: #000000;
# }
# #T_be14c_row3_col12 {
#   background-color: #f8fcbe;
#   color: #000000;
# }
# #T_be14c_row4_col0, #T_be14c_row10_col2 {
#   background-color: #9cd687;
#   color: #000000;
# }
# #T_be14c_row4_col1 {
#   background-color: #fbfed2;
#   color: #000000;
# }
# #T_be14c_row4_col2 {
#   background-color: #bce395;
#   color: #000000;
# }
# #T_be14c_row4_col4 {
#   background-color: #b8e293;
#   color: #000000;
# }
# #T_be14c_row4_col5, #T_be14c_row4_col11, #T_be14c_row6_col11, #T_be14c_row7_col11, #T_be14c_row8_col11, #T_be14c_row13_col11, #T_be14c_row20_col11, #T_be14c_row22_col11 {
#   background-color: #b9e294;
#   color: #000000;
# }
# #T_be14c_row4_col6, #T_be14c_row5_col6, #T_be14c_row6_col6, #T_be14c_row8_col6, #T_be14c_row10_col6, #T_be14c_row11_col6, #T_be14c_row17_col6, #T_be14c_row17_col11, #T_be14c_row19_col6, #T_be14c_row20_col6, #T_be14c_row22_col6 {
#   background-color: #93d284;
#   color: #000000;
# }
# #T_be14c_row4_col8, #T_be14c_row18_col1 {
#   background-color: #f8fcbd;
#   color: #000000;
# }
# #T_be14c_row4_col9, #T_be14c_row5_col9, #T_be14c_row6_col9, #T_be14c_row7_col9, #T_be14c_row8_col9, #T_be14c_row11_col11, #T_be14c_row16_col9, #T_be14c_row20_col9, #T_be14c_row22_col9 {
#   background-color: #9dd688;
#   color: #000000;
# }
# #T_be14c_row4_col10 {
#   background-color: #c9e99c;
#   color: #000000;
# }
# #T_be14c_row4_col12 {
#   background-color: #e9f6af;
#   color: #000000;
# }
# #T_be14c_row5_col1 {
#   background-color: #fdfedb;
#   color: #000000;
# }
# #T_be14c_row5_col2, #T_be14c_row6_col2, #T_be14c_row7_col2, #T_be14c_row8_col2, #T_be14c_row13_col2, #T_be14c_row17_col2, #T_be14c_row20_col2, #T_be14c_row22_col2 {
#   background-color: #a7db8c;
#   color: #000000;
# }
# #T_be14c_row5_col4, #T_be14c_row6_col4, #T_be14c_row7_col4, #T_be14c_row8_col4, #T_be14c_row11_col4, #T_be14c_row13_col4, #T_be14c_row17_col4, #T_be14c_row20_col4, #T_be14c_row22_col4 {
#   background-color: #a1d889;
#   color: #000000;
# }
# #T_be14c_row5_col8, #T_be14c_row19_col10 {
#   background-color: #61bb6d;
#   color: #f1f1f1;
# }
# #T_be14c_row5_col10 {
#   background-color: #4fb264;
#   color: #f1f1f1;
# }
# #T_be14c_row5_col11 {
#   background-color: #b3e091;
#   color: #000000;
# }
# #T_be14c_row5_col12 {
#   background-color: #58b669;
#   color: #f1f1f1;
# }
# #T_be14c_row6_col1 {
#   background-color: #fdfed9;
#   color: #000000;
# }
# #T_be14c_row6_col8 {
#   background-color: #dbf1a4;
#   color: #000000;
# }
# #T_be14c_row6_col10, #T_be14c_row11_col2 {
#   background-color: #a6da8b;
#   color: #000000;
# }
# #T_be14c_row6_col12 {
#   background-color: #c1e698;
#   color: #000000;
# }
# #T_be14c_row7_col1, #T_be14c_row16_col1 {
#   background-color: #fbfdcf;
#   color: #000000;
# }
# #T_be14c_row7_col6 {
#   background-color: #62bb6e;
#   color: #f1f1f1;
# }
# #T_be14c_row7_col7 {
#   background-color: #47ae60;
#   color: #f1f1f1;
# }
# #T_be14c_row7_col10, #T_be14c_row8_col10, #T_be14c_row11_col10, #T_be14c_row13_col10, #T_be14c_row20_col10, #T_be14c_row22_col10 {
#   background-color: #c0e597;
#   color: #000000;
# }
# #T_be14c_row7_col12, #T_be14c_row8_col12, #T_be14c_row9_col12, #T_be14c_row11_col12, #T_be14c_row13_col12, #T_be14c_row16_col12, #T_be14c_row20_col12, #T_be14c_row22_col12 {
#   background-color: #d0ec9f;
#   color: #000000;
# }
# #T_be14c_row8_col5, #T_be14c_row14_col12 {
#   background-color: #a2d88a;
#   color: #000000;
# }
# #T_be14c_row9_col0, #T_be14c_row9_col7 {
#   background-color: #0e743c;
#   color: #f1f1f1;
# }
# #T_be14c_row9_col1 {
#   background-color: #f3fab6;
#   color: #000000;
# }
# #T_be14c_row9_col2 {
#   background-color

# %%
import matplotlib.pyplot as plt

# Plotting a comparison of assets weights for each portfolio

fig = plt.gcf()
fig.set_figwidth(14)
fig.set_figheight(6)
ax = fig.subplots(nrows=1, ncols=1)

w_s.plot.bar(ax=ax)
# Out:
# <Axes: >
