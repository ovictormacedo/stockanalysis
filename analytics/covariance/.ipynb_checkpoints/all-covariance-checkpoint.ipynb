# %%
import numpy as np
import pandas as pd
import yfinance as yf
import warnings
import json

warnings.filterwarnings("ignore")
pd.options.display.float_format = '{:.4%}'.format

params = json.loads(open('../params.json', 'r').read())

# Date range
start = "2022-02-06"
end = "2024-02-06"

# Tickers of assets
industry_asset = json.loads(open('../stocks.json', 'r').read())
assets = []
for key, values in industry_asset.items():
    for value in values:
        assets.append(value)

# Downloading data
data = yf.download(assets, start = start, end = end)

data = data.loc[:,('Adj Close', slice(None))]

data.columns = assets
# Out:
# [*********************100%%**********************]  23 of 23 completed

# %%
# Calculating returns

Y = data[assets].pct_change().dropna()

display(Y.head())
# Out:
#             TIMS3.SA  VIVT3.SA  SUZB3.SA  KLBN11.SA  CSAN3.SA  VBBR3.SA  \
# Date
# 2022-02-08  -0.9138%  -0.1163%   0.3521%   -1.6415%   1.3469%  -0.4718%
# 2022-02-09  -0.1203%   0.5242%   0.7719%    0.8570%   1.2213%   1.0479%
# 2022-02-10   0.9233%   0.2897%  -0.4526%   -0.1789%   0.1064%  -0.3457%
# 2022-02-11  -1.1535%  -1.2709%   0.9094%   -0.2240%  -1.4179%   0.3716%
# 2022-02-14   0.4427%  -2.0480%   0.9705%    0.0000%  -0.2517%   0.0247%
#
#             PRIO3.SA  UGPA3.SA  ENAT3.SA  PETR3.SA  ...  ALUP11.SA  CPFE3.SA  \
# Date                                                ...
# 2022-02-08  -0.9265%  -2.1073%  -0.8053%  -1.0000%  ...    0.8800%  -1.4374%
# 2022-02-09   2.5339%   1.6960%  -0.9511%   1.0101%  ...   -1.1499%   0.0858%
# 2022-02-10   0.0000%   2.0526%   0.8665%  -0.1250%  ...   -1.0429%   1.7143%
# 2022-02-11  -1.9418%   3.1427%  -0.7894%  -0.7926%  ...   -3.1212%   4.4944%
# 2022-02-14   0.2700%  -0.3656%   1.5914%   0.3785%  ...    0.1255%  -2.5806%
#
#             CMIG3.SA  ELET3.SA  EQTL3.SA  EGIE3.SA  VALE3.SA  GGBR3.SA  \
# Date
# 2022-02-08  -1.2412%  -0.1486%  -0.6600%   2.1261%   0.7829%   1.3980%
# 2022-02-09   2.6393%   0.2316%   0.5580%   5.0558%   1.2712%   0.0219%
# 2022-02-10   1.0204%  -3.6964%   0.1321%  -1.2031%   1.1855%   2.6912%
# 2022-02-11   4.2424%  -1.0966%  -0.8182%  -0.4298%   0.1378%  -2.0241%
# 2022-02-14   2.7132%   1.1088%  -0.2129%  -0.1439%   0.6194%  -0.4349%
#
#             CSNA3.SA  FESA4.SA
# Date
# 2022-02-08  -0.4950%   0.3259%
# 2022-02-09   2.9399%   2.7203%
# 2022-02-10   0.3515%  -2.0158%
# 2022-02-11   0.0438%   0.5244%
# 2022-02-14   0.9628%  -0.0201%
#
# [5 rows x 23 columns]

# %%
import riskfolio as rp

# Building the portfolio object
port = rp.Portfolio(returns=Y)

# Calculating optimal portfolio

# Select method and estimate input parameters:

method_mu='hist' # Method to estimate expected returns based on historical data.
method_covs = ['hist', 'ledoit', 'oas', 'shrunk', 'gl', 'ewma1',
               'ewma2','jlogo', 'fixed', 'spectral', 'shrink',
               'gerber1', 'gerber2']

# Estimate optimal portfolio:

model='Classic' # Could be Classic (historical), BL (Black Litterman) or FM (Factor Model)
rm = 'MV' # Risk measure used, this time will be variance
obj = 'MinRisk' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = True # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
l = 0 # Risk aversion factor, only useful when obj is 'Utility'

w_s = pd.DataFrame([])

for i in method_covs:
    port.assets_stats(method_mu=method_mu, method_cov=i, d=0.94)
    w = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
    
w_s.columns = method_covs
# Out:
# You must convert self.cov to a positive definite matrix

# %%
display(w_s.style.format("{:.2%}").background_gradient(cmap='YlGn'))
# Out:
# <style type="text/css">
# #T_6cc08_row0_col0 {
#   background-color: #b2df90;
#   color: #000000;
# }
# #T_6cc08_row0_col1 {
#   background-color: #98d486;
#   color: #000000;
# }
# #T_6cc08_row0_col2 {
#   background-color: #9fd788;
#   color: #000000;
# }
# #T_6cc08_row0_col3 {
#   background-color: #74c477;
#   color: #000000;
# }
# #T_6cc08_row0_col4 {
#   background-color: #9ad587;
#   color: #000000;
# }
# #T_6cc08_row0_col5, #T_6cc08_row0_col6, #T_6cc08_row0_col9, #T_6cc08_row1_col0, #T_6cc08_row1_col1, #T_6cc08_row1_col2, #T_6cc08_row1_col3, #T_6cc08_row1_col4, #T_6cc08_row1_col8, #T_6cc08_row1_col9, #T_6cc08_row1_col10, #T_6cc08_row1_col12, #T_6cc08_row2_col0, #T_6cc08_row2_col1, #T_6cc08_row2_col2, #T_6cc08_row2_col3, #T_6cc08_row2_col4, #T_6cc08_row2_col5, #T_6cc08_row2_col6, #T_6cc08_row2_col7, #T_6cc08_row2_col8, #T_6cc08_row2_col9, #T_6cc08_row2_col10, #T_6cc08_row2_col12, #T_6cc08_row3_col0, #T_6cc08_row3_col1, #T_6cc08_row3_col2, #T_6cc08_row3_col3, #T_6cc08_row3_col4, #T_6cc08_row3_col5, #T_6cc08_row3_col6, #T_6cc08_row3_col7, #T_6cc08_row3_col8, #T_6cc08_row3_col9, #T_6cc08_row3_col10, #T_6cc08_row3_col11, #T_6cc08_row3_col12, #T_6cc08_row4_col0, #T_6cc08_row4_col1, #T_6cc08_row4_col2, #T_6cc08_row4_col3, #T_6cc08_row4_col4, #T_6cc08_row4_col5, #T_6cc08_row4_col6, #T_6cc08_row4_col7, #T_6cc08_row4_col8, #T_6cc08_row4_col9, #T_6cc08_row4_col10, #T_6cc08_row4_col11, #T_6cc08_row4_col12, #T_6cc08_row5_col5, #T_6cc08_row5_col6, #T_6cc08_row5_col9, #T_6cc08_row6_col0, #T_6cc08_row6_col1, #T_6cc08_row6_col2, #T_6cc08_row6_col3, #T_6cc08_row6_col4, #T_6cc08_row6_col5, #T_6cc08_row6_col6, #T_6cc08_row6_col7, #T_6cc08_row6_col8, #T_6cc08_row6_col9, #T_6cc08_row6_col10, #T_6cc08_row6_col11, #T_6cc08_row6_col12, #T_6cc08_row7_col0, #T_6cc08_row7_col1, #T_6cc08_row7_col2, #T_6cc08_row7_col3, #T_6cc08_row7_col4, #T_6cc08_row7_col5, #T_6cc08_row7_col6, #T_6cc08_row7_col8, #T_6cc08_row7_col9, #T_6cc08_row7_col11, #T_6cc08_row7_col12, #T_6cc08_row8_col0, #T_6cc08_row8_col1, #T_6cc08_row8_col2, #T_6cc08_row8_col3, #T_6cc08_row8_col4, #T_6cc08_row8_col5, #T_6cc08_row8_col6, #T_6cc08_row8_col7, #T_6cc08_row8_col8, #T_6cc08_row8_col9, #T_6cc08_row8_col10, #T_6cc08_row8_col11, #T_6cc08_row8_col12, #T_6cc08_row9_col0, #T_6cc08_row9_col2, #T_6cc08_row9_col4, #T_6cc08_row9_col5, #T_6cc08_row9_col6, #T_6cc08_row9_col7, #T_6cc08_row9_col8, #T_6cc08_row9_col9, #T_6cc08_row9_col10, #T_6cc08_row9_col12, #T_6cc08_row10_col0, #T_6cc08_row10_col1, #T_6cc08_row10_col2, #T_6cc08_row10_col3, #T_6cc08_row10_col4, #T_6cc08_row10_col8, #T_6cc08_row10_col9, #T_6cc08_row10_col10, #T_6cc08_row10_col11, #T_6cc08_row10_col12, #T_6cc08_row11_col9, #T_6cc08_row11_col10, #T_6cc08_row12_col9, #T_6cc08_row13_col5, #T_6cc08_row13_col6, #T_6cc08_row13_col9, #T_6cc08_row15_col0, #T_6cc08_row15_col4, #T_6cc08_row15_col5, #T_6cc08_row15_col6, #T_6cc08_row15_col9, #T_6cc08_row18_col5, #T_6cc08_row18_col6, #T_6cc08_row18_col9, #T_6cc08_row19_col0, #T_6cc08_row19_col1, #T_6cc08_row19_col2, #T_6cc08_row19_col3, #T_6cc08_row19_col4, #T_6cc08_row19_col5, #T_6cc08_row19_col6, #T_6cc08_row19_col7, #T_6cc08_row19_col8, #T_6cc08_row19_col9, #T_6cc08_row19_col10, #T_6cc08_row19_col11, #T_6cc08_row19_col12, #T_6cc08_row20_col9, #T_6cc08_row21_col0, #T_6cc08_row21_col1, #T_6cc08_row21_col2, #T_6cc08_row21_col3, #T_6cc08_row21_col4, #T_6cc08_row21_col7, #T_6cc08_row21_col8, #T_6cc08_row21_col9, #T_6cc08_row21_col10, #T_6cc08_row21_col11, #T_6cc08_row21_col12, #T_6cc08_row22_col9 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_6cc08_row0_col7, #T_6cc08_row16_col12 {
#   background-color: #c4e799;
#   color: #000000;
# }
# #T_6cc08_row0_col8, #T_6cc08_row18_col4 {
#   background-color: #a9db8c;
#   color: #000000;
# }
# #T_6cc08_row0_col10, #T_6cc08_row0_col12, #T_6cc08_row20_col3 {
#   background-color: #bde496;
#   color: #000000;
# }
# #T_6cc08_row0_col11, #T_6cc08_row22_col1 {
#   background-color: #8ed082;
#   color: #000000;
# }
# #T_6cc08_row1_col5, #T_6cc08_row1_col6, #T_6cc08_row9_col3, #T_6cc08_row11_col7 {
#   background-color: #f8fcbd;
#   color: #000000;
# }
# #T_6cc08_row1_col7, #T_6cc08_row14_col2 {
#   background-color: #f4fbb7;
#   color: #000000;
# }
# #T_6cc08_row1_col11, #T_6cc08_row11_col12 {
#   background-color: #fcfed4;
#   color: #000000;
# }
# #T_6cc08_row2_col11, #T_6cc08_row15_col11 {
#   background-color: #fafdc8;
#   color: #000000;
# }
# #T_6cc08_row5_col0 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_6cc08_row5_col1 {
#   background-color: #51b365;
#   color: #f1f1f1;
# }
# #T_6cc08_row5_col2 {
#   background-color: #58b669;
#   color: #f1f1f1;
# }
# #T_6cc08_row5_col3 {
#   background-color: #3ba358;
#   color: #f1f1f1;
# }
# #T_6cc08_row5_col4 {
#   background-color: #40aa5c;
#   color: #f1f1f1;
# }
# #T_6cc08_row5_col7 {
#   background-color: #a6da8b;
#   color: #000000;
# }
# #T_6cc08_row5_col8 {
#   background-color: #49af61;
#   color: #f1f1f1;
# }
# #T_6cc08_row5_col10 {
#   background-color: #89ce80;
#   color: #000000;
# }
# #T_6cc08_row5_col11 {
#   background-color: #3ca458;
#   color: #f1f1f1;
# }
# #T_6cc08_row5_col12 {
#   background-color: #5fba6c;
#   color: #f1f1f1;
# }
# #T_6cc08_row7_col7, #T_6cc08_row11_col0, #T_6cc08_row15_col10, #T_6cc08_row21_col5, #T_6cc08_row21_col6 {
#   background-color: #feffde;
#   color: #000000;
# }
# #T_6cc08_row7_col10 {
#   background-color: #fdfedd;
#   color: #000000;
# }
# #T_6cc08_row9_col1, #T_6cc08_row15_col1, #T_6cc08_row15_col2, #T_6cc08_row15_col7, #T_6cc08_row15_col8 {
#   background-color: #ffffe4;
#   color: #000000;
# }
# #T_6cc08_row9_col11, #T_6cc08_row11_col2 {
#   background-color: #fdfed9;
#   color: #000000;
# }
# #T_6cc08_row10_col5, #T_6cc08_row10_col6 {
#   background-color: #fbfdcf;
#   color: #000000;
# }
# #T_6cc08_row10_col7 {
#   background-color: #fafdcc;
#   color: #000000;
# }
# #T_6cc08_row11_col1 {
#   background-color: #fcfed6;
#   color: #000000;
# }
# #T_6cc08_row11_col3 {
#   background-color: #f9fdc7;
#   color: #000000;
# }
# #T_6cc08_row11_col4, #T_6cc08_row13_col10 {
#   background-color: #f1fab5;
#   color: #000000;
# }
# #T_6cc08_row11_col5, #T_6cc08_row11_col6, #T_6cc08_row20_col10 {
#   background-color: #eaf7af;
#   color: #000000;
# }
# #T_6cc08_row11_col8 {
#   background-color: #feffe1;
#   color: #000000;
# }
# #T_6cc08_row11_col11 {
#   background-color: #f7fcb9;
#   color: #000000;
# }
# #T_6cc08_row12_col0, #T_6cc08_row12_col7, #T_6cc08_row12_col11 {
#   background-color: #c5e89a;
#   color: #000000;
# }
# #T_6cc08_row12_col1, #T_6cc08_row18_col1 {
#   background-color: #b8e293;
#   color: #000000;
# }
# #T_6cc08_row12_col2, #T_6cc08_row13_col11, #T_6cc08_row18_col2 {
#   background-color: #bce395;
#   color: #000000;
# }
# #T_6cc08_row12_col3, #T_6cc08_row13_col4 {
#   background-color: #9cd687;
#   color: #000000;
# }
# #T_6cc08_row12_col4, #T_6cc08_row12_col10, #T_6cc08_row13_col8, #T_6cc08_row18_col0, #T_6cc08_row20_col11 {
#   background-color: #c8e99b;
#   color: #000000;
# }
# #T_6cc08_row12_col5, #T_6cc08_row12_col6, #T_6cc08_row17_col0, #T_6cc08_row17_col1, #T_6cc08_row17_col2, #T_6cc08_row17_col3, #T_6cc08_row17_col4, #T_6cc08_row17_col7, #T_6cc08_row17_col8, #T_6cc08_row17_col9, #T_6cc08_row17_col10, #T_6cc08_row17_col11, #T_6cc08_row17_col12 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_6cc08_row12_col8 {
#   background-color: #cbea9c;
#   color: #000000;
# }
# #T_6cc08_row12_col12, #T_6cc08_row20_col2 {
#   background-color: #ceeb9e;
#   color: #000000;
# }
# #T_6cc08_row13_col0, #T_6cc08_row14_col11, #T_6cc08_row17_col5, #T_6cc08_row17_col6 {
#   background-color: #f6fcb8;
#   color: #000000;
# }
# #T_6cc08_row13_col1, #T_6cc08_row14_col3 {
#   background-color: #e8f6ae;
#   color: #000000;
# }
# #T_6cc08_row13_col2 {
#   background-color: #ecf7b1;
#   color: #000000;
# }
# #T_6cc08_row13_col3, #T_6cc08_row20_col1 {
#   background-color: #ccea9d;
#   color: #000000;
# }
# #T_6cc08_row13_col7 {
#   background-color: #64bc6f;
#   color: #f1f1f1;
# }
# #T_6cc08_row13_col12 {
#   background-color: #d5eea1;
#   color: #000000;
# }
# #T_6cc08_row14_col0 {
#   background-color: #f7fcba;
#   color: #000000;
# }
# #T_6cc08_row14_col1, #T_6cc08_row14_col8 {
#   background-color: #f3fab6;
#   color: #000000;
# }
# #T_6cc08_row14_col4 {
#   background-color: #f9fdc2;
#   color: #000000;
# }
# #T_6cc08_row14_col5, #T_6cc08_row14_col6 {

# %%
import matplotlib.pyplot as plt

# Plotting a comparison of assets weights for each portfolio
fig, ax = plt.subplots(figsize=(14,6))

w_s.plot.bar(ax=ax, width=0.8)
# Out:
# <Axes: >

# %%
obj = 'Sharpe' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe

w_s = pd.DataFrame([])

for i in method_covs:
    port.assets_stats(method_mu=method_mu, method_cov=i, d=0.94)
    w = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
    
w_s.columns = method_covs

# %%
display(w_s.style.format("{:.2%}").background_gradient(cmap='YlGn'))

# %%
# Plotting a comparison of assets weights for each portfolio
ax, fig = plt.subplots(figsize=(14,6))

w_s.plot.bar(ax=fig, width=0.8)
